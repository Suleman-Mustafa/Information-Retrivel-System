# %% [markdown]
# # importing libaries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from collections import defaultdict
from pathlib import Path
from nltk.tokenize import word_tokenize
from nltk.tokenize import RegexpTokenizer
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
import math

# %% [markdown]
# # **loading dataset**

# %%
# param limiter => used to control number of training docs being loaded because of memory overload
limiter = 1000
def load_dataset():
    results = defaultdict(list)
    path = "docs/documents"
    i = 0
    for file in Path(path).iterdir():
        if i < limiter:       
            with open(file, "r") as file_open:
                results["file_name"].append(file.name)
                results["text"].append(file_open.read())
            i = i+1

    return pd.DataFrame(results)

# %%
data = load_dataset()

# %%
#removing .txt extension
data['file_name'] = data['file_name'].apply(lambda name: name.split(".")[0])

# %%
data.shape
# Out:
# (1000, 2)

# %%
data.head()
# Out:
#     file_name                                               text
# 0   file_2572  pulse amplification using impact ionization in...
# 1  file_10570  apparent reflection heights and reflection pro...
# 2   file_6850  a new ionosphere sounder  frequency sweep appa...
# 3   file_4119  the complex formulation of the equations for t...
# 4   file_1693                       lunar tides in at brisbane\n

# %%
path1 = "docs/file_label.txt"
labels = pd.read_csv(path1, names=["file_name", "label"], sep=",", header=None)
labels.head()
# Out:
#   file_name  label
# 0    file_0      0
# 1    file_1      0
# 2    file_2      0
# 3    file_3      0
# 4    file_4      0

# %%
#removing nulls
labels["label"].fillna(0, inplace=True)
labels["label"] = labels["label"].apply(lambda label: label if label != None else 0)
#concat labels to the documents dataframe
labels = labels.reindex(index=labels.index[::-1])

# %%
labels.head()
# Out:
#         file_name  label
# 11428  file_11428      0
# 11427  file_11427      0
# 11426  file_11426      0
# 11425  file_11425      0
# 11424  file_11424      0

# %%
# labels["label"][:limiter]
# data["labels"] = labels["label"][:limiter]
data["labels"] = ""
i = 1
for file_name in data["file_name"]:
    index = data[data["file_name"] == file_name].index.values[0]
    label = labels[labels["file_name"] == file_name]["label"]
    data["labels"][index] = label.values[0] if len(label) > 0 else 0
  # print(data["labels"][data.iloc[data["file_name"] == file_name].index])
# data["labels"] = labels["label"][:limiter]
data.head()
# Out:
#     file_name                                               text labels
# 0   file_2572  pulse amplification using impact ionization in...      0
# 1  file_10570  apparent reflection heights and reflection pro...      0
# 2   file_6850  a new ionosphere sounder  frequency sweep appa...      0
# 3   file_4119  the complex formulation of the equations for t...      0
# 4   file_1693                       lunar tides in at brisbane\n      0

# %% [markdown]
# configs
#
# *   only necessary in google colab

# %%
import nltk
nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/suleman/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /home/suleman/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %% [markdown]
# tokenization

# %%
def tokenize(word_list):
    tokenized_text = []
    for text in word_list:
        tokenized_text.append(word_tokenize(text))
    return tokenized_text
data["text"] = list(tokenize(data["text"]))

# %%
data.head()
# Out:
#     file_name                                               text labels
# 0   file_2572  [pulse, amplification, using, impact, ionizati...      0
# 1  file_10570  [apparent, reflection, heights, and, reflectio...      0
# 2   file_6850  [a, new, ionosphere, sounder, frequency, sweep...      0
# 3   file_4119  [the, complex, formulation, of, the, equations...      0
# 4   file_1693                   [lunar, tides, in, at, brisbane]      0

# %% [markdown]
# change case to lower case

# %%
data['text'] = data['text'].apply(lambda list: [txt.lower() for txt in list])
data.head()
# Out:
#     file_name                                               text labels
# 0   file_2572  [pulse, amplification, using, impact, ionizati...      0
# 1  file_10570  [apparent, reflection, heights, and, reflectio...      0
# 2   file_6850  [a, new, ionosphere, sounder, frequency, sweep...      0
# 3   file_4119  [the, complex, formulation, of, the, equations...      0
# 4   file_1693                   [lunar, tides, in, at, brisbane]      0

# %% [markdown]
# stop word removal

# %%
stop_words = set(stopwords.words('english'))
data['text'] = data['text'].apply(lambda list: [txt for txt in list if not txt in stop_words])
data.head()
# Out:
#     file_name                                               text labels
# 0   file_2572  [pulse, amplification, using, impact, ionizati...      0
# 1  file_10570  [apparent, reflection, heights, reflection, pr...      0
# 2   file_6850  [new, ionosphere, sounder, frequency, sweep, a...      0
# 3   file_4119  [complex, formulation, equations, two, dimensi...      0
# 4   file_1693                           [lunar, tides, brisbane]      0

# %% [markdown]
# stemming

# %%
porter_stemmer = PorterStemmer()
data['text'] = data['text'].apply(lambda list: [porter_stemmer.stem(txt) for txt in list])
data.head()
# Out:
#     file_name                                               text labels
# 0   file_2572  [puls, amplif, use, impact, ioniz, germanium, ...      0
# 1  file_10570  [appar, reflect, height, reflect, properti, io...      0
# 2   file_6850  [new, ionospher, sounder, frequenc, sweep, app...      0
# 3   file_4119  [complex, formul, equat, two, dimension, space...      0
# 4   file_1693                             [lunar, tide, brisban]      0

# %% [markdown]
# ### **generating an inverted index of terms**
# here we are going to create a dictionary with all words as keys and the values are the doc file names containing the word
# *   *NOTE: The get_inverted_index function is memory and cpu intensive so it may take some time*

# %%
#first we get all words
wordlist = [txt for list in data['text'] for txt in list]
#get only unique values using set
wordlist = set(wordlist)
wordlist = list(wordlist)
wordlist
# Out:
# ['accord',
#  'dial',
#  'dynatron',
#  'airborn',
#  'storag',
#  'support',
#  'z',
#  'meter',
#  'exampl',
#  'discharg',
#  'npn',
#  'consist',
#  'special',
#  'swept',
#  'al',
#  'presenc',
#  'suppos',
#  'ledg',
#  'among',
#  'iter',
#  'administr',
#  'alphanumer',
#  'pt',
#  'spectroscopi',
#  'stage',
#  'eleven',
#  'phoenicid',
#  'sidiod',
#  'creat',
#  'impur',
#  'lump',
#  'thevenin',
#  'though',
#  'quantit',
#  'messag',
#  'state',
#  'mgo',
#  'carryii',
#  'packag',
#  'gradient',
#  'evid',
#  'warm',
#  'lithium',
#  'variant',
#  'brown',
#  'ideal',
#  'ba',
#  'thk',
#  'optimum',
#  'probe',
#  'descript',
#  'wavelength',
#  'formal',
#  'biharmon',
#  'irrevers',
#  'vhf',
#  'sakatoon',
#  'cl',
#  'kerguelen',
#  'norton',
#  'ofr',
#  'occurr',
#  'fact',
#  'medium',
#  'barkhausen',
#  'germinid',
#  'econom',
#  'waveband',
#  'mar',
#  'ferro',
#  'langevin',
#  'carbid',
#  'examin',
#  'ten',
#  'superpos',
#  'satisfi',
#  'specif',
#  'group',
#  'didact',
#  'research',
#  'victoria',
#  'discrim',
#  'equinox',
#  'curvatur',
#  'proxim',
#  'deliv',
#  'run',
#  'convect',
#  'csiro',
#  'trlation',
#  'gorelik',
#  'method',
#  'facilit',
#  'oscillatori',
#  'capacitor',
#  'daili',
#  'steeper',
#  'dynamo',
#  'secondari',
#  'strain',
#  'histori',
#  'si',
#  'list',
#  'school',
#  'nth',
#  'manchest',
#  'stream',
#  'broadcast',
#  'counterpart',
#  'therefor',
#  'othr',
#  'electrodeless',
#  'either',
#  'avoid',
#  'po',
#  'rm',
#  'divis',
#  'antireson',
#  'absent',
#  'expert',
#  'statist',
#  'demodul',
#  'longitudin',
#  'sens',
#  'pole',
#  'radii',
#  'thundercloud',
#  'phosphor',
#  'undamp',
#  'precis',
#  'repeat',
#  'loci',
#  'intend',
#  'unifi',
#  'capac',
#  'valid',
#  'drawn',
#  'radiant',
#  'east',
#  'lightn',
#  'motion',
#  'tap',
#  'asymptot',
#  'hydroxyl',
#  'clariti',
#  'abil',
#  'recommend',
#  'surround',
#  'bias',
#  'slope',
#  'pass',
#  'remark',
#  'tripl',
#  'loop',
#  'miscellan',
#  'oscillogram',
#  'centauru',
#  'televis',
#  'preamp',
#  'reflect',
#  'convert',
#  'predomin',
#  'synchron',
#  'establish',
#  'fade',
#  'rectangular',
#  'basi',
#  'gear',
#  'advanc',
#  'inertia',
#  'neglig',
#  'puriti',
#  'collis',
#  'diffract',
#  'send',
#  'round',
#  'despit',
#  'squar',
#  'plexigla',
#  'alkali',
#  'argument',
#  'entir',
#  'markedli',
#  'upper',
#  'conduct',
#  'express',
#  'satur',
#  'teeth',
#  'hundr',
#  'lack',
#  'remaind',
#  'chosen',
#  'mesh',
#  'countri',
#  'soviet',
#  'reactor',
#  'unaffect',
#  'optim',
#  'lead',
#  'spencer',
#  'adjac',
#  'neg',
#  'primari',
#  'rod',
#  'standard',
#  'clock',
#  'construct',
#  'ahead',
#  'ocean',
#  'set',
#  'attempt',
#  'experiment',
#  'intern',
#  'introduct',
#  'tip',
#  'identifi',
#  'semimet',
#  'root',
#  'cross',
#  'predict',
#  'gray',
#  'kjeller',
#  'geodet',
#  'popul',
#  'appear',
#  'impract',
#  'longitud',
#  'centr',
#  'emu',
#  'regen',
#  'bendix',
#  'germanium',
#  'occup',
#  'simpler',
#  'pictur',
#  'diffult',
#  'part',
#  'rang',
#  'explan',
#  'august',
#  'explor',
#  'ribbon',
#  'triangul',
#  'spread',
#  'account',
#  'kennelli',
#  'present',
#  'disk',
#  'pesent',
#  'yield',
#  'movement',
#  'multiplex',
#  'mirror',
#  'maryland',
#  'life',
#  'discontinu',
#  'overal',
#  'includ',
#  'celesti',
#  'geo',
#  'redistribut',
#  'appli',
#  'zeeman',
#  'cerenkov',
#  'rapidli',
#  'highli',
#  'sound',
#  'respons',
#  'franc',
#  'microsecond',
#  'slit',
#  'tide',
#  'togeth',
#  'tendenc',
#  'unz',
#  'schmitt',
#  'particularli',
#  'emisson',
#  'sq',
#  'spim',
#  'ms',
#  'alumina',
#  'permit',
#  'ratcliff',
#  'index',
#  'expans',
#  'v',
#  'hypothes',
#  'reliabl',
#  'whole',
#  'variomet',
#  'confirm',
#  'aberr',
#  'assess',
#  'follow',
#  'mo',
#  'wate',
#  'observatori',
#  'govern',
#  'calcul',
#  'conjunct',
#  'promin',
#  'perseu',
#  'oscil',
#  'rectifi',
#  'mohler',
#  'veroniqu',
#  'preced',
#  'gramophon',
#  'signal',
#  'asymmetri',
#  'bailey',
#  'meteor',
#  'asymmetr',
#  'unload',
#  'diagram',
#  'hercul',
#  'perman',
#  'colour',
#  'ultrason',
#  'descend',
#  'compar',
#  'date',
#  'dark',
#  'intens',
#  'rarifi',
#  'electrodynam',
#  'bosson',
#  'unusu',
#  'propos',
#  'relax',
#  'undergo',
#  'result',
#  'distort',
#  'sommerfield',
#  'tensor',
#  'alkalin',
#  'symmetr',
#  'polariz',
#  'torm',
#  'discov',
#  'stroke',
#  'caviti',
#  'quaternari',
#  'lock',
#  'twenti',
#  'chamber',
#  'resist',
#  'open',
#  'multilay',
#  'moscow',
#  'begin',
#  'bandyopadhyay',
#  'major',
#  'butterworth',
#  'auror',
#  'coordin',
#  'te',
#  'opposit',
#  'describ',
#  'decay',
#  'predictor',
#  'stationari',
#  'scintil',
#  'potenti',
#  'ensur',
#  'hourli',
#  'geograph',
#  'ni',
#  'suppli',
#  'put',
#  'qualit',
#  'unbound',
#  'nomogram',
#  'cybernet',
#  'hydromagnet',
#  'echost',
#  'bombard',
#  'experi',
#  'tamanrasset',
#  'occult',
#  'welker',
#  'spiral',
#  'groov',
#  'perpendicularli',
#  'expect',
#  'plant',
#  'built',
#  'strong',
#  'essenti',
#  'ferroxcub',
#  'widthmm',
#  'us',
#  'zisler',
#  'cygnu',
#  'past',
#  'howe',
#  'full',
#  'characterist',
#  'station',
#  'bose',
#  'spectrum',
#  'astronomi',
#  'sharpen',
#  'prach',
#  'thick',
#  'pound',
#  'brophi',
#  'pressur',
#  'split',
#  'famili',
#  'cosin',
#  'galvano',
#  'whenc',
#  'interfac',
#  'helix',
#  'ozon',
#  'chemic',
#  'fuse',
#  'cone',
#  'stratifi',
#  'line',
#  'tunabl',
#  'bodi',
#  'vanish',
#  'villa',
#  'foldov',
#  'reproduc',
#  'ray',
#  'nondegener',
#  'blanket',
#  'seal',
#  'russian',
#  'combin',
#  'recombin',
#  'near',
#  'sphere',
#  'tandem',
#  'forecast',
#  'heptan',
#  'fed',
#  'manner',
#  'logarithm',
#  'impuls',
#  'inward',
#  'gap',
#  'circularli',
#  'canon',
#  'hydraul',
#  'fraction',
#  'ge',
#  'diatom',
#  'electro',
#  'earth',
#  'strike',
#  'inject',
#  'monthli',
#  'modul',
#  'synthesi',
#  'inadequaci',
#  'analog',
#  'ionic',
#  'exchang',
#  'boost',
#  'could',
#  'concurr',
#  'invercargil',
#  'servic',
#  'magnetogram',
#  'stretch',
#  'analyz',
#  'swr',
#  'spri',
#  'clf',
#  'underestim',
#  'stub',
#  'up',
#  'activ',
#  'suscept',
#  'cerem',
#  'n',
#  'milliamper',
#  'lc',
#  'perfectli',
#  'bouwkamp',
#  'subtrom',
#  'chapman',
#  'roughli',
#  'surement',
#  'aerial',
#  'variabl',
#  'degre',
#  'section',
#  'aspect',
#  'tunnel',
#  'enough',
#  'degener',
#  'arbitrari',
#  'le',
#  'fuller',
#  'vehicl',
#  'tempor',
#  'program',
#  'nonreciproc',
#  'equal',
#  'arm',
#  'emit',
#  'r',
#  'induct',
#  'resin',
#  'whistl',
#  'mechan',
#  'ingredi',
#  'interfer',
#  'miller',
#  'faraday',
#  'abrad',
#  'meissner',
#  'lectur',
#  'lcr',
#  'sign',
#  'displac',
#  'alon',
#  'train',
#  'wu',
#  'gaussian',
#  'chopper',
#  'critic',
#  'curc',
#  'strongli',
#  'piecewis',
#  'contradistinct',
#  'larger',
#  'neither',
#  'fairli',
#  'interrel',
#  'seventeen',
#  'unobtain',
#  'new',
#  'arc',
#  'carbonyl',
#  'afterglow',
#  'wite',
#  'lag',
#  'plan',
#  'improv',
#  'frequent',
#  'vicin',
#  'italian',
#  'theorem',
#  'paramagnet',
#  'electromagnet',
#  'van',
#  'amplif',
#  'depart',
#  'conductor',
#  'committe',
#  'telemetri',
#  'fourier',
#  'amper',
#  'quantum',
#  'rim',
#  'voltag',
#  'gyrofrequ',
#  'bridg',
#  'locu',
#  'vacua',
#  'ettingshausen',
#  'progress',
#  'cell',
#  'heater',
#  'wall',
#  'fall',
#  'matter',
#  'dispers',
#  'oil',
#  'distribut',
#  'defin',
#  'incid',
#  'commerci',
#  'chebyshev',
#  'gallet',
#  'nonmagnet',
#  'analogu',
#  'correct',
#  'passiv',
#  'strictiv',
#  'vice',
#  'broad',
#  'dq',
#  'transient',
#  'doubler',
#  'stochast',
#  'varenna',
#  'w',
#  'uppsala',
#  'materi',
#  'simul',
#  'recept',
#  'implic',
#  'exhaust',
#  'everi',
#  'convey',
#  'moon',
#  'semifinit',
#  'vz',
#  'royal',
#  'abridg',
#  'chiefli',
#  'separ',
#  'microstrip',
#  'bandwidth',
#  'held',
#  'vanguard',
#  'highfrequ',
#  'season',
#  'motor',
#  'dri',
#  'ew',
#  'media',
#  'singli',
#  'known',
#  'revis',
#  'insert',
#  'exactli',
#  'geoelectr',
#  'dispersionless',
#  'multiphas',
#  'ferromagnet',
#  'summer',
#  'howev',
#  'local',
#  'lens',
#  'ad',
#  'step',
#  'maxim',
#  'stop',
#  'protect',
#  'chain',
#  'cassiopeia',
#  'like',
#  'transduc',
#  'review',
#  'counter',
#  'consequ',
#  'su',
#  'unlik',
#  'partit',
#  'approxim',
#  'cost',
#  'kelman',
#  'db',
#  'moment',
#  'interest',
#  'estim',
#  'magnetogalvan',
#  'oblat',
#  'month',
#  'green',
#  'lrc',
#  'multipli',
#  'fit',
#  'well',
#  'superposit',
#  'transmiss',
#  'modulu',
#  'isoclin',
#  'record',
#  'match',
#  'classic',
#  'consum',
#  'april',
#  'rf',
#  'fornax',
#  'tham',
#  'balloon',
#  'simplifi',
#  'ionosond',
#  'germagnet',
#  'four',
#  'may',
#  'allow',
#  'fermat',
#  'strength',
#  'unsymmetr',
#  'freedom',
#  'emf',
#  'argu',
#  'whistler',
#  'behaviour',
#  'aerolen',
#  'background',
#  'magnetoresist',
#  'foil',
#  'hawaii',
#  'slough',
#  'assumpt',
#  'digit',
#  'midnight',
#  'hall',
#  'micrometeorit',
#  'orthogon',
#  'quench',
#  'aluminum',
#  'mark',
#  'principl',
#  'waveform',
#  'introduc',
#  'alfven',
#  'look',
#  'thread',
#  'tape',
#  'suitabl',
#  'elsewher',
#  'develop',
#  'dope',
#  'read',
#  'jancel',
#  'leakag',
#  'cathod',
#  'hartre',
#  'inher',
#  'explain',
#  'permitt',
#  'criteria',
#  'manual',
#  'also',
#  'field',
#  'coron',
#  'photon',
#  'dimension',
#  'feedback',
#  'precess',
#  'ford',
#  'term',
#  'rlc',
#  'telescop',
#  'hammond',
#  'selenid',
#  'board',
#  'interlink',
#  'deposit',
#  'unattend',
#  'reduc',
#  'attract',
#  'northern',
#  'collision',
#  'fredholm',
#  'nh',
#  'prevail',
#  'machineri',
#  'tchebycheff',
#  'texa',
#  'log',
#  'class',
#  'port',
#  'l',
#  'fatigu',
#  'pin',
#  'length',
#  'mismatch',
#  'mount',
#  'scherhag',
#  'column',
#  'nernst',
#  'low',
#  'persistatron',
#  'crittenden',
#  'kaufman',
#  'bulk',
#  'declin',
#  'rigor',
#  'adjust',
#  'drift',
#  'induc',
#  'maximum',
#  'fix',
#  'dynam',
#  'drastic',
#  'constant',
#  'partli',
#  'th',
#  'imag',
#  'differenti',
#  'character',
#  'futur',
#  'solv',
#  'advers',
#  'difficulti',
#  'attribut',
#  'constitut',
#  'cs',
#  'convent',
#  'proceed',
#  'break',
#  'parallel',
#  'want',
#  'dissymmetr',
#  'discuss',
#  'attain',
#  'ihi',
#  'gain',
#  'sunset',
#  'final',
#  'tustin',
#  'flight',
#  'permeabl',
#  'better',
#  'identif',
#  'excit',
#  'done',
#  'pursu',
#  'photograph',
#  'ambient',
#  'june',
#  'colpitt',
#  'lerwick',
#  'plasma',
#  'max',
#  'man',
#  'hysteresi',
#  'manufactur',
#  'array',
#  'gd',
#  'kc',
#  'scatter',
#  'millimet',
#  'birefring',
#  'pyrolysi',
#  'ma',
#  'pr',
#  'potentiomet',
#  'corona',
#  'reactiv',
#  'neighbour',
#  'sputter',
#  'sace',
#  'best',
#  'central',
#  'version',
#  'appar',
#  'speed',
#  'diad',
#  'primarili',
#  'attach',
#  'visual',
#  'dissip',
#  'termin',
#  'provid',
#  'alway',
#  'sunlit',
#  'interferomet',
#  'mu',
#  'cullington',
#  'aber',
#  'deton',
#  'depth',
#  'stabil',
#  'iron',
#  'anomal',
#  'nose',
#  'unexpectedli',
#  'evalu',
#  'perpendicular',
#  'cro',
#  'thoma',
#  'dipol',
#  'wheatston',
#  'poisson',
#  'imperfect',
#  'island',
#  'reconcil',
#  'sic',
#  'probabl',
#  'binder',
#  'antiferroelectr',
#  'shifter',
#  'ellipsoid',
#  'usual',
#  'charact',
#  'system',
#  'societi',
#  'boulder',
#  'acceler',
#  'aris',
#  'circuit',
#  'regul',
#  'gamma',
#  'abstract',
#  'beat',
#  'autodyn',
#  'extend',
#  'theori',
#  'algorithm',
#  'toward',
#  'collector',
#  'sleev',
#  'coast',
#  'geiger',
#  'hamiltonian',
#  'block',
#  'profil',
#  'effect',
#  'dawn',
#  'linear',
#  'format',
#  'obviou',
#  'kerr',
#  'twr',
#  'af',
#  'univers',
#  'encod',
#  'ritz',
#  'nocturn',
#  'thermo',
#  'except',
#  'order',
#  'around',
#  'unipolar',
#  'nation',
#  'resolv',
#  'intermedi',
#  'morpholog',
#  'gate',
#  'nonterrestri',
#  'pa',
#  'clear',
#  'lyman',
#  'powder',
#  'explicit',
#  'lowest',
#  'util',
#  'modifi',
#  'agre',
#  'absolut',
#  'k',
#  'aid',
#  'close',
#  'heavier',
#  'interrupt',
#  'moist',
#  'engrav',
#  'vari',
#  'especi',
#  'microphon',
#  'reciproc',
#  'insul',
#  'thd',
#  'comprehens',
#  'sm',
#  'rule',
#  'micropuls',
#  'greatest',
#  'higher',
#  'start',
#  'snell',
#  'bureau',
#  'aachen',
#  'born',
#  'rel',
#  'ammonia',
#  'planar',
#  'spectromet',
#  'accumul',
#  'dissector',
#  'axi',
#  'teflon',
#  'applic',
#  'morn',
#  'fifti',
#  'muf',
#  'nitrogen',
#  'annular',
#  'affect',
#  'cw',
#  'art',
#  'specular',
#  'actual',
#  'area',
#  'phase',
#  'summat',
#  'plate',
#  'isopor',
#  'langmuir',
#  'horizont',
#  'concern',
#  'ga',
#  'true',
#  'nonenerg',
#  'factor',
#  'avail',
#  'instal',
#  'twin',
#  'molecul',
#  'weber',
#  'ramp',
#  'vibrat',
#  'nine',
#  'loss',
#  'core',
#  ...]

# %%
def get_inverted_index():
    word_dict = defaultdict(set)  
    for i, doc in enumerate(data['text']):
        for word in wordlist:
            if word in doc:
                word_dict[word].add(data.iloc[i, 0])
    return word_dict

word_dict = get_inverted_index()
# word_dict = pd.DataFrame(get_inverted_index())
# word_dict.head()
word_dict
# Out:
# defaultdict(set,
#             {'impur': {'file_1209',
#               'file_2094',
#               'file_2572',
#               'file_3320',
#               'file_4760',
#               'file_5184',
#               'file_5196'},
#              'germanium': {'file_2572',
#               'file_3030',
#               'file_3403',
#               'file_4519',
#               'file_6442',
#               'file_8127'},
#              'rang': {'file_10219',
#               'file_10259',
#               'file_10349',
#               'file_10476',
#               'file_11103',
#               'file_11297',
#               'file_11336',
#               'file_1209',
#               'file_1351',
#               'file_1487',
#               'file_1734',
#               'file_1737',
#               'file_1754',
#               'file_2073',
#               'file_2184',
#               'file_2339',
#               'file_2531',
#               'file_2572',
#               'file_2801',
#               'file_2893',
#               'file_3158',
#               'file_3323',
#               'file_3755',
#               'file_3965',
#               'file_3966',
#               'file_4764',
#               'file_4868',
#               'file_555',
#               'file_5653',
#               'file_5806',
#               'file_6039',
#               'file_6061',
#               'file_6517',
#               'file_6661',
#               'file_6850',
#               'file_706',
#               'file_7186',
#               'file_7556',
#               'file_7796',
#               'file_7860',
#               'file_7895',
#               'file_7916',
#               'file_7959',
#               'file_7999',
#               'file_8132',
#               'file_8555',
#               'file_8618',
#               'file_8802',
#               'file_89',
#               'file_8959',
#               'file_9303',
#               'file_9349',
#               'file_9406',
#               'file_9783',
#               'file_9956'},
#              'describ': {'file_10064',
#               'file_10159',
#               'file_10195',
#               'file_10219',
#               'file_10287',
#               'file_10341',
#               'file_10349',
#               'file_10355',
#               'file_10457',
#               'file_10483',
#               'file_10637',
#               'file_10698',
#               'file_10939',
#               'file_11026',
#               'file_11029',
#               'file_11031',
#               'file_11039',
#               'file_11049',
#               'file_11075',
#               'file_11103',
#               'file_11132',
#               'file_11198',
#               'file_11209',
#               'file_134',
#               'file_1456',
#               'file_1475',
#               'file_1497',
#               'file_1631',
#               'file_1737',
#               'file_1864',
#               'file_1884',
#               'file_1990',
#               'file_2057',
#               'file_2059',
#               'file_2073',
#               'file_2114',
#               'file_2330',
#               'file_2445',
#               'file_2558',
#               'file_2572',
#               'file_2652',
#               'file_2692',
#               'file_2801',
#               'file_2861',
#               'file_2893',
#               'file_2925',
#               'file_2952',
#               'file_3033',
#               'file_3103',
#               'file_3136',
#               'file_3169',
#               'file_3305',
#               'file_3323',
#               'file_3614',
#               'file_3937',
#               'file_3944',
#               'file_3961',
#               'file_3965',
#               'file_3978',
#               'file_427',
#               'file_4351',
#               'file_4446',
#               'file_4451',
#               'file_4475',
#               'file_4692',
#               'file_4808',
#               'file_4811',
#               'file_4974',
#               'file_5011',
#               'file_5049',
#               'file_5275',
#               'file_5276',
#               'file_5368',
#               'file_5430',
#               'file_5458',
#               'file_5653',
#               'file_5679',
#               'file_5735',
#               'file_5741',
#               'file_5953',
#               'file_5963',
#               'file_6037',
#               'file_6046',
#               'file_6099',
#               'file_61',
#               'file_6235',
#               'file_6355',
#               'file_6429',
#               'file_6442',
#               'file_6450',
#               'file_6517',
#               'file_652',
#               'file_6525',
#               'file_6585',
#               'file_667',
#               'file_6731',
#               'file_6776',
#               'file_6781',
#               'file_6850',
#               'file_6875',
#               'file_6952',
#               'file_7077',
#               'file_7376',
#               'file_7378',
#               'file_7452',
#               'file_7489',
#               'file_7767',
#               'file_7810',
#               'file_7878',
#               'file_7879',
#               'file_7916',
#               'file_8123',
#               'file_8127',
#               'file_8128',
#               'file_8132',
#               'file_8240',
#               'file_8340',
#               'file_8559',
#               'file_8560',
#               'file_8643',
#               'file_8672',
#               'file_8676',
#               'file_8774',
#               'file_8802',
#               'file_8893',
#               'file_8959',
#               'file_8998',
#               'file_9127',
#               'file_9298',
#               'file_9303',
#               'file_9342',
#               'file_9484',
#               'file_950',
#               'file_9510',
#               'file_9539',
#               'file_9573',
#               'file_9578',
#               'file_969'},
#              'aspect': {'file_2564',
#               'file_2572',
#               'file_2929',
#               'file_3056',
#               'file_4525',
#               'file_5100'},
#              'amplif': {'file_10515',
#               'file_2330',
#               'file_2572',
#               'file_3056',
#               'file_3100',
#               'file_4124',
#               'file_4446',
#               'file_5844',
#               'file_5988',
#               'file_6254',
#               'file_6450',
#               'file_7818',
#               'file_8024',
#               'file_8960',
#               'file_9578'},
#              'dope': {'file_2572', 'file_9067'},
#              'termin': {'file_2055',
#               'file_2071',
#               'file_2572',
#               'file_2952',
#               'file_5275',
#               'file_5751',
#               'file_6782',
#               'file_7099',
#               'file_7473',
#               'file_7556',
#               'file_9943'},
#              'process': {'file_10017',
#               'file_10159',
#               'file_11429',
#               'file_2572',
#               'file_2647',
#               'file_3627',
#               'file_3803',
#               'file_4307',
#               'file_451',
#               'file_5458',
#               'file_5495',
#               'file_6032',
#               'file_6585',
#               'file_6952',
#               'file_713',
#               'file_7325',
#               'file_7866',
#               'file_8672',
#               'file_870',
#               'file_8817',
#               'file_9481'},
#              'three': {'file_10570',
#               'file_11026',
#               'file_1179',
#               'file_1396',
#               'file_1601',
#               'file_1677',
#               'file_2071',
#               'file_2148',
#               'file_2275',
#               'file_2572',
#               'file_2875',
#               'file_2904',
#               'file_3018',
#               'file_3827',
#               'file_3984',
#               'file_3992',
#               'file_407',
#               'file_4272',
#               'file_4540',
#               'file_5011',
#               'file_5212',
#               'file_5528',
#               'file_5596',
#               'file_5641',
#               'file_5735',
#               'file_587',
#               'file_6031',
#               'file_6098',
#               'file_668',
#               'file_6782',
#               'file_6875',
#               'file_7104',
#               'file_7185',
#               'file_7900',
#               'file_7961',
#               'file_8093',
#               'file_8229',
#               'file_8745',
#               'file_879',
#               'file_950',
#               'file_9808',
#               'file_9926',
#               'file_9943'},
#              'breakdown': {'file_187',
#               'file_2572',
#               'file_4118',
#               'file_7597',
#               'file_7836',
#               'file_9067',
#               'file_9886',
#               'file_9975'},
#              'use': {'file_10076',
#               'file_10085',
#               'file_10182',
#               'file_10218',
#               'file_10259',
#               'file_10281',
#               'file_1031',
#               'file_10339',
#               'file_10341',
#               'file_10355',
#               'file_10457',
#               'file_10476',
#               'file_10521',
#               'file_10588',
#               'file_1061',
#               'file_10682',
#               'file_10736',
#               'file_10800',
#               'file_10809',
#               'file_10939',
#               'file_10960',
#               'file_11049',
#               'file_11103',
#               'file_11145',
#               'file_11263',
#               'file_11332',
#               'file_11343',
#               'file_11394',
#               'file_1169',
#               'file_1187',
#               'file_1302',
#               'file_134',
#               'file_142',
#               'file_145',
#               'file_1452',
#               'file_1456',
#               'file_1497',
#               'file_1552',
#               'file_1622',
#               'file_1631',
#               'file_1638',
#               'file_1667',
#               'file_1734',
#               'file_1751',
#               'file_1754',
#               'file_1864',
#               'file_1869',
#               'file_1884',
#               'file_1976',
#               'file_1981',
#               'file_1989',
#               'file_2059',
#               'file_2073',
#               'file_2096',
#               'file_2114',
#               'file_2228',
#               'file_2321',
#               'file_2344',
#               'file_2362',
#               'file_2366',
#               'file_2374',
#               'file_2401',
#               'file_2449',
#               'file_2547',
#               'file_2563',
#               'file_2572',
#               'file_2676',
#               'file_2762',
#               'file_2801',
#               'file_2827',
#               'file_2904',
#               'file_3125',
#               'file_3169',
#               'file_3259',
#               'file_3305',
#               'file_3310',
#               'file_3472',
#               'file_3627',
#               'file_3628',
#               'file_3654',
#               'file_370',
#               'file_3823',
#               'file_3961',
#               'file_3966',
#               'file_3978',
#               'file_3984',
#               'file_4063',
#               'file_4080',
#               'file_4119',
#               'file_4124',
#               'file_4157',
#               'file_4170',
#               'file_4272',
#               'file_4307',
#               'file_4333',
#               'file_4338',
#               'file_4342',
#               'file_4351',
#               'file_4386',
#               'file_4446',
#               'file_4451',
#               'file_4475',
#               'file_4525',
#               'file_4624',
#               'file_4663',
#               'file_4752',
#               'file_4756',
#               'file_4811',
#               'file_4867',
#               'file_4922',
#               'file_4930',
#               'file_4974',
#               'file_5002',
#               'file_5011',
#               'file_5163',
#               'file_5173',
#               'file_5196',
#               'file_5274',
#               'file_533',
#               'file_5339',
#               'file_5457',
#               'file_5458',
#               'file_555',
#               'file_5653',
#               'file_5677',
#               'file_5735',
#               'file_5768',
#               'file_5836',
#               'file_5956',
#               'file_5963',
#               'file_5988',
#               'file_6033',
#               'file_6039',
#               'file_6046',
#               'file_6069',
#               'file_6081',
#               'file_6099',
#               'file_61',
#               'file_619',
#               'file_6203',
#               'file_6248',
#               'file_6254',
#               'file_6308',
#               'file_6423',
#               'file_6429',
#               'file_6442',
#               'file_6511',
#               'file_652',
#               'file_6521',
#               'file_6546',
#               'file_6553',
#               'file_6691',
#               'file_6731',
#               'file_6776',
#               'file_6781',
#               'file_6798',
#               'file_6873',
#               'file_6875',
#               'file_7077',
#               'file_7087',
#               'file_7186',
#               'file_7287',
#               'file_7325',
#               'file_7356',
#               'file_7370',
#               'file_7378',
#               'file_7385',
#               'file_7440',
#               'file_7471',
#               'file_7473',
#               'file_7486',
#               'file_7487',
#               'file_7551',
#               'file_7694',
#               'file_7796',
#               'file_7818',
#               'file_7860',
#               'file_7879',
#               'file_7895',
#               'file_812',
#               'file_8123',
#               'file_8127',
#               'file_8128',
#               'file_8130',
#               'file_8132',
#               'file_8261',
#               'file_8459',
#               'file_8481',
#               'file_8486',
#               'file_8555',
#               'file_8559',
#               'file_8570',
#               'file_8676',
#               'file_8746',
#               'file_8842',
#               'file_8856',
#               'file_8893',
#               'file_89',
#               'file_8904',
#               'file_8943',
#               'file_9180',
#               'file_93',
#               'file_9340',
#               'file_9342',
#               'file_9349',
#               'file_9406',
#               'file_9436',
#               'file_9446',
#               'file_950',
#               'file_9510',
#               'file_9539',
#               'file_9549',
#               'file_9654',
#               'file_969',
#               'file_9748',
#               'file_9782',
#               'file_9867',
#               'file_99',
#               'file_9926',
#               'file_9956',
#               'file_9969',
#               'file_9975'},
#              'control': {'file_10149',
#               'file_10457',
#               'file_10637',
#               'file_11005',
#               'file_138',
#               'file_1690',
#               'file_2051',
#               'file_2071',
#               'file_2073',
#               'file_2463',
#               'file_2572',
#               'file_26',
#               'file_28',
#               'file_3056',
#               'file_3480',
#               'file_3823',
#               'file_427',
#               'file_4346',
#               'file_4930',
#               'file_5011',
#               'file_5458',
#               'file_5538',
#               'file_5735',
#               'file_5953',
#               'file_6081',
#               'file_6355',
#               'file_7551',
#               'file_8093',
#               'file_8127',
#               'file_8132',
#               'file_8157',
#               'file_8555',
#               'file_8959',
#               'file_9301',
#               'file_9526'},
#              'obtain': {'file_10017',
#               'file_10219',
#               'file_10261',
#               'file_1031',
#               'file_10519',
#               'file_10588',
#               'file_10736',
#               'file_11049',
#               'file_11107',
#               'file_112',
#               'file_11209',
#               'file_11313',
#               'file_11336',
#               'file_11343',
#               'file_11359',
#               'file_11387',
#               'file_119',
#               'file_134',
#               'file_145',
#               'file_1622',
#               'file_166',
#               'file_1734',
#               'file_1751',
#               'file_1851',
#               'file_1884',
#               'file_1981',
#               'file_2059',
#               'file_21',
#               'file_2362',
#               'file_2402',
#               'file_2572',
#               'file_2610',
#               'file_2635',
#               'file_2652',
#               'file_2904',
#               'file_3305',
#               'file_3400',
#               'file_360',
#               'file_370',
#               'file_373',
#               'file_3803',
#               'file_3965',
#               'file_3966',
#               'file_3978',
#               'file_4119',
#               'file_4342',
#               'file_4451',
#               'file_4540',
#               'file_4580',
#               'file_4857',
#               'file_4930',
#               'file_4974',
#               'file_5002',
#               'file_5351',
#               'file_5528',
#               'file_5677',
#               'file_5735',
#               'file_5809',
#               'file_5963',
#               'file_6033',
#               'file_6061',
#               'file_6254',
#               'file_6258',
#               'file_6454',
#               'file_6474',
#               'file_6511',
#               'file_652',
#               'file_6521',
#               'file_6546',
#               'file_6692',
#               'file_6913',
#               'file_7185',
#               'file_7325',
#               'file_7608',
#               'file_7869',
#               'file_7879',
#               'file_8127',
#               'file_8128',
#               'file_8130',
#               'file_8340',
#               'file_8352',
#               'file_8357',
#               'file_89',
#               'file_9480',
#               'file_9510',
#               'file_9549',
#               'file_9578',
#               'file_9898',
#               'file_9956',
#               'file_9969'},
#              'impact': {'file_2572', 'file_5698', 'file_6731'},
#              'phenomena': {'file_11009',
#               'file_11029',
#               'file_11145',
#               'file_11394',
#               'file_1218',
#               'file_2572',
#               'file_2875',
#               'file_3018',
#               'file_3056',
#               'file_3783',
#               'file_458',
#               'file_4764',
#               'file_4786',
#               'file_5290',
#               'file_5495',
#               'file_5528',
#               'file_5698',
#               'file_7227',
#               'file_7313',
#               'file_8340',
#               'file_8453',
#               'file_8609'},
#              'ioniz': {'file_10109',
#               'file_10110',
#               'file_10294',
#               'file_10588',
#               'file_11004',
#               'file_11145',
#               'file_11148',
#               'file_11150',
#               'file_11151',
#               'file_1218',
#               'file_1291',
#               'file_1423',
#               'file_1801',
#               'file_1815',
#               'file_2033',
#               'file_2114',
#               'file_2538',
#               'file_2572',
#               'file_2652',
#               'file_2893',
#               'file_367',
#               'file_4156',
#               'file_4401',
#               'file_4692',
#               'file_4857',
#               'file_5528',
#               'file_580',
#               'file_588',
#               'file_6031',
#               'file_6032',
#               'file_6240',
#               'file_6410',
#               'file_6590',
#               'file_7243',
#               'file_7330',
#               'file_7961',
#               'file_7964',
#               'file_7965',
#               'file_8191',
#               'file_8597',
#               'file_8745',
#               'file_890',
#               'file_8929',
#               'file_899',
#               'file_9042',
#               'file_9157',
#               'file_9502',
#               'file_9748'},
#              'semiconductor': {'file_2572',
#               'file_3056',
#               'file_3320',
#               'file_3472',
#               'file_4760',
#               'file_540',
#               'file_73'},
#              'devic': {'file_10939',
#               'file_11029',
#               'file_142',
#               'file_1981',
#               'file_2051',
#               'file_2176',
#               'file_2424',
#               'file_2572',
#               'file_3056',
#               'file_3378',
#               'file_4811',
#               'file_5011',
#               'file_540',
#               'file_5430',
#               'file_6429',
#               'file_6517',
#               'file_6545',
#               'file_7810',
#               'file_7895',
#               'file_8127',
#               'file_8559'},
#              'two': {'file_10017',
#               'file_10259',
#               'file_10341',
#               'file_10415',
#               'file_10432',
#               'file_10682',
#               'file_10790',
#               'file_10809',
#               'file_10960',
#               'file_112',
#               'file_11359',
#               'file_1190',
#               'file_1246',
#               'file_142',
#               'file_1529',
#               'file_1568',
#               'file_1884',
#               'file_2055',
#               'file_2165',
#               'file_2354',
#               'file_2572',
#               'file_2652',
#               'file_2762',
#               'file_28',
#               'file_2861',
#               'file_2875',
#               'file_3136',
#               'file_3207',
#               'file_3389',
#               'file_3553',
#               'file_367',
#               'file_373',
#               'file_3919',
#               'file_3973',
#               'file_4032',
#               'file_4119',
#               'file_4157',
#               'file_4170',
#               'file_4218',
#               'file_427',
#               'file_4451',
#               'file_4624',
#               'file_4660',
#               'file_4750',
#               'file_4760',
#               'file_4808',
#               'file_4811',
#               'file_484',
#               'file_5011',
#               'file_5049',
#               'file_5276',
#               'file_5351',
#               'file_5368',
#               'file_5431',
#               'file_5538',
#               'file_5606',
#               'file_5626',
#               'file_5679',
#               'file_5751',
#               'file_5836',
#               'file_5963',
#               'file_5988',
#               'file_601',
#               'file_6031',
#               'file_6046',
#               'file_6248',
#               'file_6429',
#               'file_6442',
#               'file_6454',
#               'file_6493',
#               'file_6517',
#               'file_6525',
#               'file_6565',
#               'file_6610',
#               'file_6850',
#               'file_7185',
#               'file_7243',
#               'file_7376',
#               'file_7473',
#               'file_7489',
#               'file_7654',
#               'file_7810',
#               'file_7869',
#               'file_7879',
#               'file_7966',
#               'file_8009',
#               'file_8093',
#               'file_8127',
#               'file_8132',
#               'file_815',
#               'file_8191',
#               'file_8247',
#               'file_8271',
#               'file_8352',
#               'file_8357',
#               'file_8427',
#               'file_8579',
#               'file_8802',
#               'file_8805',
#               'file_8998',
#               'file_927',
#               'file_932',
#               'file_9446',
#               'file_9481',
#               'file_9484',
#               'file_9543',
#               'file_9570',
#               'file_9866',
#               'file_9943',
#               'file_9975'},
#              'millimicrosecond': {'file_2572'},
#              'puls': {'file_10182',
#               'file_10184',
#               'file_10287',
#               'file_10355',
#               'file_10570',
#               'file_10809',
#               'file_10872',
#               'file_11031',
#               'file_11198',
#               'file_1291',
#               'file_1334',
#               'file_166',
#               'file_1667',
#               'file_2057',
#               'file_2073',
#               'file_2321',
#               'file_2401',
#               'file_2572',
#               'file_2801',
#               'file_2952',
#               'file_3147',
#               'file_3169',
#               'file_3259',
#               'file_3285',
#               'file_33',
#               'file_3323',
#               'file_3419',
#               'file_3628',
#               'file_3944',
#               'file_3978',
#               'file_4170',
#               'file_427',
#               'file_4272',
#               'file_4808',
#               'file_5156',
#               'file_5308',
#               'file_533',
#               'file_5653',
#               'file_5959',
#               'file_6235',
#               'file_6248',
#               'file_6454',
#               'file_6525',
#               'file_6545',
#               'file_6546',
#               'file_6959',
#               'file_7287',
#               'file_7385',
#               'file_7486',
#               'file_7597',
#               'file_7869',
#               'file_8127',
#               'file_8559',
#               'file_8560',
#               'file_8676',
#               'file_917',
#               'file_9230',
#               'file_9301',
#               'file_950',
#               'file_9562',
#               'file_9969'},
#              'ledg': {'file_10570'},
#              'occurr': {'file_10570',
#               'file_1797',
#               'file_2532',
#               'file_3116',
#               'file_3389',
#               'file_5212',
#               'file_6039',
#               'file_6494',
#               'file_7965',
#               'file_9257',
#               'file_9522',
#               'file_9886'},
#              'reflect': {'file_10084',
#               'file_10432',
#               'file_10570',
#               'file_10841',
#               'file_11151',
#               'file_112',
#               'file_1291',
#               'file_2114',
#               'file_2652',
#               'file_4124',
#               'file_4156',
#               'file_4170',
#               'file_4580',
#               'file_4663',
#               'file_4760',
#               'file_5308',
#               'file_5653',
#               'file_5892',
#               'file_6036',
#               'file_6039',
#               'file_619',
#               'file_6553',
#               'file_7243',
#               'file_7330',
#               'file_7644',
#               'file_7869',
#               'file_7928',
#               'file_7959',
#               'file_8102',
#               'file_869',
#               'file_8769',
#               'file_9484',
#               'file_9895'},
#              'august': {'file_10570',
#               'file_2263',
#               'file_3017',
#               'file_3320',
#               'file_370',
#               'file_591',
#               'file_9037',
#               'file_9841'},
#              'result': {'file_10076',
#               'file_10219',
#               'file_10355',
#               'file_10513',
#               'file_10519',
#               'file_10570',
#               'file_10713',
#               'file_10718',
#               'file_10736',
#               'file_11004',
#               'file_11148',
#               'file_11336',
#               'file_11394',
#               'file_1538',
#               'file_1622',
#               'file_166',
#               'file_1667',
#               'file_1851',
#               'file_187',
#               'file_2249',
#               'file_2273',
#               'file_2275',
#               'file_249',
#               'file_2740',
#               'file_2751',
#               'file_2762',
#               'file_2861',
#               'file_2904',
#               'file_2919',
#               'file_33',
#               'file_3310',
#               'file_360',
#               'file_370',
#               'file_373',
#               'file_3782',
#               'file_3803',
#               'file_3984',
#               'file_4124',
#               'file_4156',
#               'file_4206',
#               'file_4342',
#               'file_4346',
#               'file_4351',
#               'file_4525',
#               'file_4580',
#               'file_4660',
#               'file_4663',
#               'file_4750',
#               'file_4776',
#               'file_4777',
#               'file_4794',
#               'file_4969',
#               'file_4974',
#               'file_5002',
#               'file_5196',
#               'file_531',
#               'file_5330',
#               'file_5339',
#               'file_5512',
#               'file_5528',
#               'file_5606',
#               'file_5609',
#               'file_5677',
#               'file_5711',
#               'file_5735',
#               'file_5809',
#               'file_5971',
#               'file_6032',
#               'file_6039',
#               'file_6081',
#               'file_61',
#               'file_6240',
#               'file_6258',
#               'file_6308',
#               'file_6410',
#               'file_6442',
#               'file_6449',
#               'file_6521',
#               'file_6565',
#               'file_6661',
#               'file_6692',
#               'file_6731',
#               'file_73',
#               'file_7325',
#               'file_7486',
#               'file_7487',
#               'file_7608',
#               'file_7618',
#               'file_7672',
#               'file_7860',
#               'file_7945',
#               'file_7964',
#               'file_7966',
#               'file_8130',
#               'file_8157',
#               'file_8229',
#               'file_8570',
#               'file_8579',
#               'file_8672',
#               'file_8774',
#               'file_8794',
#               'file_89',
#               'file_9037',
#               'file_9133',
#               'file_9157',
#               'file_9340',
#               'file_9382',
#               'file_9510',
#               'file_969',
#               'file_9737',
#               'file_9782',
#               'file_9825',
#               'file_9886',
#               'file_9894',
#               'file_9898'},
#              'distribut': {'file_10017',
#               'file_102',
#               'file_10285',
#               'file_10570',
#               'file_1126',
#               'file_1371',
#               'file_1690',
#               'file_1769',
#               'file_2094',
#               'file_2401',
#               'file_2952',
#               'file_3100',
#               'file_3125',
#               'file_3389',
#               'file_3803',
#               'file_3827',
#               'file_4246',
#               'file_458',
#               'file_4866',
#               'file_4868',
#               'file_555',
#               'file_5601',
#               'file_5614',
#               'file_5751',
#               'file_601',
#               'file_6032',
#               'file_604',
#               'file_6115',
#               'file_613',
#               'file_619',
#               'file_6203',
#               'file_6305',
#               'file_6438',
#               'file_6522',
#               'file_6548',
#               'file_6553',
#               'file_706',
#               'file_7608',
#               'file_7810',
#               'file_7836',
#               'file_7881',
#               'file_7959',
#               'file_7966',
#               'file_8191',
#               'file_8485',
#               'file_869',
#               'file_8772',
#               'file_8775',
#               'file_8779',
#               'file_8817',
#               'file_8904',
#               'file_9157',
#               'file_9340',
#               'file_9737',
#               'file_9748',
#               'file_9823',
#               'file_9999'},
#              'also': {'file_10064',
#               'file_10084',
#               'file_10570',
#               'file_11332',
#               'file_142',
#               'file_1649',
#               'file_1667',
#               'file_2125',
#               'file_2366',
#               'file_2919',
#               'file_33',
#               'file_3323',
#               'file_3389',
#               'file_3410',
#               'file_3584',
#               'file_3627',
#               'file_3631',
#               'file_3783',
#               'file_3818',
#               'file_4032',
#               'file_4119',
#               'file_4124',
#               'file_4143',
#               'file_4156',
#               'file_4157',
#               'file_4580',
#               'file_4930',
#               'file_5011',
#               'file_5049',
#               'file_5378',
#               'file_5614',
#               'file_5641',
#               'file_5693',
#               'file_5711',
#               'file_6061',
#               'file_619',
#               'file_6258',
#               'file_652',
#               'file_6522',
#               'file_6548',
#               'file_6553',
#               'file_6565',
#               'file_7376',
#               'file_7869',
#               'file_7961',
#               'file_8340',
#               'file_8559',
#               'file_8597',
#               'file_870',
#               'file_8745',
#               'file_89',
#               'file_8920',
#               'file_8959',
#               'file_9257',
#               'file_9737'},
#              'appar': {'file_102', 'file_10570', 'file_479', 'file_9748'},
#              'measur': {'file_102',
#               'file_10218',
#               'file_10281',
#               'file_10287',
#               'file_10294',
#               'file_1031',
#               'file_10413',
#               'file_10540',
#               'file_10557',
#               'file_10570',
#               'file_10588',
#               'file_10682',
#               'file_10698',
#               'file_10713',
#               'file_10718',
#               'file_10841',
#               'file_10872',
#               'file_11017',
#               'file_11132',
#               'file_11332',
#               'file_11359',
#               'file_11420',
#               'file_1538',
#               'file_1815',
#               'file_2125',
#               'file_2274',
#               'file_2341',
#               'file_2374',
#               'file_2397',
#               'file_2456',
#               'file_2558',
#               'file_26',
#               'file_2647',
#               'file_28',
#               'file_2861',
#               'file_2893',
#               'file_2916',
#               'file_2919',
#               'file_3018',
#               'file_309',
#               'file_3207',
#               'file_3350',
#               'file_3812',
#               'file_3827',
#               'file_3961',
#               'file_3965',
#               'file_3966',
#               'file_3973',
#               'file_4143',
#               'file_4157',
#               'file_4170',
#               'file_4256',
#               'file_4273',
#               'file_4290',
#               'file_4394',
#               'file_4451',
#               'file_4475',
#               'file_453',
#               'file_4663',
#               'file_4752',
#               'file_477',
#               'file_4922',
#               'file_4949',
#               'file_4969',
#               'file_4970',
#               'file_4975',
#               'file_5031',
#               'file_5085',
#               'file_5275',
#               'file_5368',
#               'file_5606',
#               'file_5641',
#               'file_580',
#               'file_5809',
#               'file_5963',
#               'file_6036',
#               'file_604',
#               'file_6203',
#               'file_6225',
#               'file_6474',
#               'file_6731',
#               'file_706',
#               'file_7077',
#               'file_7243',
#               'file_7330',
#               'file_7440',
#               'file_7551',
#               'file_7627',
#               'file_7654',
#               'file_7706',
#               'file_7860',
#               'file_7964',
#               'file_8128',
#               'file_8157',
#               'file_8261',
#               'file_869',
#               'file_8769',
#               'file_8775',
#               'file_8866',
#               'file_8893',
#               'file_89',
#               'file_8943',
#               'file_8959',
#               'file_899',
#               'file_9037',
#               'file_9067',
#               'file_9133',
#               'file_917',
#               'file_9230',
#               'file_93',
#               'file_9340',
#               'file_9480',
#               'file_9782',
#               'file_9783',
#               'file_9886'},
#              'ionospher': {'file_10017',
#               'file_10094',
#               'file_102',
#               'file_10281',
#               'file_10287',
#               'file_10294',
#               'file_1031',
#               'file_10432',
#               'file_10570',
#               'file_10713',
#               'file_10728',
#               'file_11004',
#               'file_11005',
#               'file_11148',
#               'file_11151',
#               'file_11267',
#               'file_11280',
#               'file_11394',
#               'file_11404',
#               'file_11420',
#               'file_1258',
#               'file_1414',
#               'file_1423',
#               'file_1552',
#               'file_2015',
#               'file_2033',
#               'file_2114',
#               'file_2274',
#               'file_2402',
#               'file_2528',
#               'file_2762',
#               'file_3017',
#               'file_3018',
#               'file_3026',
#               'file_3125',
#               'file_3584',
#               'file_360',
#               'file_367',
#               'file_370',
#               'file_3818',
#               'file_3823',
#               'file_3827',
#               'file_4159',
#               'file_4170',
#               'file_4290',
#               'file_4401',
#               'file_4403',
#               'file_4794',
#               'file_4896',
#               'file_5002',
#               'file_5112',
#               'file_5219',
#               'file_5330',
#               'file_5528',
#               'file_5606',
#               'file_5609',
#               'file_5614',
#               'file_5719',
#               'file_5809',
#               'file_588',
#               'file_5943',
#               'file_601',
#               'file_6031',
#               'file_6032',
#               'file_6033',
#               'file_6036',
#               'file_613',
#               'file_6131',
#               'file_619',
#               'file_6493',
#               'file_6590',
#               'file_6593',
#               'file_6668',
#               'file_6850',
#               'file_7227',
#               'file_7330',
#               'file_7440',
#               'file_7443',
#               'file_7627',
#               'file_7629',
#               'file_7860',
#               'file_7869',
#               'file_7959',
#               'file_7964',
#               'file_7965',
#               'file_8083',
#               'file_8191',
#               'file_8769',
#               'file_8774',
#               'file_8775',
#               'file_8779',
#               'file_9042',
#               'file_9157',
#               'file_9510',
#               'file_9522',
#               'file_9654',
#               'file_9748'},
#              'least': {'file_10159',
#               'file_10450',
#               'file_10570',
#               'file_5308',
#               'file_6952',
#               'file_8229',
#               'file_9478'},
#              'regularli': {'file_10570', 'file_5711', 'file_6493'},
#              'africa': {'file_10570', 'file_11281', 'file_9522'},
#              'mean': {'file_10017',
#               'file_10110',
#               'file_10570',
#               'file_10630',
#               'file_10872',
#               'file_11132',
#               'file_11176',
#               'file_1291',
#               'file_134',
#               'file_1803',
#               'file_2015',
#               'file_2057',
#               'file_2073',
#               'file_2366',
#               'file_2531',
#               'file_2762',
#               'file_2893',
#               'file_2919',
#               'file_3823',
#               'file_3961',
#               'file_4580',
#               'file_4692',
#               'file_4752',
#               'file_4777',
#               'file_4930',
#               'file_5528',
#               'file_5609',
#               'file_6037',
#               'file_6115',
#               'file_6123',
#               'file_6258',
#               'file_6345',
#               'file_6429',
#               'file_6850',
#               'file_7869',
#               'file_8102',
#               'file_8618',
#               'file_8745',
#               'file_9406',
#               'file_9654',
#               'file_9782',
#               'file_9866'},
#              'tsumeb': {'file_10570'},
#              'lower': {'file_10121',
#               'file_10570',
#               'file_11151',
#               'file_11394',
#               'file_2015',
#               'file_2827',
#               'file_3018',
#               'file_3207',
#               'file_3323',
#               'file_4143',
#               'file_4794',
#               'file_5528',
#               'file_5606',
#               'file_5916',
#               'file_613',
#               'file_7330',
#               'file_7964',
#               'file_8191',
#               'file_89',
#               'file_894',
#               'file_9481',
#               'file_9522',
#               'file_9684',
#               'file_9783',
#               'file_9841'},
#              'observ': {'file_10085',
#               'file_10094',
#               'file_10147',
#               'file_102',
#               'file_10261',
#               'file_10293',
#               'file_10294',
#               'file_10415',
#               'file_10450',
#               'file_10557',
#               'file_10565',
#               'file_10570',
#               'file_10682',
#               'file_10713',
#               'file_10714',
#               'file_10809',
#               'file_10960',
#               'file_10969',
#               'file_11009',
#               'file_11151',
#               'file_1126',
#               'file_11263',
#               'file_11267',
#               'file_11280',
#               'file_11394',
#               'file_11420',
#               'file_119',
#               'file_1209',
#               'file_1291',
#               'file_1414',
#               'file_1674',
#               'file_1822',
#               'file_2017',
#               'file_2394',
#               'file_249',
#               'file_2531',
#               'file_2538',
#               'file_2650',
#               'file_2652',
#               'file_2839',
#               'file_3018',
#               'file_3125',
#               'file_3350',
#               'file_3803',
#               'file_3812',
#               'file_3919',
#               'file_4143',
#               'file_4156',
#               'file_4273',
#               'file_4386',
#               'file_4401',
#               'file_4403',
#               'file_4580',
#               'file_4678',
#               'file_4794',
#               'file_4879',
#               'file_5049',
#               'file_5112',
#               'file_5208',
#               'file_5212',
#               'file_5223',
#               'file_5308',
#               'file_5596',
#               'file_5609',
#               'file_5641',
#               'file_5711',
#               'file_5719',
#               'file_5798',
#               'file_5806',
#               'file_587',
#               'file_5933',
#               'file_601',
#               'file_6031',
#               'file_6032',
#               'file_6039',
#               'file_613',
#               'file_6305',
#               'file_6308',
#               'file_6493',
#               'file_6565',
#               'file_7243',
#               'file_7608',
#               'file_7618',
#               'file_7629',
#               'file_7644',
#               'file_7772',
#               'file_7860',
#               'file_7869',
#               'file_7945',
#               'file_7959',
#               'file_7961',
#               'file_7964',
#               'file_7965',
#               'file_8083',
#               'file_8191',
#               'file_8293',
#               'file_8606',
#               'file_869',
#               'file_870',
#               'file_8746',
#               'file_8769',
#               'file_8774',
#               'file_8794',
#               'file_8817',
#               'file_8900',
#               'file_8904',
#               'file_8920',
#               'file_894',
#               'file_8943',
#               'file_9037',
#               'file_9157',
#               'file_9257',
#               'file_93',
#               'file_9478',
#               'file_9510',
#               'file_9522',
#               'file_9523',
#               'file_9573',
#               'file_9614',
#               'file_9737',
#               'file_9841',
#               'file_9886',
#               'file_9975',
#               'file_9999'},
#              'frequenc': {'file_10084',
#               'file_10195',
#               'file_102',
#               'file_10259',
#               'file_10287',
#               'file_10294',
#               'file_10432',
#               'file_10476',
#               'file_10513',
#               'file_10570',
#               'file_10588',
#               'file_10637',
#               'file_10713',
#               'file_1075',
#               'file_10872',
#               'file_10939',
#               'file_11004',
#               'file_11017',
#               'file_112',
#               'file_11202',
#               'file_11404',
#               'file_11420',
#               'file_1179',
#               'file_1209',
#               'file_142',
#               'file_1423',
#               'file_1622',
#               'file_1638',
#               'file_1734',
#               'file_1751',
#               'file_1815',
#               'file_1843',
#               'file_2015',
#               'file_2071',
#               'file_2073',
#               'file_21',
#               'file_2129',
#               'file_2184',
#               'file_2275',
#               'file_2321',
#               'file_2330',
#               'file_2532',
#               'file_2563',
#               'file_2652',
#               'file_2762',
#               'file_28',
#               'file_2827',
#               'file_2957',
#               'file_3026',
#               'file_3033',
#               'file_3158',
#               'file_33',
#               'file_3320',
#               'file_3410',
#               'file_3616',
#               'file_3654',
#               'file_3735',
#               'file_3812',
#               'file_3944',
#               'file_3961',
#               'file_3966',
#               'file_4218',
#               'file_4272',
#               'file_4273',
#               'file_4290',
#               'file_4338',
#               'file_4346',
#               'file_4351',
#               'file_4540',
#               'file_458',
#               'file_4624',
#               'file_4663',
#               'file_4729',
#               'file_4760',
#               'file_4868',
#               'file_4922',
#               'file_4930',
#               'file_4949',
#               'file_4970',
#               'file_5049',
#               'file_5085',
#               'file_5112',
#               'file_5156',
#               'file_5173',
#               'file_5189',
#               'file_5212',
#               'file_5223',
#               'file_5274',
#               'file_5276',
#               'file_531',
#               'file_533',
#               'file_5330',
#               'file_5606',
#               'file_5641',
#               'file_5653',
#               'file_5679',
#               'file_5751',
#               'file_5809',
#               'file_5827',
#               'file_5844',
#               'file_588',
#               'file_5963',
#               'file_5988',
#               'file_601',
#               'file_6039',
#               'file_6067',
#               'file_6099',
#               'file_619',
#               'file_6248',
#               'file_6254',
#               'file_6305',
#               'file_6355',
#               'file_6449',
#               'file_6450',
#               'file_6451',
#               'file_6494',
#               'file_6517',
#               'file_6522',
#               'file_6545',
#               'file_6548',
#               'file_6610',
#               'file_6661',
#               'file_6850',
#               'file_7077',
#               'file_7185',
#               'file_7243',
#               'file_7356',
#               'file_7370',
#               'file_7376',
# ...
#               'file_4475',
#               'file_4580',
#               'file_4752',
#               'file_4930',
#               'file_5031',
#               'file_5431',
#               'file_569',
#               'file_5988',
#               'file_6061',
#               'file_6258',
#               'file_6474',
#               'file_6576',
#               'file_6978',
#               'file_7077',
#               'file_7185',
#               'file_7186',
#               'file_7325',
#               'file_7370',
#               'file_7879',
#               'file_8035',
#               'file_8127',
#               'file_8579',
#               'file_917',
#               'file_9223',
#               'file_9382',
#               'file_9570',
#               'file_9761',
#               'file_9798',
#               'file_9898'},
#              'welker': {'file_8127'},
#              'ge': {'file_10219',
#               'file_1622',
#               'file_3628',
#               'file_7287',
#               'file_8127'},
#              'db': {'file_2330', 'file_7378', 'file_8127'},
#              'thin': {'file_10736',
#               'file_11105',
#               'file_1529',
#               'file_1989',
#               'file_1992',
#               'file_2366',
#               'file_2424',
#               'file_2676',
#               'file_3378',
#               'file_3944',
#               'file_5212',
#               'file_6179',
#               'file_8127',
#               'file_8998',
#               'file_9109'},
#              'obliqu': {'file_10084',
#               'file_112',
#               'file_2532',
#               'file_3018',
#               'file_8127',
#               'file_869'},
#              'weisshaar': {'file_8127'},
#              'carrier': {'file_10184',
#               'file_6442',
#               'file_6548',
#               'file_7879',
#               'file_8127',
#               'file_8689',
#               'file_9969'},
#              'slab': {'file_5653', 'file_8127'},
#              'novel': {'file_10159', 'file_8127'},
#              'format': {'file_4678', 'file_6031', 'file_6493', 'file_9257'},
#              'vari': {'file_1690',
#               'file_2129',
#               'file_2772',
#               'file_4930',
#               'file_5112',
#               'file_5308',
#               'file_5798',
#               'file_5953',
#               'file_6081',
#               'file_6429',
#               'file_6978',
#               'file_7243',
#               'file_7370',
#               'file_7378',
#               'file_7654',
#               'file_7869',
#               'file_815',
#               'file_8261',
#               'file_8597',
#               'file_8920',
#               'file_9109',
#               'file_9257'},
#              'accumul': {'file_7866', 'file_9257'},
#              'horizont': {'file_11145',
#               'file_373',
#               'file_3827',
#               'file_6039',
#               'file_7961',
#               'file_9257',
#               'file_9382'},
#              'wind': {'file_4272',
#               'file_5002',
#               'file_5719',
#               'file_6522',
#               'file_7330',
#               'file_7916',
#               'file_8805',
#               'file_9257',
#               'file_9406',
#               'file_9956'},
#              'hypothesi': {'file_2772',
#               'file_3026',
#               'file_3553',
#               'file_3961',
#               'file_4777',
#               'file_8293',
#               'file_899',
#               'file_9257'},
#              'persist': {'file_10736', 'file_2676', 'file_3378', 'file_9257'},
#              'veloc': {'file_10646',
#               'file_11280',
#               'file_11345',
#               'file_119',
#               'file_2878',
#               'file_309',
#               'file_3125',
#               'file_3472',
#               'file_4868',
#               'file_5199',
#               'file_5719',
#               'file_61',
#               'file_6913',
#               'file_7961',
#               'file_8293',
#               'file_849',
#               'file_8893',
#               'file_9109',
#               'file_9157',
#               'file_9257',
#               'file_9798'},
#              'whether': {'file_11151', 'file_2125', 'file_528', 'file_7608'},
#              'statist': {'file_10017',
#               'file_1674',
#               'file_3116',
#               'file_3584',
#               'file_484',
#               'file_5330',
#               'file_5528',
#               'file_6115',
#               'file_6410',
#               'file_6668',
#               'file_7422',
#               'file_7629',
#               'file_8271',
#               'file_9461',
#               'file_9484'},
#              'obviou': {'file_484'},
#              'conclus': {'file_1642',
#               'file_484',
#               'file_6565',
#               'file_7525',
#               'file_7866'},
#              'specif': {'file_3584', 'file_4930', 'file_8024'},
#              'attempt': {'file_11145', 'file_1396', 'file_3584', 'file_8794'},
#              'spiral': {'file_3584', 'file_7186'},
#              'behaviour': {'file_1568',
#               'file_2302',
#               'file_3378',
#               'file_3584',
#               'file_4032',
#               'file_588',
#               'file_7836',
#               'file_7888',
#               'file_8191',
#               'file_8960',
#               'file_9109'},
#              'usual': {'file_2165',
#               'file_3584',
#               'file_6008',
#               'file_7629',
#               'file_7818',
#               'file_8157'},
#              'treat': {'file_10800',
#               'file_3584',
#               'file_4660',
#               'file_4769',
#               'file_6442',
#               'file_7325',
#               'file_7928',
#               'file_8093'},
#              'polar': {'file_10287',
#               'file_10483',
#               'file_11323',
#               'file_11394',
#               'file_1552',
#               'file_2148',
#               'file_2275',
#               'file_2366',
#               'file_2528',
#               'file_2839',
#               'file_3584',
#               'file_4118',
#               'file_4124',
#               'file_4930',
#               'file_5606',
#               'file_6115',
#               'file_6454',
#               'file_7525',
#               'file_7916',
#               'file_7961',
#               'file_8229',
#               'file_879',
#               'file_8866'},
#              'elementari': {'file_1642', 'file_4307', 'file_6776', 'file_879'},
#              'pole': {'file_2952',
#               'file_6548',
#               'file_6576',
#               'file_7376',
#               'file_8119',
#               'file_9543',
#               'file_9808'},
#              'allow': {'file_1291',
#               'file_1667',
#               'file_2878',
#               'file_3210',
#               'file_3818',
#               'file_4949',
#               'file_6565',
#               'file_9543'},
#              'version': {'file_5741', 'file_6797', 'file_950'},
#              'abstract': {'file_11026',
#               'file_5641',
#               'file_5837',
#               'file_6797',
#               'file_8547'},
#              'shorten': {'file_6797'},
#              'januari': {'file_11394',
#               'file_1754',
#               'file_5711',
#               'file_5837',
#               'file_6797',
#               'file_8157',
#               'file_8486'},
#              'precis': {'file_3403', 'file_6913', 'file_8794', 'file_9526'},
#              'waveform': {'file_166',
#               'file_2067',
#               'file_3978',
#               'file_427',
#               'file_4346',
#               'file_4930',
#               'file_5156',
#               'file_5308',
#               'file_6254',
#               'file_7385',
#               'file_7869',
#               'file_8132',
#               'file_8794',
#               'file_9956'},
#              'resolv': {'file_6565', 'file_706', 'file_8794', 'file_9737'},
#              'deviat': {'file_7916', 'file_8794', 'file_9523', 'file_9783'},
#              'conflict': {'file_8024', 'file_8794', 'file_9720'},
#              'smooth': {'file_2483', 'file_8794'},
#              'necessari': {'file_11045',
#               'file_1552',
#               'file_2952',
#               'file_3419',
#               'file_6978',
#               'file_8009',
#               'file_8794'},
#              'accur': {'file_11263',
#               'file_1456',
#               'file_3033',
#               'file_3158',
#               'file_427',
#               'file_4580',
#               'file_6203',
#               'file_8794'},
#              'pierc': {'file_2071', 'file_8794'},
#              'trace': {'file_1552', 'file_619', 'file_8794'},
#              'caton': {'file_8794'},
#              'simpl': {'file_11332',
#               'file_11343',
#               'file_1529',
#               'file_1622',
#               'file_166',
#               'file_183',
#               'file_1976',
#               'file_2015',
#               'file_2354',
#               'file_28',
#               'file_2969',
#               'file_3210',
#               'file_3654',
#               'file_4750',
#               'file_5276',
#               'file_5677',
#               'file_5798',
#               'file_6451',
#               'file_654',
#               'file_6545',
#               'file_6548',
#               'file_6800',
#               'file_7672',
#               'file_7810',
#               'file_8340',
#               'file_8555',
#               'file_8672',
#               'file_8794',
#               'file_9523',
#               'file_9562',
#               'file_9943'},
#              'wavelength': {'file_10800',
#               'file_1246',
#               'file_1981',
#               'file_2374',
#               'file_2861',
#               'file_4386',
#               'file_4969',
#               'file_5308',
#               'file_5677',
#               'file_5693',
#               'file_5798',
#               'file_5963',
#               'file_6031',
#               'file_6225',
#               'file_7325',
#               'file_7869',
#               'file_8102',
#               'file_870',
#               'file_9232',
#               'file_9684',
#               'file_9737'},
#              'swr': {'file_5963'},
#              'axi': {'file_2861',
#               'file_3919',
#               'file_4575',
#               'file_5512',
#               'file_5963',
#               'file_8606',
#               'file_8874',
#               'file_9985'},
#              'magic': {'file_10476', 'file_5963'},
#              'coaxial': {'file_5963',
#               'file_6454',
#               'file_6517',
#               'file_6952',
#               'file_7417',
#               'file_7575',
#               'file_8240',
#               'file_8579'},
#              'shield': {'file_10476', 'file_5512', 'file_5963'},
#              'load': {'file_10195',
#               'file_11051',
#               'file_1801',
#               'file_183',
#               'file_2057',
#               'file_2185',
#               'file_2321',
#               'file_2339',
#               'file_3136',
#               'file_3419',
#               'file_3472',
#               'file_528',
#               'file_5368',
#               'file_5963',
#               'file_6098',
#               'file_6875',
#               'file_6981',
#               'file_6993',
#               'file_7356',
#               'file_8240',
#               'file_8555'},
#              'stand': {'file_10923', 'file_4760', 'file_5963'},
#              'hybrid': {'file_10476',
#               'file_4663',
#               'file_5963',
#               'file_8128',
#               'file_8229',
#               'file_9539'},
#              'junction': {'file_10476',
#               'file_1351',
#               'file_2094',
#               'file_2449',
#               'file_3031',
#               'file_3056',
#               'file_3076',
#               'file_5679',
#               'file_5768',
#               'file_5836',
#               'file_5963',
#               'file_667',
#               'file_7672',
#               'file_8229',
#               'file_8559',
#               'file_8570',
#               'file_9528',
#               'file_9969'},
#              'modif': {'file_10193',
#               'file_3103',
#               'file_3553',
#               'file_4794',
#               'file_5963',
#               'file_7183',
#               'file_7916',
#               'file_9414'},
#              'wate': {'file_11220'},
#              'penetr': {'file_112',
#               'file_11220',
#               'file_11394',
#               'file_2839',
#               'file_3018',
#               'file_9894'},
#              'specimen': {'file_11028', 'file_11220'},
#              'chiefli': {'file_3669'},
#              'order': {'file_10521',
#               'file_10557',
#               'file_11387',
#               'file_1334',
#               'file_1642',
#               'file_1677',
#               'file_21',
#               'file_3480',
#               'file_3669',
#               'file_4451',
#               'file_4760',
#               'file_4777',
#               'file_4867',
#               'file_6451',
#               'file_6565',
#               'file_6668',
#               'file_7243',
#               'file_7654',
#               'file_882',
#               'file_90',
#               'file_9005',
#               'file_9761',
#               'file_9898',
#               'file_9926'},
#              'harm': {'file_3669'},
#              'magnitud': {'file_1667',
#               'file_1851',
#               'file_2538',
#               'file_3669',
#               'file_3827',
#               'file_5330',
#               'file_5719',
#               'file_5916',
#               'file_6115',
#               'file_7422',
#               'file_870',
#               'file_8893',
#               'file_9414'},
#              'less': {'file_1209',
#               'file_2033',
#               'file_2394',
#               'file_3136',
#               'file_3285',
#               'file_3305',
#               'file_3669',
#               'file_3755',
#               'file_4930',
#               'file_6429',
#               'file_6494',
#               'file_7183',
#               'file_7964',
#               'file_8943',
#               'file_9969'},
#              'agreement': {'file_11343',
#               'file_11359',
#               'file_1622',
#               'file_1884',
#               'file_3669',
#               'file_4206',
#               'file_4580',
#               'file_4750',
#               'file_5677',
#               'file_5809',
#               'file_6032',
#               'file_6179',
#               'file_7330',
#               'file_7486',
#               'file_7964',
#               'file_8128',
#               'file_849',
#               'file_8920',
#               'file_9510',
#               'file_9783',
#               'file_9886',
#               'file_9898'},
#              'ne': {'file_1884', 'file_3669'},
#              'xe': {'file_3669'},
#              'gaseou': {'file_1884', 'file_3669', 'file_4256', 'file_706'},
#              'spitzer': {'file_3669'},
#              'vicin': {'file_10110', 'file_477', 'file_5596'},
#              'moon': {'file_10261',
#               'file_2528',
#               'file_2878',
#               'file_4386',
#               'file_477',
#               'file_5308',
#               'file_9484'},
#              'scientif': {'file_10281', 'file_11132', 'file_477'},
#              'planet': {'file_3553', 'file_477'},
#              'inertia': {'file_6209'},
#              'terrestri': {'file_10450',
#               'file_11387',
#               'file_3553',
#               'file_6209',
#               'file_7227'},
#              'make': {'file_4867',
#               'file_5011',
#               'file_6209',
#               'file_7370',
#               'file_7378',
#               'file_7869',
#               'file_9342'},
#              'contribut': {'file_10195',
#               'file_3310',
#               'file_3961',
#               'file_5212',
#               'file_6209',
#               'file_7556',
#               'file_8689'},
#              'alkali': {'file_6115'},
#              'l': {'file_1452', 'file_6115'},
#              'imag': {'file_16',
#               'file_1940',
#               'file_6115',
#               'file_652',
#               'file_654',
#               'file_7376',
#               'file_7473',
#               'file_9549'},
#              ...})

# %% [markdown]
# # **modelling**

# %% [markdown]
# get inverse document frequency
# *   idf = log(total docs/total docs containing term)

# %%
def get_idf(word):
    return math.log(data.shape[0] / (len(word_dict[word])))

# %% [markdown]
# get rsv ranking weights
#
#
# 1.   generate rsv of each word based on the whole training documents
# 2.   generate rsv of doc based on specific doc provided

# %%
def get_relevant_docs(docs):
  
    files = []
    for file_name in list(docs):
        if int(data[data['file_name'] == file_name]["labels"]) == 1:
            files.append( file_name )
    return files


def generate_rsv_weights():
    weights = {}
    for word in wordlist:
        terms_in_relevant_docs = len(get_relevant_docs(word_dict[word]))
        prob_of_word = terms_in_relevant_docs/(data.shape[0]+0.5)
        _log = math.log(prob_of_word/(1-prob_of_word)) if prob_of_word > 0 else 0
        weights[word] = get_idf(word) + _log
    return weights

weights = generate_rsv_weights()

# %%
weights
# Out:
# {'accord': 5.521460917862246,
#  'dial': 6.907755278982137,
#  'dynatron': 6.907755278982137,
#  'airborn': 6.214608098422191,
#  'storag': 3.9633162998156966,
#  'support': 4.509860006183766,
#  'z': 5.298317366548036,
#  'meter': 5.809142990314028,
#  'exampl': 4.3428059215206005,
#  'discharg': -3.496007436424798,
#  'npn': 6.214608098422191,
#  'consist': 3.7297014486341915,
#  'special': 4.199705077879927,
#  'swept': 6.907755278982137,
#  'al': 5.298317366548036,
#  'presenc': 4.8283137373023015,
#  'suppos': 6.907755278982137,
#  'ledg': 6.907755278982137,
#  'among': 6.214608098422191,
#  'iter': 6.907755278982137,
#  'administr': 6.907755278982137,
#  'alphanumer': 6.907755278982137,
#  'pt': 5.809142990314028,
#  'spectroscopi': 6.214608098422191,
#  'stage': 3.912023005428146,
#  'eleven': 6.907755278982137,
#  'phoenicid': 6.907755278982137,
#  'sidiod': 6.907755278982137,
#  'creat': 5.809142990314028,
#  'impur': 4.961845129926823,
#  'lump': 6.214608098422191,
#  'thevenin': 6.907755278982137,
#  'though': 5.298317366548036,
#  'quantit': 4.961845129926823,
#  'messag': 6.214608098422191,
#  'state': 3.649658740960655,
#  'mgo': 6.907755278982137,
#  'carryii': 6.907755278982137,
#  'packag': 6.214608098422191,
#  'gradient': 5.521460917862246,
#  'evid': 4.074541934925921,
#  'warm': 6.907755278982137,
#  'lithium': 0.0005001250416816205,
#  'variant': 6.214608098422191,
#  'brown': 6.907755278982137,
#  'ideal': 4.509860006183766,
#  'ba': 6.214608098422191,
#  'thk': 6.907755278982137,
#  'optimum': 4.422848629194137,
#  'probe': 4.605170185988092,
#  'descript': 3.506557897319982,
#  'wavelength': 3.8632328412587142,
#  'formal': 6.907755278982137,
#  'biharmon': 6.907755278982137,
#  'irrevers': 5.809142990314028,
#  'vhf': 5.115995809754082,
#  'sakatoon': 6.907755278982137,
#  'cl': 6.907755278982137,
#  'kerguelen': 6.907755278982137,
#  'norton': 6.907755278982137,
#  'ofr': 6.907755278982137,
#  'occurr': 4.422848629194137,
#  'fact': 6.214608098422191,
#  'medium': -2.397395147756689,
#  'barkhausen': 6.907755278982137,
#  'germinid': 6.907755278982137,
#  'econom': 6.907755278982137,
#  'waveband': 6.907755278982137,
#  'mar': 6.907755278982137,
#  'ferro': 6.907755278982137,
#  'langevin': 6.907755278982137,
#  'carbid': 6.907755278982137,
#  'examin': 3.575550768806933,
#  'ten': 4.961845129926823,
#  'superpos': 6.907755278982137,
#  'satisfi': 4.961845129926823,
#  'specif': 5.809142990314028,
#  'group': 5.298317366548036,
#  'didact': 6.907755278982137,
#  'research': 4.710530701645918,
#  'victoria': 6.907755278982137,
#  'discrim': 6.907755278982137,
#  'equinox': 6.214608098422191,
#  'curvatur': 6.907755278982137,
#  'proxim': 6.907755278982137,
#  'deliv': 6.214608098422191,
#  'run': 5.521460917862246,
#  'convect': 6.907755278982137,
#  'csiro': 6.214608098422191,
#  'trlation': 6.907755278982137,
#  'gorelik': 6.907755278982137,
#  'method': 2.3330443004787544,
#  'facilit': 5.809142990314028,
#  'oscillatori': 5.298317366548036,
#  'capacitor': 4.199705077879927,
#  'daili': 5.115995809754082,
#  'steeper': 6.907755278982137,
#  'dynamo': 5.521460917862246,
#  'secondari': -1.3182497006530314,
#  'strain': 6.907755278982137,
#  'histori': 6.907755278982137,
#  'si': 5.809142990314028,
#  'list': 6.907755278982137,
#  'school': 6.907755278982137,
#  'nth': 6.907755278982137,
#  'manchest': 6.214608098422191,
#  'stream': 5.521460917862246,
#  'broadcast': 6.907755278982137,
#  'counterpart': 6.907755278982137,
#  'therefor': 6.907755278982137,
#  'othr': 6.907755278982137,
#  'electrodeless': 5.809142990314028,
#  'either': 4.605170185988092,
#  'avoid': 5.809142990314028,
#  'po': 6.907755278982137,
#  'rm': 6.214608098422191,
#  'divis': 6.214608098422191,
#  'antireson': 6.214608098422191,
#  'absent': 6.907755278982137,
#  'expert': 6.907755278982137,
#  'statist': 4.199705077879927,
#  'demodul': 6.214608098422191,
#  'longitudin': 4.605170185988092,
#  'sens': 6.214608098422191,
#  'pole': 4.961845129926823,
#  'radii': 6.214608098422191,
#  'thundercloud': 5.809142990314028,
#  'phosphor': 6.907755278982137,
#  'undamp': 5.809142990314028,
#  'precis': 5.521460917862246,
#  'repeat': 5.809142990314028,
#  'loci': 6.907755278982137,
#  'intend': 6.907755278982137,
#  'unifi': 6.214608098422191,
#  'capac': 5.809142990314028,
#  'valid': 5.809142990314028,
#  'drawn': 6.214608098422191,
#  'radiant': 6.214608098422191,
#  'east': 5.115995809754082,
#  'lightn': 5.521460917862246,
#  'motion': 3.8632328412587142,
#  'tap': 5.809142990314028,
#  'asymptot': 6.214608098422191,
#  'hydroxyl': 6.907755278982137,
#  'clariti': 6.907755278982137,
#  'abil': 6.214608098422191,
#  'recommend': 6.907755278982137,
#  'surround': 6.214608098422191,
#  'bias': 6.907755278982137,
#  'slope': 6.907755278982137,
#  'pass': 3.324236340526027,
#  'remark': 5.809142990314028,
#  'tripl': 5.809142990314028,
#  'loop': 4.017383521085972,
#  'miscellan': 6.907755278982137,
#  'oscillogram': 6.214608098422191,
#  'centauru': 6.907755278982137,
#  'televis': 5.115995809754082,
#  'preamp': 6.907755278982137,
#  'reflect': 3.411247717515657,
#  'convert': 5.115995809754082,
#  'predomin': 5.809142990314028,
#  'synchron': 4.8283137373023015,
#  'establish': 4.710530701645918,
#  'fade': 5.298317366548036,
#  'rectangular': 4.509860006183766,
#  'basi': 4.605170185988092,
#  'gear': 6.907755278982137,
#  'advanc': 5.809142990314028,
#  'inertia': 6.907755278982137,
#  'neglig': 6.214608098422191,
#  'puriti': 6.907755278982137,
#  'collis': 4.3428059215206005,
#  'diffract': 4.199705077879927,
#  'send': 6.907755278982137,
#  'round': 5.521460917862246,
#  'despit': 6.214608098422191,
#  'squar': 4.017383521085972,
#  'plexigla': 6.907755278982137,
#  'alkali': 6.907755278982137,
#  'argument': 6.907755278982137,
#  'entir': 6.907755278982137,
#  'markedli': 6.214608098422191,
#  'upper': 4.3428059215206005,
#  'conduct': 3.575550768806933,
#  'express': 3.2968373663379125,
#  'satur': 5.115995809754082,
#  'teeth': 6.907755278982137,
#  'hundr': 6.907755278982137,
#  'lack': 6.907755278982137,
#  'remaind': 6.907755278982137,
#  'chosen': 5.809142990314028,
#  'mesh': 5.521460917862246,
#  'countri': 6.907755278982137,
#  'soviet': 6.214608098422191,
#  'reactor': 6.907755278982137,
#  'unaffect': 6.907755278982137,
#  'optim': 6.907755278982137,
#  'lead': -2.707550076060528,
#  'spencer': 6.907755278982137,
#  'adjac': 6.907755278982137,
#  'neg': 3.473768074496991,
#  'primari': -1.6079367863078327,
#  'rod': 5.521460917862246,
#  'standard': -2.1967244522945375,
#  'clock': 6.907755278982137,
#  'construct': 3.4420193761824107,
#  'ahead': 6.907755278982137,
#  'ocean': 6.907755278982137,
#  'set': 4.199705077879927,
#  'attempt': 5.521460917862246,
#  'experiment': -3.96979178851044,
#  'intern': 4.710530701645918,
#  'introduct': 6.214608098422191,
#  'tip': 6.907755278982137,
#  'identifi': 5.809142990314028,
#  'semimet': 6.907755278982137,
#  'root': 5.298317366548036,
#  'cross': 4.268697949366879,
#  'predict': 4.268697949366879,
#  'gray': 6.907755278982137,
#  'kjeller': 6.907755278982137,
#  'geodet': 6.907755278982137,
#  'popul': 5.809142990314028,
#  'appear': 4.605170185988092,
#  'impract': 6.907755278982137,
#  'longitud': 6.907755278982137,
#  'centr': 3.9633162998156966,
#  'emu': 6.907755278982137,
#  'regen': 6.214608098422191,
#  'bendix': 6.907755278982137,
#  'germanium': 5.115995809754082,
#  'occup': 6.907755278982137,
#  'simpler': 5.809142990314028,
#  'pictur': 6.214608098422191,
#  'diffult': 6.907755278982137,
#  'part': 3.2188758248682006,
#  'rang': 2.900422093749666,
#  'explan': 4.199705077879927,
#  'august': 4.8283137373023015,
#  'explor': 5.521460917862246,
#  'ribbon': 6.907755278982137,
#  'triangul': 6.907755278982137,
#  'spread': 4.8283137373023015,
#  'account': -3.5258603995744795,
#  'kennelli': 6.907755278982137,
#  'present': 2.864704011147587,
#  'disk': 4.268697949366879,
#  'pesent': 6.907755278982137,
#  'yield': -1.3857942360782092,
#  'movement': 5.115995809754082,
#  'multiplex': 6.907755278982137,
#  'mirror': 5.809142990314028,
#  'maryland': 6.907755278982137,
#  'life': 5.809142990314028,
#  'discontinu': 5.521460917862246,
#  'overal': 5.809142990314028,
#  'includ': 3.1941832122778293,
#  'celesti': 6.907755278982137,
#  'geo': 6.907755278982137,
#  'redistribut': 6.907755278982137,
#  'appli': -3.7836895088765794,
#  'zeeman': 6.214608098422191,
#  'cerenkov': 5.521460917862246,
#  'rapidli': 5.115995809754082,
#  'highli': 6.907755278982137,
#  'sound': 5.521460917862246,
#  'respons': 3.2188758248682006,
#  'franc': 6.214608098422191,
#  'microsecond': 5.521460917862246,
#  'slit': 5.809142990314028,
#  'tide': 5.809142990314028,
#  'togeth': 4.8283137373023015,
#  'tendenc': 6.907755278982137,
#  'unz': 6.907755278982137,
#  'schmitt': 6.907755278982137,
#  'particularli': 4.8283137373023015,
#  'emisson': 0.0005001250416816205,
#  'sq': 6.214608098422191,
#  'spim': 6.907755278982137,
#  'ms': 6.907755278982137,
#  'alumina': 6.907755278982137,
#  'permit': 5.298317366548036,
#  'ratcliff': 6.907755278982137,
#  'index': 4.605170185988092,
#  'expans': 4.961845129926823,
#  'v': 5.298317366548036,
#  'hypothes': 6.907755278982137,
#  'reliabl': 4.961845129926823,
#  'whole': 5.115995809754082,
#  'variomet': 6.907755278982137,
#  'confirm': 4.605170185988092,
#  'aberr': 6.907755278982137,
#  'assess': 5.809142990314028,
#  'follow': 4.017383521085972,
#  'mo': 6.907755278982137,
#  'wate': 6.907755278982137,
#  'observatori': 6.214608098422191,
#  'govern': 6.214608098422191,
#  'calcul': -4.330233215244649,
#  'conjunct': 5.298317366548036,
#  'promin': 6.907755278982137,
#  'perseu': 6.907755278982137,
#  'oscil': 2.5383074265151158,
#  'rectifi': 4.8283137373023015,
#  'mohler': 6.907755278982137,
#  'veroniqu': 6.907755278982137,
#  'preced': 6.907755278982137,
#  'gramophon': 6.907755278982137,
#  'signal': 2.882403588246988,
#  'asymmetri': 6.214608098422191,
#  'bailey': 6.907755278982137,
#  'meteor': 4.3428059215206005,
#  'asymmetr': 5.298317366548036,
#  'unload': 6.907755278982137,
#  'diagram': 4.605170185988092,
#  'hercul': 6.907755278982137,
#  'perman': 6.214608098422191,
#  'colour': 6.907755278982137,
#  'ultrason': 5.521460917862246,
#  'descend': 6.907755278982137,
#  'compar': 3.1941832122778293,
#  'date': 6.907755278982137,
#  'dark': -1.0981121636264275,
#  'intens': 3.4420193761824107,
#  'rarifi': 6.907755278982137,
#  'electrodynam': 5.298317366548036,
#  'bosson': 6.907755278982137,
#  'unusu': 5.298317366548036,
#  'propos': 4.074541934925921,
#  'relax': 4.961845129926823,
#  'undergo': 6.907755278982137,
#  'result': -4.050283821677038,
#  'distort': 4.017383521085972,
#  'sommerfield': 6.907755278982137,
#  'tensor': 5.809142990314028,
#  'alkalin': 6.907755278982137,
#  'symmetr': 4.605170185988092,
#  'polariz': 6.907755278982137,
#  'torm': 6.907755278982137,
#  'discov': 6.907755278982137,
#  'stroke': 6.907755278982137,
#  'caviti': 4.3428059215206005,
#  'quaternari': 6.907755278982137,
#  'lock': 5.809142990314028,
#  'twenti': 6.907755278982137,
#  'chamber': 5.521460917862246,
#  'resist': 3.324236340526027,
#  'open': 5.298317366548036,
#  'multilay': 6.214608098422191,
#  'moscow': 5.809142990314028,
#  'begin': 6.214608098422191,
#  'bandyopadhyay': 6.907755278982137,
#  'major': 5.298317366548036,
#  'butterworth': 6.907755278982137,
#  'auror': 3.7722610630529876,
#  'coordin': 6.907755278982137,
#  'te': 5.809142990314028,
#  'opposit': 6.214608098422191,
#  'describ': -4.926753560115523,
#  'decay': 6.214608098422191,
#  'predictor': 6.907755278982137,
#  'stationari': 5.809142990314028,
#  'scintil': 5.809142990314028,
#  'potenti': -2.889871632854483,
#  'ensur': 6.907755278982137,
#  'hourli': 6.214608098422191,
#  'geograph': 5.115995809754082,
#  'ni': 6.214608098422191,
#  'suppli': 4.074541934925921,
#  'put': 6.907755278982137,
#  'qualit': 5.809142990314028,
#  'unbound': 6.214608098422191,
#  'nomogram': 6.907755278982137,
#  'cybernet': 6.907755278982137,
#  'hydromagnet': 5.298317366548036,
#  'echost': 6.907755278982137,
#  'bombard': 5.809142990314028,
#  'experi': 4.135166556742356,
#  'tamanrasset': 6.907755278982137,
#  'occult': 6.214608098422191,
#  'welker': 6.907755278982137,
#  'spiral': 6.214608098422191,
#  'groov': 6.907755278982137,
#  'perpendicularli': 6.907755278982137,
#  'expect': 5.115995809754082,
#  'plant': 6.907755278982137,
#  'built': 5.115995809754082,
#  'strong': 4.8283137373023015,
#  'essenti': 5.298317366548036,
#  'ferroxcub': 5.809142990314028,
#  'widthmm': 6.907755278982137,
#  'us': 6.214608098422191,
#  'zisler': 6.907755278982137,
#  'cygnu': 6.907755278982137,
#  'past': 6.907755278982137,
#  'howe': 6.907755278982137,
#  'full': 4.961845129926823,
#  'characterist': -4.142634601349851,
#  'station': 3.6888794541139363,
#  'bose': 6.907755278982137,
#  'spectrum': 4.268697949366879,
#  'astronomi': 5.809142990314028,
#  'sharpen': 6.907755278982137,
#  'prach': 6.907755278982137,
#  'thick': 4.268697949366879,
#  'pound': 6.907755278982137,
#  'brophi': 6.907755278982137,
#  'pressur': -2.707550076060528,
#  'split': 4.961845129926823,
#  'famili': 5.809142990314028,
#  'cosin': 6.907755278982137,
#  'galvano': 6.907755278982137,
#  'whenc': 6.907755278982137,
#  'interfac': 6.907755278982137,
#  'helix': 6.907755278982137,
#  'ozon': 5.809142990314028,
#  'chemic': 6.214608098422191,
#  'fuse': 5.809142990314028,
#  'cone': 6.907755278982137,
#  'stratifi': 6.907755278982137,
#  'line': 3.123565645063876,
#  'tunabl': 5.521460917862246,
#  'bodi': 4.710530701645918,
#  'vanish': 6.214608098422191,
#  'villa': 6.907755278982137,
#  'foldov': 6.907755278982137,
#  'reproduc': 5.809142990314028,
#  'ray': 3.649658740960655,
#  'nondegener': 6.907755278982137,
#  'blanket': 6.907755278982137,
#  'seal': 6.907755278982137,
#  'russian': 6.214608098422191,
#  'combin': 4.8283137373023015,
#  'recombin': 4.605170185988092,
#  'near': 3.8632328412587142,
#  'sphere': 4.961845129926823,
#  'tandem': 6.907755278982137,
#  'forecast': 5.521460917862246,
#  'heptan': 6.907755278982137,
#  'fed': 6.907755278982137,
#  'manner': 5.809142990314028,
#  'logarithm': 5.521460917862246,
#  'impuls': 6.214608098422191,
#  'inward': 6.907755278982137,
#  'gap': 5.115995809754082,
#  'circularli': 6.907755278982137,
#  'canon': 6.907755278982137,
#  'hydraul': 6.907755278982137,
#  'fraction': 5.298317366548036,
#  'ge': 5.298317366548036,
#  'diatom': 6.907755278982137,
#  'electro': 5.809142990314028,
#  'earth': 3.1465551632885744,
#  'strike': 6.214608098422191,
#  'inject': 6.907755278982137,
#  'monthli': 5.521460917862246,
#  'modul': 3.7297014486341915,
#  'synthesi': 5.298317366548036,
#  'inadequaci': 6.214608098422191,
#  'analog': 5.115995809754082,
#  'ionic': -1.6089377873924189,
#  'exchang': 5.521460917862246,
#  'boost': 6.907755278982137,
#  'could': 5.521460917862246,
#  'concurr': 6.907755278982137,
#  'invercargil': 6.907755278982137,
#  'servic': 6.907755278982137,
#  'magnetogram': 6.907755278982137,
#  'stretch': 6.907755278982137,
#  'analyz': 5.809142990314028,
#  'swr': 6.907755278982137,
#  'spri': 6.907755278982137,
#  'clf': 6.907755278982137,
#  'underestim': 6.907755278982137,
#  'stub': 6.907755278982137,
#  'up': 6.907755278982137,
#  'activ': 3.649658740960655,
#  'suscept': 5.809142990314028,
#  'cerem': 6.907755278982137,
#  'n': 4.199705077879927,
#  'milliamper': 6.907755278982137,
#  'lc': 5.298317366548036,
#  'perfectli': 5.809142990314028,
#  'bouwkamp': 6.907755278982137,
#  'subtrom': 6.907755278982137,
#  'chapman': 5.809142990314028,
#  'roughli': 6.907755278982137,
#  'surement': 6.907755278982137,
#  'aerial': 4.605170185988092,
#  'variabl': 3.7297014486341915,
#  'degre': 4.605170185988092,
#  'section': 4.422848629194137,
#  'aspect': 5.115995809754082,
#  'tunnel': 5.809142990314028,
#  'enough': 6.907755278982137,
#  'degener': 5.809142990314028,
#  'arbitrari': 5.298317366548036,
#  'le': 6.907755278982137,
#  'fuller': 6.214608098422191,
#  'vehicl': 6.907755278982137,
#  'tempor': 6.907755278982137,
#  'program': 5.115995809754082,
#  'nonreciproc': 6.214608098422191,
#  'equal': 4.135166556742356,
#  'arm': 6.214608098422191,
#  'emit': -1.3857942360782092,
#  'r': 5.115995809754082,
#  'induct': 3.912023005428146,
#  'resin': 6.907755278982137,
#  'whistl': 6.907755278982137,
#  'mechan': -3.090542328316634,
#  'ingredi': 6.907755278982137,
#  'interfer': 5.298317366548036,
#  'miller': 5.809142990314028,
#  'faraday': 5.298317366548036,
#  'abrad': 6.907755278982137,
#  'meissner': 6.907755278982137,
#  'lectur': 6.907755278982137,
#  'lcr': 5.809142990314028,
#  'sign': 5.809142990314028,
#  'displac': 5.521460917862246,
#  'alon': 5.809142990314028,
#  'train': 5.521460917862246,
#  'wu': 6.907755278982137,
#  'gaussian': 6.907755278982137,
#  'chopper': 5.809142990314028,
#  'critic': 3.649658740960655,
#  'curc': 6.907755278982137,
#  'strongli': 6.214608098422191,
#  'piecewis': 6.907755278982137,
#  'contradistinct': 6.907755278982137,
#  'larger': 5.809142990314028,
#  'neither': 5.809142990314028,
#  'fairli': 6.907755278982137,
#  'interrel': 6.907755278982137,
#  'seventeen': 6.907755278982137,
#  'unobtain': 6.907755278982137,
#  'new': 3.4420193761824107,
#  'arc': 5.298317366548036,
#  'carbonyl': 6.907755278982137,
#  'afterglow': 6.907755278982137,
#  'wite': 6.907755278982137,
#  'lag': 6.214608098422191,
#  'plan': 6.907755278982137,
#  'improv': 4.017383521085972,
#  'frequent': 5.521460917862246,
#  'vicin': 5.809142990314028,
#  'italian': 6.907755278982137,
#  'theorem': 5.115995809754082,
#  'paramagnet': 4.8283137373023015,
#  'electromagnet': 3.7297014486341915,
#  'van': 5.521460917862246,
#  'amplif': 4.199705077879927,
#  'depart': 6.907755278982137,
#  'conductor': 4.3428059215206005,
#  'committe': 6.907755278982137,
#  'telemetri': 5.521460917862246,
#  'fourier': 5.809142990314028,
#  'amper': 6.907755278982137,
#  'quantum': 5.115995809754082,
#  'rim': 6.907755278982137,
#  'voltag': 2.796881414808826,
#  'gyrofrequ': 6.907755278982137,
#  'bridg': 4.8283137373023015,
#  'locu': 6.214608098422191,
#  'vacua': 6.907755278982137,
#  'ettingshausen': 6.907755278982137,
#  'progress': 6.214608098422191,
#  'cell': 4.710530701645918,
#  'heater': 6.214608098422191,
#  'wall': 5.521460917862246,
#  'fall': -2.1967244522945375,
#  'matter': 5.809142990314028,
#  'dispers': 4.961845129926823,
#  'oil': 6.907755278982137,
#  'distribut': 2.864704011147587,
#  'defin': 4.3428059215206005,
#  'incid': -2.195723451209952,
#  'commerci': 5.298317366548036,
#  'chebyshev': 6.907755278982137,
#  'gallet': 6.907755278982137,
#  'nonmagnet': 5.809142990314028,
#  'analogu': 4.199705077879927,
#  'correct': 4.509860006183766,
#  'passiv': 4.961845129926823,
#  'strictiv': 6.907755278982137,
#  'vice': 6.907755278982137,
#  'broad': 6.214608098422191,
#  'dq': 6.907755278982137,
#  'transient': 4.268697949366879,
#  'doubler': 6.907755278982137,
#  'stochast': 6.907755278982137,
#  'varenna': 6.907755278982137,
#  'w': 6.214608098422191,
#  'uppsala': 6.907755278982137,
#  'materi': -2.9952321485123092,
#  'simul': 5.298317366548036,
#  'recept': 5.809142990314028,
#  'implic': 5.809142990314028,
#  'exhaust': 6.907755278982137,
#  'everi': 6.214608098422191,
#  'convey': 6.907755278982137,
#  'moon': 4.961845129926823,
#  'semifinit': 6.907755278982137,
#  'vz': 6.907755278982137,
#  'royal': 5.809142990314028,
#  'abridg': 6.907755278982137,
#  'chiefli': 6.907755278982137,
#  'separ': 4.017383521085972,
#  'microstrip': 6.907755278982137,
#  'bandwidth': 4.017383521085972,
#  'held': 5.115995809754082,
#  'vanguard': 6.214608098422191,
#  'highfrequ': 6.907755278982137,
#  'season': 5.115995809754082,
#  'motor': 6.214608098422191,
#  'dri': 6.214608098422191,
#  'ew': 6.907755278982137,
#  'media': 5.115995809754082,
#  'singli': 6.907755278982137,
#  'known': 4.509860006183766,
#  'revis': 5.521460917862246,
#  'insert': 4.710530701645918,
#  'exactli': 5.521460917862246,
#  'geoelectr': 6.907755278982137,
#  'dispersionless': 6.907755278982137,
#  'multiphas': 6.907755278982137,
#  'ferromagnet': 4.509860006183766,
#  'summer': 4.961845129926823,
#  'howev': 6.907755278982137,
#  'local': 5.809142990314028,
#  'lens': 5.809142990314028,
#  'ad': 4.710530701645918,
#  'step': 4.605170185988092,
#  'maxim': 6.907755278982137,
#  'stop': 6.907755278982137,
#  'protect': 6.214608098422191,
#  'chain': 6.907755278982137,
#  'cassiopeia': 6.214608098422191,
#  'like': -1.3857942360782092,
#  'transduc': 5.809142990314028,
#  'review': 3.8632328412587142,
#  'counter': 4.268697949366879,
#  'consequ': 4.710530701645918,
#  'su': 6.907755278982137,
#  'unlik': 6.907755278982137,
#  'partit': 6.907755278982137,
#  'approxim': 3.611918412977808,
#  'cost': 5.809142990314028,
#  'kelman': 6.907755278982137,
#  'db': 5.809142990314028,
#  'moment': 5.809142990314028,
#  'interest': 6.907755278982137,
#  'estim': 4.135166556742356,
#  'magnetogalvan': 6.907755278982137,
#  'oblat': 6.214608098422191,
#  'month': 5.521460917862246,
#  'green': 6.907755278982137,
#  'lrc': 6.907755278982137,
#  'multipli': 4.509860006183766,
#  'fit': 5.298317366548036,
#  'well': 4.509860006183766,
#  'superposit': 6.214608098422191,
#  'transmiss': 4.135166556742356,
#  'modulu': 6.907755278982137,
#  'isoclin': 6.907755278982137,
#  'record': 3.123565645063876,
#  'match': 4.961845129926823,
#  'classic': -1.791259344186373,
#  'consum': 6.907755278982137,
#  'april': 4.961845129926823,
#  'rf': 4.605170185988092,
#  'fornax': 6.907755278982137,
#  'tham': 0.0005001250416816205,
#  'balloon': 5.809142990314028,
#  'simplifi': 4.8283137373023015,
#  'ionosond': 6.214608098422191,
#  'germagnet': 6.907755278982137,
#  'four': 4.017383521085972,
#  'may': 3.101092789211817,
#  'allow': -2.0789414166381537,
#  'fermat': 6.907755278982137,
#  'strength': -2.9952321485123092,
#  'unsymmetr': 6.214608098422191,
#  'freedom': 6.214608098422191,
#  'emf': 6.214608098422191,
#  'argu': 6.214608098422191,
#  'whistler': 5.115995809754082,
#  'behaviour': 4.509860006183766,
#  'aerolen': 6.907755278982137,
#  'background': 5.521460917862246,
#  'magnetoresist': 6.907755278982137,
#  'foil': 6.214608098422191,
#  'hawaii': 6.907755278982137,
#  'slough': 5.521460917862246,
#  'assumpt': 4.8283137373023015,
#  'digit': 4.017383521085972,
#  'midnight': 5.809142990314028,
#  'hall': 5.115995809754082,
#  'micrometeorit': 6.907755278982137,
#  'orthogon': 6.907755278982137,
#  'quench': 6.907755278982137,
#  'aluminum': 6.907755278982137,
#  'mark': 4.961845129926823,
#  'principl': 4.199705077879927,
#  'waveform': 4.268697949366879,
#  'introduc': 4.8283137373023015,
#  'alfven': 6.907755278982137,
#  'look': 6.907755278982137,
#  'thread': 6.907755278982137,
#  'tape': 5.115995809754082,
#  'suitabl': 4.017383521085972,
#  'elsewher': 6.907755278982137,
#  'develop': 3.123565645063876,
#  'dope': 6.214608098422191,
#  'read': 4.710530701645918,
#  'jancel': 6.907755278982137,
#  'leakag': 6.907755278982137,
#  'cathod': -1.870301050775324,
#  'hartre': 5.521460917862246,
#  'inher': 5.115995809754082,
#  'explain': 4.268697949366879,
#  'permitt': 5.809142990314028,
#  'criteria': 6.907755278982137,
#  'manual': 6.907755278982137,
#  'also': -4.0068330601907896,
#  'field': -4.188153615900158,
#  'coron': 6.214608098422191,
#  'photon': 6.214608098422191,
#  'dimension': 4.422848629194137,
#  'feedback': 3.411247717515657,
#  'precess': 6.214608098422191,
#  'ford': 6.907755278982137,
#  'term': 3.473768074496991,
#  'rlc': 5.298317366548036,
#  'telescop': 4.8283137373023015,
#  'hammond': 6.907755278982137,
#  'selenid': 6.907755278982137,
#  'board': 6.907755278982137,
#  'interlink': 6.907755278982137,
#  'deposit': 5.521460917862246,
#  'unattend': 6.907755278982137,
#  'reduc': 3.912023005428146,
#  'attract': 6.214608098422191,
#  'northern': 5.115995809754082,
#  'collision': 6.907755278982137,
#  'fredholm': 6.214608098422191,
#  'nh': 5.521460917862246,
#  'prevail': 6.214608098422191,
#  'machineri': 6.907755278982137,
#  'tchebycheff': 5.809142990314028,
#  'texa': 6.907755278982137,
#  'log': 6.907755278982137,
#  'class': 4.605170185988092,
#  'port': 5.809142990314028,
#  'l': 6.214608098422191,
#  'fatigu': 6.907755278982137,
#  'pin': 6.214608098422191,
#  'length': -2.5644492324198547,
#  'mismatch': 6.214608098422191,
#  'mount': 5.809142990314028,
#  'scherhag': 6.907755278982137,
#  'column': 5.521460917862246,
#  'nernst': 6.907755278982137,
#  'low': -4.262179751999634,
#  'persistatron': 6.907755278982137,
#  'crittenden': 6.907755278982137,
#  'kaufman': 6.907755278982137,
#  'bulk': 6.907755278982137,
#  'declin': 6.214608098422191,
#  'rigor': 6.214608098422191,
#  'adjust': 5.115995809754082,
#  'drift': 4.135166556742356,
#  'induc': 5.298317366548036,
#  'maximum': 2.900422093749666,
#  'fix': 5.521460917862246,
#  'dynam': 4.605170185988092,
#  'drastic': 6.907755278982137,
#  'constant': -3.1775537053062637,
#  'partli': 6.907755278982137,
#  'th': 5.521460917862246,
#  'imag': 4.8283137373023015,
#  'differenti': 4.135166556742356,
#  'character': 5.521460917862246,
#  'futur': 6.214608098422191,
#  'solv': 4.074541934925921,
#  'advers': 6.907755278982137,
#  'difficulti': 5.809142990314028,
#  'attribut': 5.298317366548036,
#  'constitut': 5.521460917862246,
#  'cs': 6.214608098422191,
#  'convent': -2.0789414166381537,
#  'proceed': 5.809142990314028,
#  'break': 6.214608098422191,
#  'parallel': -3.2575964129798,
#  'want': 6.907755278982137,
#  'dissymmetr': 6.907755278982137,
#  'discuss': 2.111964733385396,
#  'attain': 6.214608098422191,
#  'ihi': 6.907755278982137,
#  'gain': 3.575550768806933,
#  'sunset': 6.907755278982137,
#  'final': 5.115995809754082,
#  'tustin': 6.907755278982137,
#  'flight': 5.115995809754082,
#  'permeabl': 6.214608098422191,
#  'better': 4.961845129926823,
#  'identif': 6.214608098422191,
#  'excit': 4.135166556742356,
#  'done': 6.907755278982137,
#  'pursu': 6.907755278982137,
#  'photograph': 5.809142990314028,
#  'ambient': 6.907755278982137,
#  'june': 5.115995809754082,
#  'colpitt': 5.809142990314028,
#  'lerwick': 6.907755278982137,
#  'plasma': 3.2968373663379125,
#  'max': 6.907755278982137,
#  'man': 6.907755278982137,
#  'hysteresi': 4.961845129926823,
#  'manufactur': 6.214608098422191,
#  'array': 5.809142990314028,
#  'gd': 6.907755278982137,
#  'kc': 6.907755278982137,
#  'scatter': -3.1775537053062637,
#  'millimet': 6.907755278982137,
#  'birefring': 6.907755278982137,
#  'pyrolysi': 6.907755278982137,
#  'ma': 6.907755278982137,
#  'pr': 6.214608098422191,
#  'potentiomet': 6.907755278982137,
#  'corona': 5.115995809754082,
#  'reactiv': 6.907755278982137,
#  'neighbour': 6.907755278982137,
#  'sputter': 6.907755278982137,
#  'sace': 0.0005001250416816205,
#  'best': 5.521460917862246,
#  'central': 6.214608098422191,
#  'version': 5.809142990314028,
#  'appar': 5.521460917862246,
#  'speed': 3.912023005428146,
#  'diad': 6.907755278982137,
#  'primarili': 5.809142990314028,
#  'attach': 5.115995809754082,
#  'visual': 4.710530701645918,
#  'dissip': 5.521460917862246,
#  'termin': 4.509860006183766,
#  'provid': 3.7722610630529876,
#  'alway': 6.214608098422191,
#  'sunlit': 6.214608098422191,
#  'interferomet': 5.115995809754082,
#  'mu': 6.214608098422191,
#  'cullington': 6.907755278982137,
#  'aber': 6.907755278982137,
#  'deton': 6.907755278982137,
#  'depth': 6.907755278982137,
#  'stabil': 3.123565645063876,
#  'iron': 5.298317366548036,
#  'anomal': 5.809142990314028,
#  'nose': 6.907755278982137,
#  'unexpectedli': 6.907755278982137,
#  'evalu': 4.422848629194137,
#  'perpendicular': 5.521460917862246,
#  'cro': 6.214608098422191,
#  'thoma': 6.907755278982137,
#  'dipol': 4.605170185988092,
#  'wheatston': 6.907755278982137,
#  'poisson': 6.907755278982137,
#  'imperfect': 6.214608098422191,
#  'island': 5.521460917862246,
#  'reconcil': 0.0005001250416816205,
#  'sic': 6.907755278982137,
#  'probabl': 4.135166556742356,
#  'binder': 6.907755278982137,
#  'antiferroelectr': 6.907755278982137,
#  'shifter': 5.809142990314028,
#  'ellipsoid': 5.809142990314028,
#  'usual': 5.115995809754082,
#  'charact': 5.809142990314028,
#  'system': 2.513306124309698,
#  'societi': 6.214608098422191,
#  'boulder': 6.907755278982137,
#  'acceler': 5.298317366548036,
#  'aris': 5.521460917862246,
#  'circuit': 1.748699979767608,
#  'regul': 4.710530701645918,
#  'gamma': 6.907755278982137,
#  'abstract': 5.298317366548036,
#  'beat': 6.907755278982137,
#  'autodyn': 6.907755278982137,
#  'extend': 3.912023005428146,
#  'theori': -3.346397947945317,
#  'algorithm': 6.907755278982137,
#  'toward': 6.214608098422191,
#  'collector': 4.961845129926823,
#  'sleev': 6.907755278982137,
#  'coast': 6.214608098422191,
#  'geiger': 6.214608098422191,
#  'hamiltonian': 6.907755278982137,
#  'block': 5.809142990314028,
#  'profil': 5.809142990314028,
#  'effect': -3.987482920438007,
#  'dawn': 6.907755278982137,
#  'linear': 3.3524072174927233,
#  'format': 5.521460917862246,
#  'obviou': 6.907755278982137,
#  'kerr': 6.907755278982137,
#  'twr': 6.907755278982137,
#  'af': 5.298317366548036,
#  'univers': 5.521460917862246,
#  'encod': 6.907755278982137,
#  'ritz': 6.907755278982137,
#  'nocturn': 5.809142990314028,
#  'thermo': 6.214608098422191,
#  'except': 5.809142990314028,
#  'order': -3.1775537053062637,
#  'around': 5.809142990314028,
#  'unipolar': 6.907755278982137,
#  'nation': 5.809142990314028,
#  'resolv': -1.3857942360782092,
#  'intermedi': 5.521460917862246,
#  'morpholog': 6.907755278982137,
#  'gate': 5.115995809754082,
#  'nonterrestri': 6.907755278982137,
#  'pa': 6.907755278982137,
#  'clear': 5.521460917862246,
#  'lyman': 6.214608098422191,
#  'powder': 6.214608098422191,
#  'explicit': 5.521460917862246,
#  'lowest': 5.298317366548036,
#  'util': 6.214608098422191,
#  'modifi': 5.115995809754082,
#  'agre': 4.605170185988092,
#  'absolut': 6.214608098422191,
#  'k': 5.809142990314028,
#  'aid': 5.298317366548036,
#  'close': 4.422848629194137,
#  'heavier': 0.0005001250416816205,
#  'interrupt': 6.907755278982137,
#  'moist': 6.907755278982137,
#  'engrav': 6.907755278982137,
#  'vari': 3.816712825623821,
#  'especi': 6.907755278982137,
#  'microphon': 6.214608098422191,
#  'reciproc': 6.907755278982137,
#  'insul': 5.809142990314028,
#  'thd': 6.907755278982137,
#  'comprehens': 6.907755278982137,
#  'sm': 6.907755278982137,
#  'rule': 5.809142990314028,
#  'micropuls': 6.214608098422191,
#  'greatest': 6.907755278982137,
#  'higher': -2.4844065247463183,
#  'start': 5.521460917862246,
#  'snell': 6.907755278982137,
#  'bureau': 6.907755278982137,
#  'aachen': 6.907755278982137,
#  'born': 5.521460917862246,
#  'rel': 4.074541934925921,
#  'ammonia': 6.214608098422191,
#  'planar': 5.809142990314028,
#  'spectromet': 5.809142990314028,
#  'accumul': 6.214608098422191,
#  'dissector': 6.907755278982137,
#  'axi': 4.8283137373023015,
#  'teflon': 6.907755278982137,
#  'applic': 2.631089159966082,
#  'morn': 6.907755278982137,
#  'fifti': 6.907755278982137,
#  'muf': 6.907755278982137,
#  'nitrogen': 6.214608098422191,
#  'annular': 6.907755278982137,
#  'affect': 6.214608098422191,
#  'cw': 6.214608098422191,
#  'art': 6.907755278982137,
#  'specular': 6.907755278982137,
#  'actual': 5.521460917862246,
#  'area': 5.115995809754082,
#  'phase': 3.0159349808715104,
#  'summat': 6.907755278982137,
#  'plate': 4.710530701645918,
#  'isopor': 6.907755278982137,
#  'langmuir': 6.214608098422191,
#  'horizont': 4.961845129926823,
#  'concern': 5.521460917862246,
#  'ga': -3.5830188134144283,
#  'true': 5.809142990314028,
#  'nonenerg': 6.907755278982137,
#  'factor': 4.074541934925921,
#  'avail': 5.115995809754082,
#  'instal': 6.907755278982137,
#  'twin': 6.907755278982137,
#  'molecul': 5.115995809754082,
#  'weber': 6.907755278982137,
#  'ramp': 6.907755278982137,
#  'vibrat': 5.521460917862246,
#  'nine': 5.521460917862246,
#  'loss': 3.649658740960655,
#  'core': 4.017383521085972,
#  ...}

# %% [markdown]
# getting total doc rsv score

# %%
#calculates the rsv of a document based on the query provided
def generate_doc_rsv(file_name, query):
    result = 0
    doc_list = data[data["file_name"] == file_name]["text"]
    for doc in doc_list:
        for word in doc:
            if word in query:
                result += weights[word]
    return result

# %% [markdown]
# rank docs by query provided

# %%
#retreive all docs containing our word
#get the rsv score of the retrieved docs
def rank_docs(query):
    results = {
        'file_name': [],
        'score': []
    }
    docs = list()
    for word in query:
        docs = [*docs, *list(word_dict[word])]
    for file_name in docs:
        results['file_name'].append(file_name)
        results['score'].append(generate_doc_rsv(file_name, query))
    results = pd.DataFrame(results).sort_values('score', ascending=False)
    return results

# %% [markdown]
# # search results/ prediction

# %%
#preprocess the query first then rank
def search_query(search_query, retrieved_docs = 10):
    #tokenize query
    query = list(tokenize([search_query]))[0]
    #lower case
    query = [txt.lower() for txt in query]
    #stop words
    query = [txt for txt in query if not txt in stop_words]
    #stemming
    query = [porter_stemmer.stem(txt) for txt in query]
    return rank_docs(query).head(retrieved_docs)

# %% [markdown]
# get the query

# %% [markdown]
# get first top 10 results

# %%
result = search_query("calculator", 10)
result
# Out:
#      file_name     score
# 0    file_6179 -4.330233
# 37   file_3419 -4.330233
# 55   file_2249 -4.330233
# 54   file_4345 -4.330233
# 53  file_10380 -4.330233
# 52   file_6115 -4.330233
# 51   file_8874 -4.330233
# 50   file_9782 -4.330233
# 49   file_8943 -4.330233
# 47   file_7867 -4.330233
