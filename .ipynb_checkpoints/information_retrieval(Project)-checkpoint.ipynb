# %% [markdown]
# # importing libaries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from collections import defaultdict
from pathlib import Path
from nltk.tokenize import word_tokenize
from nltk.tokenize import RegexpTokenizer
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
import math

# %% [markdown]
# # **loading dataset**

# %%
# param limiter => used to control number of training docs being loaded because of memory overload
limiter = 1000
def load_dataset():
    results = defaultdict(list)
    path = "HW04/documents"
    i = 0
    for file in Path(path).iterdir():
        if i < limiter:       
            with open(file, "r") as file_open:
                results["file_name"].append(file.name)
                results["text"].append(file_open.read())
            i = i+1

    return pd.DataFrame(results)

# %%
data = load_dataset()

# %%
#removing .txt extension
data['file_name'] = data['file_name'].apply(lambda name: name.split(".")[0])

# %%
data.shape
# Out:
# (1000, 2)

# %%
data.head()
# Out:
#     file_name                                               text
# 0      file_1  compact memories have flexible capacities  a d...
# 1     file_10  highspeed microwave switching of semiconductor...
# 2    file_100  satellite observations of electrons artificial...
# 3   file_1000  the eta carinae nebula and centaurus a near mc...
# 4  file_10000  notes on the sunspot cycle  analysis of a long...

# %%
path1 = "C:/Users/Anonymous_King/Downloads/binary-independence-model-main/binary-independence-model-main/model/HW04/file_label.txt"
labels = pd.read_csv(path1, names=["file_name", "label"], sep=",", header=None)
labels.head()
# Out:
#   file_name  label
# 0    file_0      0
# 1    file_1      0
# 2    file_2      0
# 3    file_3      0
# 4    file_4      0

# %%
#removing nulls
labels["label"].fillna(0, inplace=True)
labels["label"] = labels["label"].apply(lambda label: label if label != None else 0)
#concat labels to the documents dataframe
labels = labels.reindex(index=labels.index[::-1])

# %%
labels.head()
# Out:
#         file_name  label
# 11428  file_11428      0
# 11427  file_11427      0
# 11426  file_11426      0
# 11425  file_11425      0
# 11424  file_11424      0

# %%
# labels["label"][:limiter]
# data["labels"] = labels["label"][:limiter]
data["labels"] = ""
i = 1
for file_name in data["file_name"]:
  index = data[data["file_name"] == file_name].index.values[0]
  label = labels[labels["file_name"] == file_name]["label"]
  data["labels"][index] = label.values[0] if len(label) > 0 else 0
  # print(data["labels"][data.iloc[data["file_name"] == file_name].index])
# data["labels"] = labels["label"][:limiter]
data.head()
# Out:
#     file_name                                               text labels
# 0      file_1  compact memories have flexible capacities  a d...      0
# 1     file_10  highspeed microwave switching of semiconductor...      0
# 2    file_100  satellite observations of electrons artificial...      0
# 3   file_1000  the eta carinae nebula and centaurus a near mc...      0
# 4  file_10000  notes on the sunspot cycle  analysis of a long...      0

# %% [markdown]
# configs
#
# *   only necessary in google colab

# %%
import nltk
nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Anonymous_King\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Anonymous_King\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %% [markdown]
# tokenization

# %%
def tokenize(word_list):
    tokenized_text = []
    for text in word_list:
        tokenized_text.append(word_tokenize(text))
    return tokenized_text
data["text"] = list(tokenize(data["text"]))

# %%
data.head()
# Out:
#     file_name                                               text labels
# 0      file_1  [compact, memories, have, flexible, capacities...      0
# 1     file_10  [highspeed, microwave, switching, of, semicond...      0
# 2    file_100  [satellite, observations, of, electrons, artif...      0
# 3   file_1000  [the, eta, carinae, nebula, and, centaurus, a,...      0
# 4  file_10000  [notes, on, the, sunspot, cycle, analysis, of,...      0

# %% [markdown]
# change case to lower case

# %%
data['text'] = data['text'].apply(lambda list: [txt.lower() for txt in list])
data.head()
# Out:
#     file_name                                               text labels
# 0      file_1  [compact, memories, have, flexible, capacities...      0
# 1     file_10  [highspeed, microwave, switching, of, semicond...      0
# 2    file_100  [satellite, observations, of, electrons, artif...      0
# 3   file_1000  [the, eta, carinae, nebula, and, centaurus, a,...      0
# 4  file_10000  [notes, on, the, sunspot, cycle, analysis, of,...      0

# %% [markdown]
# stop word removal

# %%
stop_words = set(stopwords.words('english'))
data['text'] = data['text'].apply(lambda list: [txt for txt in list if not txt in stop_words])
data.head()
# Out:
#     file_name                                               text labels
# 0      file_1  [compact, memories, flexible, capacities, digi...      0
# 1     file_10  [highspeed, microwave, switching, semiconducto...      0
# 2    file_100  [satellite, observations, electrons, artificia...      0
# 3   file_1000  [eta, carinae, nebula, centaurus, near, mc, pa...      0
# 4  file_10000  [notes, sunspot, cycle, analysis, long, series...      0

# %% [markdown]
# stemming

# %%
porter_stemmer = PorterStemmer()
data['text'] = data['text'].apply(lambda list: [porter_stemmer.stem(txt) for txt in list])
data.head()
# Out:
#     file_name                                               text labels
# 0      file_1  [compact, memori, flexibl, capac, digit, data,...      0
# 1     file_10   [highspe, microwav, switch, semiconductor, part]      0
# 2    file_100  [satellit, observ, electron, artifici, inject,...      0
# 3   file_1000  [eta, carina, nebula, centauru, near, mc, part...      0
# 4  file_10000  [note, sunspot, cycl, analysi, long, seri, sun...      0

# %% [markdown]
# ### **generating an inverted index of terms**
# here we are going to create a dictionary with all words as keys and the values are the doc file names containing the word
# *   *NOTE: The get_inverted_index function is memory and cpu intensive so it may take some time*

# %%
#first we get all words
wordlist = [txt for list in data['text'] for txt in list]
#get only unique values using set
wordlist = set(wordlist)
wordlist = list(wordlist)
wordlist
# Out:
# ['viewpoint',
#  'germanium',
#  'month',
#  'hercul',
#  'binari',
#  'dsb',
#  'nerv',
#  'nikecajun',
#  'principl',
#  'isoin',
#  'concurr',
#  'underli',
#  'gate',
#  'crystallin',
#  'fail',
#  'parabol',
#  'spread',
#  'recov',
#  'cyrat',
#  'control',
#  'place',
#  'tightli',
#  'longitudin',
#  'meteor',
#  'bandwidth',
#  'apart',
#  'et',
#  'nonessenti',
#  'aid',
#  'quit',
#  'receiv',
#  'ovr',
#  'wiener',
#  'input',
#  'correspond',
#  'filter',
#  'tali',
#  'kaenel',
#  'telescop',
#  'four',
#  'absorb',
#  'rapidli',
#  'disk',
#  'rf',
#  'scan',
#  'lake',
#  'februari',
#  'infrar',
#  'horizon',
#  'thermal',
#  'appear',
#  'divers',
#  'unconvent',
#  'immers',
#  'sharpli',
#  'finit',
#  'paraboloid',
#  'result',
#  'fourth',
#  'action',
#  'toward',
#  'equilibrium',
#  'valu',
#  'carbon',
#  'argu',
#  'collis',
#  'microelectron',
#  'bilater',
#  'flux',
#  'squar',
#  'stress',
#  'creas',
#  'relat',
#  'leakag',
#  'extraordinari',
#  'resistor',
#  'experiment',
#  'due',
#  'set',
#  'breadth',
#  'anisotropi',
#  'ambipolar',
#  'impact',
#  'hydromagnet',
#  'onward',
#  'quinari',
#  'kc',
#  'clear',
#  'leav',
#  'pulsat',
#  'account',
#  'chapman',
#  'understand',
#  'lati',
#  'daytim',
#  'depth',
#  'stagger',
#  'mask',
#  'televis',
#  'handl',
#  'interior',
#  'exercis',
#  'magnon',
#  'serv',
#  'intersect',
#  'enhanc',
#  'isl',
#  'hazard',
#  'waltair',
#  'solenoid',
#  'manner',
#  'ge',
#  'comprehens',
#  'aerodynam',
#  'main',
#  'amplitud',
#  'cyclic',
#  'subsequ',
#  'symmetri',
#  'nose',
#  'forc',
#  'connect',
#  'open',
#  'one',
#  'nuvistor',
#  'len',
#  'quarter',
#  'million',
#  'increas',
#  'helic',
#  'rotat',
#  'suf',
#  'captur',
#  'eleven',
#  'histori',
#  'found',
#  'easili',
#  'low',
#  'pressur',
#  'bistat',
#  'emerg',
#  'hop',
#  'aboard',
#  'new',
#  'function',
#  'appleton',
#  'circumst',
#  'submultipl',
#  'matric',
#  'ray',
#  'emf',
#  'adder',
#  'astronom',
#  'ez',
#  'helium',
#  'drop',
#  'radiu',
#  'christchurch',
#  'raman',
#  'locu',
#  'suggest',
#  'interact',
#  'boron',
#  'distortionless',
#  'meteoroid',
#  'theoret',
#  'anod',
#  'height',
#  'stl',
#  'shadow',
#  'calculu',
#  'pulkov',
#  'rectif',
#  'shift',
#  'head',
#  'increasingli',
#  'collector',
#  'order',
#  'flip',
#  'recommend',
#  'maxwellian',
#  'uhf',
#  'orthonorm',
#  'trend',
#  'sq',
#  'topsid',
#  'hillhead',
#  'overhead',
#  'consist',
#  'scalar',
#  'east',
#  'compat',
#  'recent',
#  'mode',
#  'photoion',
#  'f',
#  'ramp',
#  'latitudin',
#  'satisfi',
#  'orthogon',
#  'flare',
#  'lien',
#  'illumin',
#  'rarefi',
#  'laplac',
#  'memori',
#  'van',
#  'data',
#  'excess',
#  'skylark',
#  'frame',
#  'baov',
#  'mainli',
#  'exospher',
#  'dielectr',
#  'hm',
#  'nuclear',
#  'uptap',
#  'hypothes',
#  'wafer',
#  'invok',
#  'lattic',
#  'ba',
#  'knowledg',
#  'interv',
#  'fast',
#  'planar',
#  'nocturn',
#  'band',
#  'januari',
#  'imped',
#  'stuggart',
#  'vane',
#  'rarifi',
#  'contactless',
#  'extent',
#  'powder',
#  'oscillographi',
#  'ith',
#  'scheme',
#  'correct',
#  'diamet',
#  'thermon',
#  'tiro',
#  'differenti',
#  'lossless',
#  'decreas',
#  'bodi',
#  'lead',
#  'german',
#  'nyquist',
#  'mm',
#  'ferrit',
#  'scintil',
#  'disintegr',
#  'withstandard',
#  'mani',
#  'hyperfin',
#  'steerabl',
#  'ration',
#  'intermediari',
#  'season',
#  'definit',
#  'therefor',
#  'invari',
#  'elast',
#  'cryosistor',
#  'redfield',
#  'topolog',
#  'broadsid',
#  'monthli',
#  'terr',
#  'compar',
#  'effect',
#  'flayer',
#  'el',
#  'nonadiabat',
#  'consid',
#  'budden',
#  'microcircuit',
#  'post',
#  'highest',
#  'luminos',
#  'media',
#  'bit',
#  'watson',
#  'fabri',
#  'twoer',
#  'sky',
#  'metr',
#  'grade',
#  'phonon',
#  'analogu',
#  'enabl',
#  'five',
#  'heavi',
#  'favour',
#  'layeri',
#  'transvers',
#  'neglig',
#  'formula',
#  'distort',
#  'introduc',
#  'centr',
#  'overal',
#  'equat',
#  'dynamo',
#  'full',
#  'novel',
#  'almost',
#  'precis',
#  'distribut',
#  'flexibl',
#  'read',
#  'perpendicularli',
#  'express',
#  'caribbean',
#  'stormi',
#  'extragalact',
#  'weather',
#  'swing',
#  'clock',
#  'probabl',
#  'unoccupi',
#  'bidirect',
#  'round',
#  'coerciv',
#  'explain',
#  'shell',
#  'arriv',
#  'suppli',
#  'procedur',
#  'bifurc',
#  'detect',
#  'pen',
#  'royal',
#  'width',
#  'sampl',
#  'arrang',
#  'juli',
#  'ranger',
#  'min',
#  'analys',
#  'demonstr',
#  'half',
#  'absolut',
#  'parametr',
#  'numer',
#  'sept',
#  'lump',
#  'trace',
#  'nice',
#  'vavilov',
#  'val',
#  'stratif',
#  'instal',
#  'throughout',
#  'neutral',
#  'kato',
#  'kind',
#  'rol',
#  'motor',
#  'crane',
#  'notat',
#  'incoher',
#  'deton',
#  'telecommun',
#  'specular',
#  'alfven',
#  'unwant',
#  'partial',
#  'tail',
#  'harmon',
#  'perige',
#  'emiss',
#  'briefli',
#  'synthes',
#  'transreson',
#  'util',
#  'faraday',
#  'inject',
#  'ring',
#  'second',
#  'properti',
#  'although',
#  'pnpn',
#  'intrins',
#  'tidal',
#  'couett',
#  'incid',
#  'meteorolog',
#  'hree',
#  'turn',
#  'tunnel',
#  'well',
#  'plot',
#  'sputter',
#  'banalor',
#  'ottawa',
#  'advanc',
#  'novemb',
#  'predetermin',
#  'spheric',
#  'highspe',
#  'washington',
#  'intens',
#  'rico',
#  'adopt',
#  'intermodul',
#  'oy',
#  'airglow',
#  'character',
#  'orient',
#  'fabric',
#  'irrevers',
#  'factor',
#  'quartz',
#  'cauer',
#  'cylind',
#  'precess',
#  'hundr',
#  'imbed',
#  'astrophys',
#  'futur',
#  'ionospher',
#  'afbmd',
#  'veroniqu',
#  'want',
#  'doubl',
#  'rod',
#  'specif',
#  'assess',
#  'multicav',
#  'releas',
#  'transistor',
#  'mobil',
#  'take',
#  'millston',
#  'helix',
#  'x',
#  'spatial',
#  'branch',
#  'fictiti',
#  'gradient',
#  'lie',
#  'minut',
#  'view',
#  'filamentari',
#  'stoke',
#  'sm',
#  'held',
#  'refer',
#  'caesium',
#  'subcarri',
#  'lightn',
#  'sunspot',
#  'disadvantag',
#  'henc',
#  'explos',
#  'variabl',
#  'electroacoust',
#  'loss',
#  'recurr',
#  'interplanetari',
#  'test',
#  'difficulti',
#  'suppress',
#  'per',
#  'usabl',
#  'goldstein',
#  'ahmedabad',
#  'photo',
#  'averag',
#  'magic',
#  'regularli',
#  'circuit',
#  'turbul',
#  'insuffici',
#  'zero',
#  'logarithm',
#  'ral',
#  'restrict',
#  'defect',
#  'thick',
#  'ammonia',
#  'light',
#  'circular',
#  'invers',
#  'expon',
#  'photoexcit',
#  'rise',
#  'holt',
#  'florenc',
#  'north',
#  'es',
#  'role',
#  'impli',
#  'photomultipli',
#  'storag',
#  'feed',
#  'occas',
#  'polar',
#  'slight',
#  'mixtur',
#  'bloch',
#  'especi',
#  'univers',
#  'rate',
#  'sec',
#  'rule',
#  'interpret',
#  'isobar',
#  'qualit',
#  'transform',
#  'calcul',
#  'index',
#  'algebra',
#  'schedul',
#  'shape',
#  'extract',
#  'k',
#  'made',
#  'discuss',
#  'jacobi',
#  'respons',
#  'theorem',
#  'time',
#  'converg',
#  'microwav',
#  'dust',
#  'puk',
#  'mill',
#  'swept',
#  'multivibr',
#  'magnetomet',
#  'root',
#  'circul',
#  'tabul',
#  'symbol',
#  'unequ',
#  'leopoldvil',
#  'angular',
#  'kent',
#  'l',
#  'coaxial',
#  'hf',
#  'quick',
#  'slough',
#  'suitabl',
#  'circl',
#  'penetr',
#  'avoid',
#  'durban',
#  'coil',
#  'medium',
#  'optron',
#  'telegraph',
#  'unilater',
#  'balanc',
#  'corbino',
#  'vol',
#  'outlin',
#  'proton',
#  'gain',
#  'constanc',
#  'intend',
#  'complex',
#  'occur',
#  'shoran',
#  'milki',
#  'conveni',
#  'cross',
#  'wideband',
#  'identif',
#  'vertex',
#  'vicin',
#  'diod',
#  'galvanomagnet',
#  'unreli',
#  'passiv',
#  'piezoelectr',
#  'creation',
#  'declin',
#  'great',
#  'output',
#  'radii',
#  'commenc',
#  'microsecond',
#  'repeat',
#  'inner',
#  'nitrogen',
#  'possess',
#  'recognit',
#  'bottleneck',
#  'pattern',
#  'interstellar',
#  'bay',
#  'sun',
#  'titan',
#  'seniti',
#  'reappear',
#  'profil',
#  'radiomet',
#  'push',
#  'meter',
#  'emphasi',
#  'evalu',
#  'magnitud',
#  'region',
#  'neutron',
#  'servo',
#  'portabl',
#  'fox',
#  'narrow',
#  'institut',
#  'maxima',
#  'self',
#  'examin',
#  'repres',
#  'meteorit',
#  'nearli',
#  'ultraviolet',
#  'octob',
#  'constant',
#  'perhap',
#  'write',
#  'itali',
#  'elong',
#  'trajectori',
#  'behaviour',
#  'solut',
#  'cosmic',
#  'ordinari',
#  'necessit',
#  'whether',
#  'unsatisfactori',
#  'site',
#  'butterworth',
#  'ai',
#  'third',
#  'observ',
#  'could',
#  'detector',
#  'summari',
#  'loop',
#  'magnetograph',
#  'still',
#  'distinct',
#  'eras',
#  'adeli',
#  'occult',
#  'twenti',
#  'beat',
#  'sw',
#  'scout',
#  'achiev',
#  'wedg',
#  'masur',
#  'whitfield',
#  'varianc',
#  'soviet',
#  'summer',
#  'cylindr',
#  'sphere',
#  'elementari',
#  'within',
#  'radial',
#  'kilocycl',
#  'cheap',
#  'dipol',
#  'pioneer',
#  'long',
#  'ferroelectr',
#  'uncompens',
#  'april',
#  'abrupt',
#  'six',
#  'scale',
#  'research',
#  'environ',
#  'proport',
#  'hold',
#  'tropospher',
#  'interferomet',
#  'tabular',
#  'translat',
#  'either',
#  'eject',
#  'macquari',
#  'particl',
#  'israel',
#  'constitut',
#  'cool',
#  'print',
#  'local',
#  'taipet',
#  'wherein',
#  'far',
#  'poona',
#  'fourier',
#  'steadi',
#  'ta',
#  'justifi',
#  'cryotron',
#  'descript',
#  'major',
#  'departur',
#  'criteria',
#  'chang',
#  'flat',
#  'slot',
#  'sunris',
#  'servomechan',
#  'number',
#  'charact',
#  'super',
#  'flash',
#  'thunderstorm',
#  'delta',
#  'british',
#  'superconduct',
#  'fine',
#  'duffin',
#  'prototyp',
#  'bohm',
#  'waveform',
#  'geomagnet',
#  'triangl',
#  'act',
#  'would',
#  'cite',
#  'midnight',
#  'cassiopeia',
#  'transport',
#  'lutting',
#  'geograph',
#  'return',
#  'construct',
#  'ascens',
#  'acceler',
#  'propag',
#  'significantli',
#  'nevada',
#  'estim',
#  'jupit',
#  'altern',
#  'moon',
#  'balloon',
#  'convers',
#  'monsoon',
#  'usual',
#  'block',
#  'success',
#  'opaqu',
#  'particularli',
#  'section',
#  'nicolet',
#  'cherenkov',
#  'punch',
#  'liquid',
#  'steep',
#  'neon',
#  'typic',
#  'classifi',
#  'bia',
#  'arbitrarili',
#  'environment',
#  'antenna',
#  'erser',
#  'substitut',
#  'hard',
#  'volum',
#  'confoc',
#  'gyroscop',
#  'middl',
#  'hi',
#  'choic',
#  'load',
#  'satur',
#  'live',
#  'ambient',
#  'signatur',
#  'domain',
#  'space',
#  'note',
#  'fragment',
#  'pump',
#  'atom',
#  'hourli',
#  'least',
#  'multipli',
#  'follow',
#  'outsid',
#  'jacobian',
#  'minimis',
#  'accord',
#  'locat',
#  'tube',
#  'terof',
#  'stronger',
#  'boulder',
#  'depend',
#  'maser',
#  'prepar',
#  'u',
#  'absorpt',
#  'panoram',
#  'nois',
#  'quadripol',
#  'nonlinear',
#  'equival',
#  'nonreciproc',
#  'indic',
#  'paper',
#  'cap',
#  'march',
#  'splot',
#  'kinet',
#  'survey',
#  'servic',
#  'inferior',
#  'differ',
#  'card',
#  'higher',
#  'yield',
#  'ce',
#  'sector',
#  'way',
#  'wina',
#  'fresh',
#  'oscil',
#  'interest',
#  'solv',
#  'gesellschaft',
#  'bessel',
#  'bombard',
#  'mang',
#  'author',
#  'identifi',
#  'import',
#  'wi',
#  'missil',
#  'less',
#  'emerald',
#  'cut',
#  'composit',
#  'expect',
#  'hine',
#  'alloy',
#  'sh',
#  'magneto',
#  'shown',
#  'thu',
#  'upon',
#  'vectori',
#  'emitt',
#  'nearbi',
#  'degre',
#  'spectrum',
#  'portion',
#  'tht',
#  'raptur',
#  'shaper',
#  'year',
#  'spot',
#  'earli',
#  'instantan',
#  'hanicap',
#  'cover',
#  'emit',
#  'shunt',
#  'surg',
#  'spiral',
#  'rc',
#  'skin',
#  'provision',
#  'work',
#  'check',
#  'stray',
#  'constitu',
#  'helliwel',
#  'paramet',
#  'format',
#  'vortic',
#  'gyro',
#  'lifetim',
#  'reactor',
#  'apparatu',
#  'microminiaturizatio',
#  'boltzmann',
#  'wear',
#  'southern',
#  'techniqu',
#  'tip',
#  'wheatston',
#  'recur',
#  'store',
#  'monoton',
#  'direct',
#  'thousand',
#  'discover',
#  'tie',
#  'video',
#  'decad',
#  'nighttim',
#  'simpl',
#  'transduct',
#  'percentag',
#  'quasi',
#  'ballist',
#  'lecher',
#  'overrid',
#  'agre',
#  'mechan',
#  'kw',
#  'present',
#  'si',
#  'step',
#  'coupl',
#  'mixer',
#  'kokobunji',
#  'rubi',
#  'baguio',
#  'appli',
#  'breakdown',
#  'hx',
#  'product',
#  'tent',
#  'much',
#  'failur',
#  'total',
#  'gaseou',
#  'transfer',
#  'true',
#  'stream',
#  'fade',
#  'august',
#  'deviat',
#  'optimum',
#  'date',
#  'interpenetr',
#  'valley',
#  'nonhomogen',
#  'allow',
#  'uniform',
#  'fribourg',
#  'multipact',
#  'northern',
#  'recoveri',
#  'dynam',
#  'satellit',
#  'applic',
#  'packag',
#  'selenium',
#  'reproduc',
#  'reveal',
#  'speci',
#  'repli',
#  'filament',
#  'naval',
#  'wide',
#  'corpuscular',
#  'ascrib',
#  'topic',
#  'permalloy',
#  'superconductor',
#  'ter',
#  'sodium',
#  'boresight',
#  'virtual',
#  'taper',
#  'master',
#  'induct',
#  'beyond',
#  'brown',
#  'linear',
#  'electrostat',
#  'reject',
#  'infin',
#  'obtain',
#  'steer',
#  'temperatur',
#  'capacit',
#  'ocean',
#  'case',
#  'vector',
#  'proceed',
#  'synchron',
#  'stop',
#  'bank',
#  'radic',
#  'perman',
#  'ude',
#  'coverag',
#  'cathod',
#  'later',
#  'radio',
#  'zenith',
#  'sudden',
#  'viscou',
#  ...]

# %%
def get_inverted_index():
    word_dict = defaultdict(set)  
    for i, doc in enumerate(data['text']):
        for word in wordlist:
            if word in doc:
                word_dict[word].add(data.iloc[i, 0])
    return word_dict

word_dict = get_inverted_index()
# word_dict = pd.DataFrame(get_inverted_index())
# word_dict.head()
word_dict
# Out:
# defaultdict(set,
#             {'memori': {'file_1',
#               'file_10157',
#               'file_10471',
#               'file_10474',
#               'file_10615',
#               'file_10736',
#               'file_10737',
#               'file_10873',
#               'file_10876'},
#              'data': {'file_1',
#               'file_10011',
#               'file_10012',
#               'file_10013',
#               'file_10015',
#               'file_10023',
#               'file_10043',
#               'file_1005',
#               'file_1010',
#               'file_1012',
#               'file_10138',
#               'file_10157',
#               'file_10164',
#               'file_10174',
#               'file_1026',
#               'file_10269',
#               'file_10270',
#               'file_10273',
#               'file_1028',
#               'file_10284',
#               'file_10287',
#               'file_10298',
#               'file_10323',
#               'file_10336',
#               'file_1035',
#               'file_1037',
#               'file_10423',
#               'file_10431',
#               'file_10441',
#               'file_10446',
#               'file_10450',
#               'file_10451',
#               'file_10457',
#               'file_10469',
#               'file_1049',
#               'file_10552',
#               'file_10559',
#               'file_10577',
#               'file_10581',
#               'file_10594',
#               'file_10635',
#               'file_10679',
#               'file_10761',
#               'file_10821',
#               'file_10823',
#               'file_10828',
#               'file_10835',
#               'file_10836',
#               'file_10848'},
#              'bit': {'file_1', 'file_10162', 'file_10182', 'file_10474'},
#              'flexibl': {'file_1'},
#              'storag': {'file_1',
#               'file_10021',
#               'file_10023',
#               'file_10046',
#               'file_10157',
#               'file_10158',
#               'file_10186',
#               'file_10470',
#               'file_10471',
#               'file_10472',
#               'file_10474',
#               'file_1055',
#               'file_1056',
#               'file_10614',
#               'file_10615',
#               'file_10875',
#               'file_10876',
#               'file_10877',
#               'file_10891'},
#              'sequenti': {'file_1'},
#              'compact': {'file_1'},
#              'digit': {'file_1',
#               'file_10022',
#               'file_10091',
#               'file_10154',
#               'file_10160',
#               'file_10302',
#               'file_10323',
#               'file_10325',
#               'file_10356',
#               'file_10457',
#               'file_10469',
#               'file_10479',
#               'file_1055',
#               'file_10611',
#               'file_10612',
#               'file_10738',
#               'file_10878'},
#              'system': {'file_1',
#               'file_10021',
#               'file_10058',
#               'file_10070',
#               'file_10087',
#               'file_1010',
#               'file_10116',
#               'file_10157',
#               'file_10161',
#               'file_1018',
#               'file_10183',
#               'file_10186',
#               'file_10231',
#               'file_10237',
#               'file_10251',
#               'file_10252',
#               'file_10259',
#               'file_10277',
#               'file_10278',
#               'file_10315',
#               'file_10326',
#               'file_1033',
#               'file_10346',
#               'file_10365',
#               'file_10390',
#               'file_10409',
#               'file_10428',
#               'file_10447',
#               'file_10457',
#               'file_10463',
#               'file_10472',
#               'file_10480',
#               'file_10483',
#               'file_10484',
#               'file_10485',
#               'file_1049',
#               'file_10493',
#               'file_1050',
#               'file_1051',
#               'file_10511',
#               'file_10554',
#               'file_10578',
#               'file_10604',
#               'file_10611',
#               'file_10615',
#               'file_10630',
#               'file_10632',
#               'file_10647',
#               'file_10659',
#               'file_10672',
#               'file_10683',
#               'file_10708',
#               'file_10719',
#               'file_10738',
#               'file_10739',
#               'file_10748',
#               'file_1076',
#               'file_1077',
#               'file_10775',
#               'file_10805',
#               'file_10808',
#               'file_10832',
#               'file_10837',
#               'file_10849',
#               'file_10875',
#               'file_10880'},
#              'describ': {'file_1',
#               'file_100',
#               'file_10001',
#               'file_10007',
#               'file_10028',
#               'file_10031',
#               'file_10032',
#               'file_10034',
#               'file_10036',
#               'file_10037',
#               'file_10047',
#               'file_10064',
#               'file_1008',
#               'file_10081',
#               'file_10088',
#               'file_10114',
#               'file_10134',
#               'file_10157',
#               'file_10159',
#               'file_10165',
#               'file_10175',
#               'file_1018',
#               'file_10187',
#               'file_10188',
#               'file_10192',
#               'file_10194',
#               'file_10195',
#               'file_10198',
#               'file_10219',
#               'file_10221',
#               'file_10250',
#               'file_10258',
#               'file_10287',
#               'file_10301',
#               'file_10310',
#               'file_10319',
#               'file_10322',
#               'file_10326',
#               'file_10341',
#               'file_10346',
#               'file_10349',
#               'file_10350',
#               'file_10352',
#               'file_10355',
#               'file_10357',
#               'file_10365',
#               'file_10410',
#               'file_10430',
#               'file_10433',
#               'file_10457',
#               'file_10459',
#               'file_10470',
#               'file_10477',
#               'file_10478',
#               'file_10483',
#               'file_10489',
#               'file_1049',
#               'file_10491',
#               'file_10501',
#               'file_10512',
#               'file_10516',
#               'file_1053',
#               'file_10549',
#               'file_10573',
#               'file_10576',
#               'file_10578',
#               'file_10584',
#               'file_1059',
#               'file_1060',
#               'file_10603',
#               'file_10616',
#               'file_10618',
#               'file_10629',
#               'file_10631',
#               'file_10633',
#               'file_10637',
#               'file_10644',
#               'file_10651',
#               'file_10655',
#               'file_10657',
#               'file_10694',
#               'file_10698',
#               'file_1070',
#               'file_10704',
#               'file_10723',
#               'file_10738',
#               'file_10739',
#               'file_10747',
#               'file_10758',
#               'file_1076',
#               'file_1077',
#               'file_10772',
#               'file_10773',
#               'file_10775',
#               'file_10776',
#               'file_10777',
#               'file_1078',
#               'file_1079',
#               'file_10791',
#               'file_10805',
#               'file_10812',
#               'file_10830',
#               'file_10845',
#               'file_10850',
#               'file_10860',
#               'file_10867',
#               'file_10880',
#               'file_10884',
#               'file_10893'},
#              'random': {'file_1',
#               'file_10089',
#               'file_10122',
#               'file_10182',
#               'file_10345',
#               'file_10503',
#               'file_10574',
#               'file_10629',
#               'file_10630',
#               'file_1069'},
#              'capac': {'file_1',
#               'file_10474',
#               'file_10615',
#               'file_10737',
#               'file_10770'},
#              'access': {'file_1'},
#              'highspe': {'file_10'},
#              'microwav': {'file_10',
#               'file_10059',
#               'file_10061',
#               'file_10066',
#               'file_10085',
#               'file_10094',
#               'file_10141',
#               'file_10178',
#               'file_10235',
#               'file_10250',
#               'file_10272',
#               'file_10326',
#               'file_10396',
#               'file_10401',
#               'file_10515',
#               'file_10640',
#               'file_10652',
#               'file_10656',
#               'file_10762',
#               'file_10783',
#               'file_10784',
#               'file_10788',
#               'file_10789',
#               'file_10802',
#               'file_10803',
#               'file_10807',
#               'file_1082',
#               'file_10858',
#               'file_10867',
#               'file_1088',
#               'file_1089',
#               'file_10893'},
#              'part': {'file_10',
#               'file_1000',
#               'file_10016',
#               'file_10035',
#               'file_1008',
#               'file_10095',
#               'file_10116',
#               'file_10134',
#               'file_10144',
#               'file_10170',
#               'file_10200',
#               'file_10204',
#               'file_10248',
#               'file_1026',
#               'file_1027',
#               'file_10294',
#               'file_10301',
#               'file_10302',
#               'file_10308',
#               'file_10309',
#               'file_10311',
#               'file_10312',
#               'file_1032',
#               'file_10389',
#               'file_10401',
#               'file_10432',
#               'file_1046',
#               'file_10495',
#               'file_10523',
#               'file_10530',
#               'file_10531',
#               'file_10540',
#               'file_10567',
#               'file_10610',
#               'file_10645',
#               'file_10648',
#               'file_10651',
#               'file_10685',
#               'file_10696',
#               'file_107',
#               'file_10742',
#               'file_10803',
#               'file_10808',
#               'file_10824',
#               'file_10894'},
#              'semiconductor': {'file_10',
#               'file_10072',
#               'file_10214',
#               'file_10223',
#               'file_10372',
#               'file_10475',
#               'file_1059',
#               'file_10618',
#               'file_1084'},
#              'switch': {'file_10',
#               'file_10024',
#               'file_10025',
#               'file_10030',
#               'file_10032',
#               'file_10320',
#               'file_10326',
#               'file_10332',
#               'file_10333',
#               'file_10350',
#               'file_10357',
#               'file_10475',
#               'file_10478',
#               'file_10479',
#               'file_10480',
#               'file_1054',
#               'file_10616',
#               'file_10620',
#               'file_1063',
#               'file_10736',
#               'file_10744',
#               'file_10745',
#               'file_10746',
#               'file_10747',
#               'file_10759',
#               'file_10760'},
#              'four': {'file_100',
#               'file_10019',
#               'file_10026',
#               'file_10046',
#               'file_1010',
#               'file_10107',
#               'file_10120',
#               'file_10170',
#               'file_1026',
#               'file_10320',
#               'file_10378',
#               'file_10419',
#               'file_10422',
#               'file_10471',
#               'file_10626',
#               'file_10682',
#               'file_10699',
#               'file_10725',
#               'file_10890'},
#              'result': {'file_100',
#               'file_10003',
#               'file_10010',
#               'file_10019',
#               'file_1003',
#               'file_10032',
#               'file_10036',
#               'file_1004',
#               'file_10044',
#               'file_10070',
#               'file_10072',
#               'file_10076',
#               'file_10080',
#               'file_10081',
#               'file_10089',
#               'file_1009',
#               'file_10092',
#               'file_101',
#               'file_10104',
#               'file_10107',
#               'file_10108',
#               'file_10115',
#               'file_10120',
#               'file_10136',
#               'file_10142',
#               'file_10145',
#               'file_1015',
#               'file_10192',
#               'file_10200',
#               'file_10213',
#               'file_10219',
#               'file_10221',
#               'file_10242',
#               'file_10257',
#               'file_10262',
#               'file_10268',
#               'file_10272',
#               'file_10298',
#               'file_10299',
#               'file_10300',
#               'file_10310',
#               'file_10311',
#               'file_10316',
#               'file_10344',
#               'file_10350',
#               'file_10355',
#               'file_10358',
#               'file_10367',
#               'file_1037',
#               'file_10370',
#               'file_10374',
#               'file_1038',
#               'file_10418',
#               'file_10419',
#               'file_1042',
#               'file_10444',
#               'file_10452',
#               'file_10453',
#               'file_10456',
#               'file_10510',
#               'file_10513',
#               'file_10519',
#               'file_10522',
#               'file_10523',
#               'file_10537',
#               'file_10570',
#               'file_10574',
#               'file_10576',
#               'file_10581',
#               'file_10589',
#               'file_10591',
#               'file_10595',
#               'file_10598',
#               'file_106',
#               'file_10622',
#               'file_10661',
#               'file_10669',
#               'file_10680',
#               'file_10681',
#               'file_10692',
#               'file_10699',
#               'file_10707',
#               'file_10709',
#               'file_10713',
#               'file_10718',
#               'file_10736',
#               'file_10742',
#               'file_10763',
#               'file_10770',
#               'file_10780',
#               'file_1080',
#               'file_10817',
#               'file_10831',
#               'file_10832',
#               'file_10839',
#               'file_10842',
#               'file_10844',
#               'file_10859',
#               'file_10865',
#               'file_10867',
#               'file_10883',
#               'file_10896'},
#              'argu': {'file_100'},
#              'nuclear': {'file_100',
#               'file_10074',
#               'file_10104',
#               'file_10123',
#               'file_10131',
#               'file_10403',
#               'file_10404',
#               'file_10805',
#               'file_1082'},
#              'shell': {'file_100', 'file_10796'},
#              'deton': {'file_100'},
#              'inject': {'file_100', 'file_10110', 'file_10798'},
#              'observ': {'file_100',
#               'file_10002',
#               'file_10007',
#               'file_10019',
#               'file_1003',
#               'file_1006',
#               'file_1008',
#               'file_10085',
#               'file_10093',
#               'file_10094',
#               'file_10098',
#               'file_10099',
#               'file_101',
#               'file_10103',
#               'file_10104',
#               'file_10107',
#               'file_1011',
#               'file_10112',
#               'file_10113',
#               'file_10116',
#               'file_10125',
#               'file_10130',
#               'file_10143',
#               'file_10146',
#               'file_10147',
#               'file_1019',
#               'file_102',
#               'file_1020',
#               'file_10228',
#               'file_1023',
#               'file_10235',
#               'file_10237',
#               'file_10252',
#               'file_10257',
#               'file_1026',
#               'file_10260',
#               'file_10261',
#               'file_10262',
#               'file_10263',
#               'file_10264',
#               'file_10266',
#               'file_10274',
#               'file_10275',
#               'file_10280',
#               'file_10288',
#               'file_1029',
#               'file_10293',
#               'file_10294',
#               'file_10296',
#               'file_1030',
#               'file_10300',
#               'file_10305',
#               'file_10309',
#               'file_10310',
#               'file_10311',
#               'file_10313',
#               'file_1038',
#               'file_10403',
#               'file_10404',
#               'file_10411',
#               'file_10412',
#               'file_10414',
#               'file_10415',
#               'file_10416',
#               'file_10418',
#               'file_10419',
#               'file_10422',
#               'file_10426',
#               'file_10427',
#               'file_1043',
#               'file_10430',
#               'file_10434',
#               'file_10445',
#               'file_10448',
#               'file_10450',
#               'file_10452',
#               'file_10454',
#               'file_10455',
#               'file_10456',
#               'file_1047',
#               'file_10482',
#               'file_10510',
#               'file_10529',
#               'file_10535',
#               'file_10537',
#               'file_10539',
#               'file_10541',
#               'file_10542',
#               'file_10543',
#               'file_10546',
#               'file_10547',
#               'file_10549',
#               'file_10557',
#               'file_10562',
#               'file_10565',
#               'file_10568',
#               'file_10570',
#               'file_10574',
#               'file_10580',
#               'file_10584',
#               'file_10587',
#               'file_10591',
#               'file_10597',
#               'file_10599',
#               'file_106',
#               'file_10600',
#               'file_10601',
#               'file_10602',
#               'file_10603',
#               'file_10647',
#               'file_10653',
#               'file_10669',
#               'file_10671',
#               'file_10673',
#               'file_10682',
#               'file_10694',
#               'file_10697',
#               'file_10704',
#               'file_10707',
#               'file_10713',
#               'file_10714',
#               'file_10719',
#               'file_10726',
#               'file_10729',
#               'file_10772',
#               'file_10773',
#               'file_10785',
#               'file_10809',
#               'file_10816',
#               'file_10817',
#               'file_10820',
#               'file_10828',
#               'file_10829',
#               'file_10830',
#               'file_10834',
#               'file_10837',
#               'file_10842',
#               'file_10844',
#               'file_10856',
#               'file_10859'},
#              'detector': {'file_100',
#               'file_10203',
#               'file_10218',
#               'file_10220',
#               'file_10237',
#               'file_10760'},
#              'geomagnet': {'file_100',
#               'file_1003',
#               'file_1004',
#               'file_1005',
#               'file_10099',
#               'file_10106',
#               'file_10107',
#               'file_1027',
#               'file_10279',
#               'file_10280',
#               'file_10292',
#               'file_10312',
#               'file_10313',
#               'file_1039',
#               'file_1041',
#               'file_10418',
#               'file_10419',
#               'file_10422',
#               'file_10447',
#               'file_10456',
#               'file_1047',
#               'file_10545',
#               'file_10554',
#               'file_10555',
#               'file_10557',
#               'file_10558',
#               'file_10574',
#               'file_10590',
#               'file_10601',
#               'file_10680',
#               'file_10690',
#               'file_10691',
#               'file_10692',
#               'file_10711',
#               'file_10828',
#               'file_10835',
#               'file_10836',
#               'file_10837',
#               'file_10838',
#               'file_10859'},
#              'satellit': {'file_100',
#               'file_1006',
#               'file_101',
#               'file_10109',
#               'file_10110',
#               'file_10111',
#               'file_10112',
#               'file_10113',
#               'file_10114',
#               'file_1014',
#               'file_1015',
#               'file_1016',
#               'file_1017',
#               'file_1018',
#               'file_1019',
#               'file_102',
#               'file_1020',
#               'file_1021',
#               'file_1022',
#               'file_1023',
#               'file_1024',
#               'file_1025',
#               'file_10281',
#               'file_10282',
#               'file_10283',
#               'file_10284',
#               'file_10285',
#               'file_10286',
#               'file_10287',
#               'file_10288',
#               'file_10294',
#               'file_103',
#               'file_10300',
#               'file_10375',
#               'file_10411',
#               'file_10419',
#               'file_10427',
#               'file_10428',
#               'file_10429',
#               'file_10431',
#               'file_10432',
#               'file_10433',
#               'file_10434',
#               'file_10435',
#               'file_10436',
#               'file_10450',
#               'file_10458',
#               'file_10462',
#               'file_10511',
#               'file_10559',
#               'file_10560',
#               'file_10561',
#               'file_10562',
#               'file_10564',
#               'file_10565',
#               'file_10566',
#               'file_10567',
#               'file_10582',
#               'file_10583',
#               'file_10672',
#               'file_10694',
#               'file_10695',
#               'file_10696',
#               'file_10697',
#               'file_10698',
#               'file_10699',
#               'file_10701',
#               'file_10702',
#               'file_10713',
#               'file_10718',
#               'file_10719',
#               'file_10720',
#               'file_10721',
#               'file_10726',
#               'file_10816',
#               'file_10840',
#               'file_10841',
#               'file_10842',
#               'file_10843',
#               'file_10844',
#               'file_10845',
#               'file_10847',
#               'file_10848',
#               'file_10861',
#               'file_10862',
#               'file_10879'},
#              'artifici': {'file_100',
#               'file_101',
#               'file_1014',
#               'file_1019',
#               'file_102',
#               'file_1023',
#               'file_1026',
#               'file_10281',
#               'file_10283',
#               'file_10284',
#               'file_10436',
#               'file_10516',
#               'file_10560',
#               'file_10696',
#               'file_10802',
#               'file_10840',
#               'file_10862',
#               'file_10868'},
#              'sever': {'file_100',
#               'file_10019',
#               'file_10046',
#               'file_10072',
#               'file_10180',
#               'file_10188',
#               'file_10200',
#               'file_10227',
#               'file_10255',
#               'file_10293',
#               'file_10308',
#               'file_10403',
#               'file_1042',
#               'file_10430',
#               'file_10447',
#               'file_10567',
#               'file_10598',
#               'file_10720',
#               'file_10731',
#               'file_10756',
#               'file_10820'},
#              'trap': {'file_100',
#               'file_1005',
#               'file_10097',
#               'file_10138',
#               'file_10281',
#               'file_10299',
#               'file_1039',
#               'file_10418',
#               'file_1046',
#               'file_10545',
#               'file_10554',
#               'file_10680',
#               'file_10681',
#               'file_10832',
#               'file_10855',
#               'file_10860'},
#              'pass': {'file_100',
#               'file_10039',
#               'file_10043',
#               'file_10106',
#               'file_10175',
#               'file_10192',
#               'file_10234',
#               'file_10339',
#               'file_10462',
#               'file_10486',
#               'file_10628',
#               'file_10723',
#               'file_10755',
#               'file_10756',
#               'file_10757'},
#              'explor': {'file_100',
#               'file_1005',
#               'file_1006',
#               'file_10112',
#               'file_10419',
#               'file_10424',
#               'file_10543',
#               'file_10682'},
#              'altitud': {'file_100',
#               'file_10007',
#               'file_10009',
#               'file_10014',
#               'file_10017',
#               'file_1003',
#               'file_1005',
#               'file_10110',
#               'file_10131',
#               'file_10141',
#               'file_10267',
#               'file_10434',
#               'file_10440',
#               'file_10450',
#               'file_10452',
#               'file_10536',
#               'file_10677',
#               'file_10828'},
#              'signific': {'file_100',
#               'file_10017',
#               'file_10162',
#               'file_1027',
#               'file_10275',
#               'file_1032',
#               'file_10429',
#               'file_10547',
#               'file_10549',
#               'file_10624',
#               'file_10689',
#               'file_10830',
#               'file_10871'},
#              'summar': {'file_100', 'file_10174'},
#              'field': {'file_100',
#               'file_10003',
#               'file_10011',
#               'file_1003',
#               'file_1004',
#               'file_1005',
#               'file_10068',
#               'file_10070',
#               'file_10077',
#               'file_10078',
#               'file_10086',
#               'file_10088',
#               'file_10097',
#               'file_10105',
#               'file_10107',
#               'file_10126',
#               'file_1013',
#               'file_10140',
#               'file_10144',
#               'file_10145',
#               'file_10149',
#               'file_10154',
#               'file_10201',
#               'file_10232',
#               'file_10234',
#               'file_10235',
#               'file_10239',
#               'file_1024',
#               'file_10242',
#               'file_10245',
#               'file_10250',
#               'file_10255',
#               'file_10257',
#               'file_10258',
#               'file_1027',
#               'file_10270',
#               'file_10272',
#               'file_10276',
#               'file_10280',
#               'file_10281',
#               'file_10290',
#               'file_10292',
#               'file_10304',
#               'file_10309',
#               'file_10316',
#               'file_10338',
#               'file_10367',
#               'file_10368',
#               'file_10381',
#               'file_10384',
#               'file_10387',
#               'file_10389',
#               'file_10391',
#               'file_10393',
#               'file_10394',
#               'file_10398',
#               'file_1040',
#               'file_10403',
#               'file_10404',
#               'file_10405',
#               'file_10406',
#               'file_10409',
#               'file_10418',
#               'file_10425',
#               'file_10426',
#               'file_10427',
#               'file_10435',
#               'file_10451',
#               'file_10455',
#               'file_1046',
#               'file_10461',
#               'file_10473',
#               'file_10481',
#               'file_10517',
#               'file_10518',
#               'file_10520',
#               'file_10522',
#               'file_10533',
#               'file_10534',
#               'file_10545',
#               'file_10556',
#               'file_10566',
#               'file_10569',
#               'file_10571',
#               'file_10574',
#               'file_10583',
#               'file_10587',
#               'file_10649',
#               'file_10650',
#               'file_10651',
#               'file_10654',
#               'file_10655',
#               'file_10662',
#               'file_10663',
#               'file_10664',
#               'file_10668',
#               'file_10680',
#               'file_10681',
#               'file_10682',
#               'file_10686',
#               'file_10691',
#               'file_10693',
#               'file_10719',
#               'file_10723',
#               'file_10747',
#               'file_10771',
#               'file_10784',
#               'file_10786',
#               'file_10789',
#               'file_10790',
#               'file_10791',
#               'file_10792',
#               'file_10793',
#               'file_10794',
#               'file_10805',
#               'file_10812',
#               'file_10813',
#               'file_1083',
#               'file_10832',
#               'file_10834',
#               'file_10835',
#               'file_10836',
#               'file_10850',
#               'file_10851',
#               'file_10855',
#               'file_10869',
#               'file_10872',
#               'file_10895'},
#              'radiat': {'file_100',
#               'file_10009',
#               'file_10018',
#               'file_1002',
#               'file_1003',
#               'file_1004',
#               'file_1005',
#               'file_1006',
#               'file_10076',
#               'file_10081',
#               'file_10094',
#               'file_10095',
#               'file_10107',
#               'file_10108',
#               'file_1011',
#               'file_10115',
#               'file_10138',
#               'file_10229',
#               'file_10233',
#               'file_10234',
#               'file_10235',
#               'file_10237',
#               'file_1025',
#               'file_10267',
#               'file_10268',
#               'file_10281',
#               'file_10291',
#               'file_10367',
#               'file_10395',
#               'file_10396',
#               'file_10407',
#               'file_10411',
#               'file_10416',
#               'file_10419',
#               'file_1043',
#               'file_10432',
#               'file_10433',
#               'file_10452',
#               'file_10462',
#               'file_1047',
#               'file_1048',
#               'file_10523',
#               'file_10539',
#               'file_10540',
#               'file_10543',
#               'file_10544',
#               'file_10552',
#               'file_10554',
#               'file_10565',
#               'file_10567',
#               'file_10597',
#               'file_10677',
#               'file_10678',
#               'file_10682',
#               'file_10697',
#               'file_10705',
#               'file_10706',
#               'file_10716',
#               'file_10728',
#               'file_10783',
#               'file_10789',
#               'file_10797',
#               'file_10802',
#               'file_10803',
#               'file_10818',
#               'file_10820',
#               'file_10825',
#               'file_10827',
#               'file_10841',
#               'file_10842',
#               'file_10856'},
#              'experi': {'file_100',
#               'file_10076',
#               'file_10143',
#               'file_10235',
#               'file_10248',
#               'file_10251',
#               'file_10368',
#               'file_10393',
#               'file_10435',
#               'file_10453',
#               'file_10489',
#               'file_10519',
#               'file_10564',
#               'file_10639',
#               'file_10672',
#               'file_10721',
#               'file_10729',
#               'file_10784',
#               'file_10791',
#               'file_10802',
#               'file_10813',
#               'file_1082',
#               'file_10860',
#               'file_10896'},
#              'high': {'file_100',
#               'file_10014',
#               'file_10019',
#               'file_10021',
#               'file_10024',
#               'file_10029',
#               'file_10031',
#               'file_10033',
#               'file_1006',
#               'file_1007',
#               'file_10079',
#               'file_10081',
#               'file_10092',
#               'file_10115',
#               'file_10116',
#               'file_10131',
#               'file_10134',
#               'file_10141',
#               'file_10153',
#               'file_10165',
#               'file_10182',
#               'file_10192',
#               'file_10194',
#               'file_10212',
#               'file_10213',
#               'file_10224',
#               'file_1024',
#               'file_10268',
#               'file_10269',
#               'file_10280',
#               'file_10301',
#               'file_10302',
#               'file_10304',
#               'file_10316',
#               'file_1033',
#               'file_10333',
#               'file_10339',
#               'file_1034',
#               'file_1036',
#               'file_10365',
#               'file_1039',
#               'file_10423',
#               'file_1044',
#               'file_10440',
#               'file_10441',
#               'file_10469',
#               'file_10479',
#               'file_10521',
#               'file_10536',
#               'file_1056',
#               'file_10564',
#               'file_10612',
#               'file_10625',
#               'file_10628',
#               'file_10652',
#               'file_10660',
#               'file_10722',
#               'file_10724',
#               'file_10729',
#               'file_10731',
#               'file_10737',
#               'file_10742',
#               'file_10745',
#               'file_1075',
#               'file_10755',
#               'file_10756',
#               'file_10760',
#               'file_10783',
#               'file_10784',
#               'file_10786',
#               'file_10793',
#               'file_10799',
#               'file_1080',
#               'file_10828',
#               'file_10837',
#               'file_10843',
#               'file_1085'},
#              'electron': {'file_100',
#               'file_10013',
#               'file_10014',
#               'file_10017',
#               'file_10018',
#               'file_10026',
#               'file_10060',
#               'file_10061',
#               'file_10071',
#               'file_10074',
#               'file_10075',
#               'file_10087',
#               'file_10089',
#               'file_10090',
#               'file_10109',
#               'file_10126',
#               'file_10153',
#               'file_102',
#               'file_10221',
#               'file_10223',
#               'file_10224',
#               'file_10225',
#               'file_10226',
#               'file_10227',
#               'file_1023',
#               'file_10234',
#               'file_1026',
#               'file_10267',
#               'file_1027',
#               'file_10274',
#               'file_10275',
#               'file_1028',
#               'file_10287',
#               'file_10290',
#               'file_10291',
#               'file_10296',
#               'file_10298',
#               'file_10309',
#               'file_1038',
#               'file_10381',
#               'file_10383',
#               'file_10386',
#               'file_10387',
#               'file_10388',
#               'file_10389',
#               'file_1039',
#               'file_10391',
#               'file_10392',
#               'file_10393',
#               'file_10395',
#               'file_10396',
#               'file_1040',
#               'file_10418',
#               'file_10419',
#               'file_10434',
#               'file_10445',
#               'file_10451',
#               'file_1046',
#               'file_10486',
#               'file_10499',
#               'file_10520',
#               'file_10521',
#               'file_10522',
#               'file_10533',
#               'file_10543',
#               'file_10545',
#               'file_10546',
#               'file_10570',
#               'file_10588',
#               'file_10592',
#               'file_10593',
#               'file_106',
#               'file_10600',
#               'file_1063',
#               'file_10646',
#               'file_10647',
#               'file_10648',
#               'file_10649',
#               'file_10651',
#               'file_10652',
#               'file_10663',
#               'file_10664',
#               'file_10665',
#               'file_10680',
#               'file_10682',
#               'file_10704',
#               'file_10705',
#               'file_10706',
#               'file_10713',
#               'file_10716',
#               'file_10718',
#               'file_10723',
#               'file_10758',
#               'file_10777',
#               'file_10782',
#               'file_10784',
#               'file_10785',
#               'file_10787',
#               'file_10790',
#               'file_10792',
#               'file_10795',
#               'file_10796',
#               'file_10798',
#               'file_10834',
#               'file_10850',
#               'file_10851',
#               'file_10852',
#               'file_10857',
#               'file_10858',
#               'file_10860',
#               'file_10861',
#               'file_10862'},
#              'measur': {'file_100',
#               'file_10006',
#               'file_10013',
#               'file_10014',
#               'file_1002',
#               'file_10026',
#               'file_1003',
#               'file_10032',
#               'file_10034',
#               'file_10044',
#               'file_1005',
#               'file_10069',
#               'file_1008',
#               'file_10080',
#               'file_10081',
#               'file_101',
#               'file_10102',
#               'file_10108',
#               'file_10114',
#               'file_10120',
#               'file_10123',
#               'file_1013',
#               'file_10135',
#               'file_1014',
#               'file_10140',
#               'file_10141',
#               'file_10144',
#               'file_1015',
#               'file_10151',
#               'file_10187',
#               'file_102',
#               'file_1020',
#               'file_10204',
#               'file_10215',
#               'file_10218',
#               'file_1023',
#               'file_10231',
#               'file_1024',
#               'file_10257',
#               'file_10258',
#               'file_10264',
#               'file_10267',
#               'file_10281',
#               'file_10287',
#               'file_10294',
#               'file_10297',
#               'file_10298',
#               'file_10299',
#               'file_10302',
#               'file_1031',
#               'file_10330',
#               'file_10350',
#               'file_10358',
#               'file_10376',
#               'file_10381',
#               'file_10411',
#               'file_10413',
#               'file_10414',
#               'file_10419',
#               'file_10421',
#               'file_10427',
#               'file_10430',
#               'file_10433',
#               'file_10434',
#               'file_10439',
#               'file_10452',
#               'file_10453',
#               'file_10487',
#               'file_10506',
#               'file_10533',
#               'file_10540',
#               'file_10551',
#               'file_10552',
#               'file_10557',
#               'file_10562',
#               'file_10566',
#               'file_10570',
#               'file_10571',
#               'file_10574',
#               'file_10575',
#               'file_10577',
#               'file_10580',
#               'file_10581',
#               'file_10582',
#               'file_10584',
#               'file_10588',
#               'file_10591',
#               'file_10595',
#               'file_10600',
#               'file_10651',
#               'file_10652',
#               'file_10673',
#               'file_10674',
#               'file_10677',
#               'file_10682',
#               'file_10684',
#               'file_10693',
#               'file_10694',
#               'file_10698',
#               'file_10713',
#               'file_10716',
#               'file_10718',
#               'file_10722',
#               'file_10725',
#               'file_10727',
#               'file_10744',
#               'file_10783',
#               'file_10784',
#               'file_10787',
#               'file_10789',
#               'file_1079',
#               'file_10812',
#               'file_10820',
#               'file_10826',
#               'file_10827',
#               'file_10831',
#               'file_10836',
#               'file_10841',
#               'file_10848',
#               'file_10856',
#               'file_10860',
#               'file_10861',
#               'file_10862',
#               'file_10865',
#               'file_10867',
#               'file_10872',
#               'file_10873',
#               'file_10882',
#               'file_10884'},
#              'one': {'file_1000',
#               'file_1001',
#               'file_10040',
#               'file_1005',
#               'file_10057',
#               'file_10061',
#               'file_1009',
#               'file_10090',
#               'file_10127',
#               'file_1013',
#               'file_10135',
#               'file_10155',
#               'file_1016',
#               'file_10167',
#               'file_10168',
#               'file_10227',
#               'file_10287',
#               'file_10328',
#               'file_1035',
#               'file_10350',
#               'file_10357',
#               'file_10493',
#               'file_10496',
#               'file_10505',
#               'file_10516',
#               'file_1053',
#               'file_1055',
#               'file_10578',
#               'file_10626',
#               'file_1063',
#               'file_10639',
#               'file_10728',
#               'file_10743',
#               'file_10760',
#               'file_10830',
#               'file_10871'},
#              'centauru': {'file_1000', 'file_10416'},
#              'eta': {'file_1000'},
#              'carina': {'file_1000'},
#              'mc': {'file_1000',
#               'file_1007',
#               'file_1008',
#               'file_1022',
#               'file_10290',
#               'file_103',
#               'file_1030',
#               'file_1043',
#               'file_10469',
#               'file_10571'},
#              'near': {'file_1000',
#               'file_10070',
#               'file_10083',
#               'file_10106',
#               'file_10109',
#               'file_10111',
#               'file_10116',
#               'file_10131',
#               'file_10276',
#               'file_10281',
#               'file_10297',
#               'file_10298',
#               'file_10395',
#               'file_10422',
#               'file_10448',
#               'file_10557',
#               'file_10569',
#               'file_10582',
#               'file_10600',
#               'file_10719',
#               'file_10734',
#               'file_10792',
#               'file_10847',
#               'file_10857'},
#              'nebula': {'file_1000'},
#              'effect': {'file_10000',
#               'file_10017',
#               'file_10026',
#               'file_10028',
#               'file_10054',
#               'file_10055',
#               'file_10065',
#               'file_10069',
#               'file_10070',
#               'file_10077',
#               'file_10085',
#               'file_10086',
#               'file_10097',
#               'file_10106',
#               'file_10111',
#               'file_10116',
#               'file_10130',
#               'file_10132',
#               'file_10136',
#               'file_10151',
#               'file_10196',
#               'file_10198',
#               'file_1021',
#               'file_10229',
#               'file_10232',
#               'file_10237',
#               'file_10239',
#               'file_10268',
#               'file_10274',
#               'file_10276',
#               'file_10279',
#               'file_10281',
#               'file_10283',
#               'file_10330',
#               'file_10346',
#               'file_10348',
#               'file_10351',
#               'file_1036',
#               'file_10369',
#               'file_1038',
#               'file_10388',
#               'file_10389',
#               'file_10393',
#               'file_10401',
#               'file_10404',
#               'file_10405',
#               'file_1042',
#               'file_10422',
#               'file_10429',
#               'file_10432',
#               'file_1045',
#               'file_10461',
#               'file_10473',
#               'file_10478',
#               'file_10498',
#               'file_10523',
#               'file_10532',
#               'file_10534',
#               'file_10544',
#               'file_10567',
#               'file_10571',
#               'file_10578',
#               'file_10583',
#               'file_10589',
#               'file_10590',
#               'file_1060',
#               'file_10613',
#               'file_10620',
#               'file_10622',
#               'file_10643',
#               'file_10655',
#               'file_10660',
#               'file_10664',
#               'file_10665',
#               'file_10679',
#               'file_10686',
#               'file_10690',
#               'file_10694',
#               'file_10696',
#               'file_107',
#               'file_10713',
#               'file_10717',
#               'file_10741',
#               'file_10747',
#               'file_10772',
#               'file_10778',
#               'file_10785',
#               'file_10787',
#               'file_10791',
#               'file_10797',
#               'file_1082',
#               'file_10823',
#               'file_10830',
#               'file_10832',
#               'file_1084',
#               'file_10842',
#               'file_10844',
#               'file_10848',
#               'file_10849',
#               'file_10852',
#               'file_10856',
#               'file_10864',
#               'file_10868',
#               'file_10871',
#               'file_10872',
#               'file_10876',
#               'file_10879',
#               'file_10891',
#               'file_10894',
#               'file_10895'},
#              'neglig': {'file_10000', 'file_10017'},
#              'sunspot': {'file_10000',
#               'file_10012',
#               'file_10129',
#               'file_10286',
#               'file_1033',
#               'file_1036',
#               'file_1037',
#               'file_10412',
#               'file_10553',
#               'file_10856',
#               'file_10857'},
#              'long': {'file_10000',
#               'file_10129',
#               'file_10151',
#               'file_10165',
#               'file_10249',
#               'file_10274',
#               'file_10276',
#               'file_10283',
#               'file_10312',
#               'file_10470',
#               'file_10507',
#               'file_10526',
#               'file_10696',
#               'file_10761',
#               'file_10817',
#               'file_10839',
#               'file_10856'},
#              'note': {'file_10000',
#               'file_10008',
#               'file_10019',
#               'file_10047',
#               'file_10058',
#               'file_10117',
#               'file_1021',
#               'file_10214',
#               'file_10241',
#               'file_10244',
#               'file_10322',
#               'file_10324',
#               'file_10361',
#               'file_10399',
#               'file_10430',
#               'file_10449',
#               'file_1050',
#               'file_10514',
#               'file_10570',
#               'file_10646',
#               'file_10726',
#               'file_10746',
#               'file_10836',
#               'file_10839',
#               'file_10849',
#               'file_10890',
#               'file_10897'},
# ...
#               'file_1063',
#               'file_10632',
#               'file_10704'},
#              'yield': {'file_10089', 'file_102'},
#              'forward': {'file_10089',
#               'file_10214',
#               'file_10246',
#               'file_10278',
#               'file_10800'},
#              'straight': {'file_10089',
#               'file_10373',
#               'file_10512',
#               'file_10800'},
#              'summat': {'file_10089'},
#              'motion': {'file_10089',
#               'file_10236',
#               'file_10249',
#               'file_10282',
#               'file_10283',
#               'file_10392',
#               'file_10412',
#               'file_105',
#               'file_10521',
#               'file_10533',
#               'file_10554',
#               'file_10696',
#               'file_10699',
#               'file_10818',
#               'file_10832',
#               'file_10853',
#               'file_10869'},
#              'combin': {'file_10089',
#               'file_10153',
#               'file_10190',
#               'file_10469',
#               'file_1057',
#               'file_1059',
#               'file_10598',
#               'file_10647',
#               'file_1071',
#               'file_1083',
#               'file_10849',
#               'file_10883',
#               'file_10886'},
#              'divers': {'file_1009'},
#              'impli': {'file_1009', 'file_10309', 'file_10569'},
#              'adequ': {'file_1009', 'file_10674'},
#              'distanc': {'file_1009',
#               'file_10107',
#               'file_10110',
#               'file_10238',
#               'file_10268',
#               'file_103',
#               'file_10304',
#               'file_10395',
#               'file_10412',
#               'file_10685',
#               'file_10691',
#               'file_10725'},
#              'recept': {'file_1009',
#               'file_10145',
#               'file_10277',
#               'file_10455',
#               'file_10564'},
#              'via': {'file_1009', 'file_10714'},
#              'km': {'file_1009',
#               'file_101',
#               'file_10102',
#               'file_10238',
#               'file_1026',
#               'file_10304',
#               'file_10430',
#               'file_10453',
#               'file_10545',
#               'file_10552',
#               'file_10561',
#               'file_10569',
#               'file_10598',
#               'file_10717',
#               'file_108',
#               'file_10853'},
#              'orbit': {'file_10090',
#               'file_10111',
#               'file_1017',
#               'file_1019',
#               'file_10283',
#               'file_10286',
#               'file_10287',
#               'file_10300',
#               'file_10429',
#               'file_10431',
#               'file_10432',
#               'file_10457',
#               'file_10559',
#               'file_10560',
#               'file_10561',
#               'file_10665',
#               'file_10695',
#               'file_10696',
#               'file_10699',
#               'file_10701',
#               'file_10782',
#               'file_10816',
#               'file_10840',
#               'file_10845'},
#              'prove': {'file_10090', 'file_10229', 'file_10291', 'file_10751'},
#              'energet': {'file_10090', 'file_10832', 'file_10834'},
#              'radiomet': {'file_10091',
#               'file_10343',
#               'file_10698',
#               'file_10789'},
#              'resolut': {'file_10092',
#               'file_10316',
#               'file_10355',
#               'file_10414',
#               'file_10501',
#               'file_10564',
#               'file_10822'},
#              'cygnu': {'file_10092', 'file_10096', 'file_10542'},
#              'nontherm': {'file_10092'},
#              'flux': {'file_10093',
#               'file_10112',
#               'file_10145',
#               'file_10165',
#               'file_10216',
#               'file_10267',
#               'file_10268',
#               'file_10293',
#               'file_10417',
#               'file_10419',
#               'file_10433',
#               'file_10472',
#               'file_10545',
#               'file_10546',
#               'file_10565',
#               'file_10671',
#               'file_10713',
#               'file_10843',
#               'file_10883'},
#              'per': {'file_10093',
#               'file_10159',
#               'file_10310',
#               'file_10495',
#               'file_10508',
#               'file_1085'},
#              'cassiopeia': {'file_10093'},
#              'hogbom': {'file_10093'},
#              'support': {'file_10093',
#               'file_10148',
#               'file_10305',
#               'file_10435',
#               'file_10442',
#               'file_10822'},
#              'last': {'file_10093', 'file_10624', 'file_10846'},
#              'shakeshaft': {'file_10093'},
#              'annum': {'file_10093'},
#              'secular': {'file_10093', 'file_10553'},
#              'corpuscular': {'file_10094',
#               'file_10106',
#               'file_10138',
#               'file_10590'},
#              'zenith': {'file_10094', 'file_10412'},
#              'venu': {'file_10094', 'file_10683', 'file_10684'},
#              'bright': {'file_10094', 'file_10266', 'file_10414'},
#              'maintain': {'file_10094', 'file_10105', 'file_10507'},
#              'angl': {'file_10094',
#               'file_10237',
#               'file_10239',
#               'file_10244',
#               'file_10245',
#               'file_10542',
#               'file_10545',
#               'file_10556',
#               'file_10597',
#               'file_10647',
#               'file_10660',
#               'file_10661',
#               'file_10789',
#               'file_10862',
#               'file_10869'},
#              'consequ': {'file_10094', 'file_10550', 'file_10857'},
#              'jupit': {'file_10095', 'file_10537'},
#              'decimetr': {'file_10095', 'file_10540'},
#              'cyclotron': {'file_10095',
#               'file_10235',
#               'file_10784',
#               'file_1084'},
#              'identifi': {'file_10096', 'file_1040', 'file_10430'},
#              'emit': {'file_10096',
#               'file_1011',
#               'file_10367',
#               'file_10412',
#               'file_10502',
#               'file_10630'},
#              'perseu': {'file_10096'},
#              'cluster': {'file_10096', 'file_10670'},
#              'acceler': {'file_10097',
#               'file_10544',
#               'file_10720',
#               'file_10723'},
#              'spectrum': {'file_10097',
#               'file_10112',
#               'file_10146',
#               'file_10188',
#               'file_10248',
#               'file_10267',
#               'file_10270',
#               'file_10271',
#               'file_10290',
#               'file_10291',
#               'file_10345',
#               'file_10391',
#               'file_10393',
#               'file_10418',
#               'file_10535',
#               'file_10537',
#               'file_10545',
#               'file_10552',
#               'file_10566',
#               'file_10622',
#               'file_10630',
#               'file_10725',
#               'file_10727',
#               'file_1073',
#               'file_10792',
#               'file_10861'},
#              'betatron': {'file_10097', 'file_10544'},
#              'th': {'file_10097',
#               'file_10116',
#               'file_10276',
#               'file_10350',
#               'file_10367',
#               'file_10418',
#               'file_10447'},
#              'novemb': {'file_10098',
#               'file_10130',
#               'file_10269',
#               'file_10279',
#               'file_10313',
#               'file_10412',
#               'file_10538',
#               'file_10547',
#               'file_10555',
#               'file_10572',
#               'file_10576',
#               'file_10596',
#               'file_10599',
#               'file_10602',
#               'file_10700',
#               'file_10717',
#               'file_10825'},
#              'fine': {'file_10098'},
#              'former': {'file_10098'},
#              'sharp': {'file_10098'},
#              'gi': {'file_10098'},
#              'x': {'file_10099',
#               'file_1011',
#               'file_10184',
#               'file_10433',
#               'file_10508',
#               'file_10551',
#               'file_10716',
#               'file_10758',
#               'file_10845'},
#              'disturb': {'file_10099',
#               'file_10105',
#               'file_10106',
#               'file_10107',
#               'file_10121',
#               'file_10123',
#               'file_10269',
#               'file_10295',
#               'file_10388',
#               'file_10410',
#               'file_10423',
#               'file_1044',
#               'file_10447',
#               'file_1047',
#               'file_10557',
#               'file_10558',
#               'file_10572',
#               'file_10717',
#               'file_10724',
#               'file_10859',
#               'file_10865',
#               'file_10869'},
#              'auror': {'file_10099',
#               'file_10118',
#               'file_10144',
#               'file_10306',
#               'file_10307',
#               'file_10308',
#               'file_10309',
#               'file_1039',
#               'file_1040',
#               'file_1043',
#               'file_10447',
#               'file_1045',
#               'file_10454',
#               'file_10536',
#               'file_10557',
#               'file_10590',
#               'file_10599',
#               'file_10600',
#               'file_10601',
#               'file_10602',
#               'file_10678',
#               'file_10686',
#               'file_10724',
#               'file_10834',
#               'file_10869',
#               'file_10870'},
#              'interv': {'file_101', 'file_10310', 'file_10688'},
#              'composit': {'file_101', 'file_10351', 'file_10581'},
#              'spectrogram': {'file_101'},
#              'graph': {'file_101', 'file_10342', 'file_10748', 'file_10749'},
#              'rel': {'file_101',
#               'file_10151',
#               'file_10267',
#               'file_10328',
#               'file_10434',
#               'file_10549',
#               'file_10573',
#               'file_10668',
#               'file_10712',
#               'file_10724',
#               'file_10778',
#               'file_1080',
#               'file_10857'},
#              'taken': {'file_101',
#               'file_1023',
#               'file_10250',
#               'file_10290',
#               'file_10292',
#               'file_10294',
#               'file_10540',
#               'file_10545',
#               'file_10859'},
#              'mass': {'file_101',
#               'file_10223',
#               'file_10273',
#               'file_10275',
#               'file_10653',
#               'file_10858',
#               'file_10861'},
#              'longer': {'file_101', 'file_10465'},
#              'spectromet': {'file_101',
#               'file_10134',
#               'file_10301',
#               'file_10302',
#               'file_10845',
#               'file_10858'},
#              'broadsid': {'file_1010'},
#              'april': {'file_1010',
#               'file_1020',
#               'file_10284',
#               'file_1038',
#               'file_10426',
#               'file_10427',
#               'file_10683',
#               'file_10839'},
#              'reproduc': {'file_1010', 'file_10722'},
#              'area': {'file_1010', 'file_10533', 'file_1060', 'file_10831'},
#              'aerial': {'file_1010',
#               'file_10135',
#               'file_10287',
#               'file_1029',
#               'file_10411',
#               'file_10457',
#               'file_10511',
#               'file_10588',
#               'file_10742',
#               'file_10814',
#               'file_10820',
#               'file_10844',
#               'file_10872'},
#              'rectangular': {'file_1010', 'file_10183', 'file_10242'},
#              'array': {'file_1010', 'file_10597'},
#              'rhombic': {'file_1010'},
#              'polar': {'file_10100',
#               'file_10138',
#               'file_10287',
#               'file_10292',
#               'file_10305',
#               'file_10411',
#               'file_10447',
#               'file_10483',
#               'file_10590',
#               'file_10591',
#               'file_10605',
#               'file_10656',
#               'file_10674',
#               'file_10703',
#               'file_10783',
#               'file_1082',
#               'file_10820',
#               'file_10824',
#               'file_10852'},
#              'meteoroid': {'file_10101'},
#              'dust': {'file_10101', 'file_10416'},
#              'fragment': {'file_10101'},
#              'rough': {'file_10101', 'file_10151', 'file_10813'},
#              'ball': {'file_10101', 'file_10802'},
#              'trail': {'file_10101',
#               'file_10102',
#               'file_10273',
#               'file_10274',
#               'file_10275',
#               'file_10276',
#               'file_10277',
#               'file_10278',
#               'file_10448',
#               'file_10550',
#               'file_10685'},
#              'ambipolar': {'file_10102'},
#              'bank': {'file_10102'},
#              'beam': {'file_10102',
#               'file_10209',
#               'file_10210',
#               'file_10290',
#               'file_10382',
#               'file_10383',
#               'file_10386',
#               'file_10396',
#               'file_10508',
#               'file_10529',
#               'file_10533',
#               'file_10605',
#               'file_10646',
#               'file_10772',
#               'file_10784',
#               'file_10797',
#               'file_10798'},
#              'jodrel': {'file_10102'},
#              'conclud': {'file_10102'},
#              'split': {'file_10102',
#               'file_10168',
#               'file_10403',
#               'file_10539',
#               'file_10663'},
#              'flare': {'file_10103',
#               'file_10130',
#               'file_10138',
#               'file_10269',
#               'file_10270',
#               'file_10279',
#               'file_10313',
#               'file_10541',
#               'file_10578',
#               'file_10590',
#               'file_10688',
#               'file_10689',
#               'file_10715',
#               'file_10716',
#               'file_10717',
#               'file_10843',
#               'file_10871'},
#              'arriv': {'file_10103', 'file_10104', 'file_10862'},
#              'tht': {'file_10103', 'file_10652'},
#              'reveal': {'file_10103', 'file_1017', 'file_10270', 'file_10582'},
#              'ground': {'file_10103',
#               'file_10118',
#               'file_1024',
#               'file_10287',
#               'file_10452',
#               'file_1048',
#               'file_10620',
#               'file_10718',
#               'file_10828',
#               'file_10830',
#               'file_10831'},
#              'septemb': {'file_10103',
#               'file_10104',
#               'file_10367',
#               'file_10434',
#               'file_10590',
#               'file_10726'},
#              'gm': {'file_10104', 'file_10566'},
#              'top': {'file_10104'},
#              'c': {'file_10104',
#               'file_10137',
#               'file_10180',
#               'file_10245',
#               'file_1037',
#               'file_1042',
#               'file_1058',
#               'file_1081'},
#              'integr': {'file_10104',
#               'file_10127',
#               'file_10164',
#               'file_10216',
#               'file_10332',
#               'file_10378',
#               'file_10397',
#               'file_10398',
#               'file_10588',
#               'file_10645',
#               'file_10683',
#               'file_10696',
#               'file_10730',
#               'file_10752',
#               'file_10761',
#               'file_10800'},
#              'emuls': {'file_10104'},
#              'million': {'file_10105', 'file_10495'},
#              'penetr': {'file_10105', 'file_1062'},
#              ...})

# %% [markdown]
# # **modelling**

# %% [markdown]
# get inverse document frequency
# *   idf = log(total docs/total docs containing term)

# %%
def get_idf(word):
    return math.log(data.shape[0] / (len(word_dict[word])))

# %% [markdown]
# get rsv ranking weights
#
#
# 1.   generate rsv of each word based on the whole training documents
# 2.   generate rsv of doc based on specific doc provided

# %%
def get_relevant_docs(docs):
  
    files = []
    for file_name in list(docs):
        if int(data[data['file_name'] == file_name]["labels"]) == 1:
            files.append( file_name )
    return files


def generate_rsv_weights():
    weights = {}
    for word in wordlist:
        terms_in_relevant_docs = len(get_relevant_docs(word_dict[word]))
        prob_of_word = terms_in_relevant_docs/(data.shape[0]+0.5)
        _log = math.log(prob_of_word/(1-prob_of_word)) if prob_of_word > 0 else 0
        weights[word] = get_idf(word) + _log
    return weights

weights = generate_rsv_weights()

# %%
weights
# Out:
# {'viewpoint': 6.907755278982137,
#  'germanium': 6.907755278982137,
#  'month': 5.521460917862246,
#  'hercul': 6.907755278982137,
#  'binari': 4.8283137373023015,
#  'dsb': 6.907755278982137,
#  'nerv': 6.907755278982137,
#  'nikecajun': 6.907755278982137,
#  'principl': 4.509860006183766,
#  'isoin': 6.907755278982137,
#  'concurr': 6.907755278982137,
#  'underli': 6.907755278982137,
#  'gate': 6.214608098422191,
#  'crystallin': 6.214608098422191,
#  'fail': 6.907755278982137,
#  'parabol': 6.214608098422191,
#  'spread': 4.3428059215206005,
#  'recov': 6.907755278982137,
#  'cyrat': 6.907755278982137,
#  'control': 3.3524072174927233,
#  'place': 5.298317366548036,
#  'tightli': 6.907755278982137,
#  'longitudin': 4.8283137373023015,
#  'meteor': 4.074541934925921,
#  'bandwidth': 3.9633162998156966,
#  'apart': 6.907755278982137,
#  'et': 6.214608098422191,
#  'nonessenti': 6.907755278982137,
#  'aid': 5.809142990314028,
#  'quit': 6.907755278982137,
#  'receiv': 3.9633162998156966,
#  'ovr': 6.907755278982137,
#  'wiener': 6.907755278982137,
#  'input': 4.074541934925921,
#  'correspond': 4.8283137373023015,
#  'filter': 3.2188758248682006,
#  'tali': 6.907755278982137,
#  'kaenel': 6.907755278982137,
#  'telescop': 4.961845129926823,
#  'four': 3.9633162998156966,
#  'absorb': 5.115995809754082,
#  'rapidli': 5.809142990314028,
#  'disk': 5.521460917862246,
#  'rf': 4.3428059215206005,
#  'scan': 6.214608098422191,
#  'lake': 6.907755278982137,
#  'februari': 6.214608098422191,
#  'infrar': 5.298317366548036,
#  'horizon': 6.907755278982137,
#  'thermal': 4.509860006183766,
#  'appear': 4.710530701645918,
#  'divers': 6.907755278982137,
#  'unconvent': 6.907755278982137,
#  'immers': 6.907755278982137,
#  'sharpli': 6.907755278982137,
#  'finit': 5.809142990314028,
#  'paraboloid': 6.214608098422191,
#  'result': 2.282782465697866,
#  'fourth': 5.809142990314028,
#  'action': 4.961845129926823,
#  'toward': 6.214608098422191,
#  'equilibrium': 5.298317366548036,
#  'valu': 3.0159349808715104,
#  'carbon': 6.214608098422191,
#  'argu': 6.907755278982137,
#  'collis': 4.074541934925921,
#  'microelectron': 6.907755278982137,
#  'bilater': 6.907755278982137,
#  'flux': 3.9633162998156966,
#  'squar': 4.268697949366879,
#  'stress': 6.907755278982137,
#  'creas': 6.907755278982137,
#  'relat': 3.079113882493042,
#  'leakag': 5.809142990314028,
#  'extraordinari': 5.521460917862246,
#  'resistor': 4.8283137373023015,
#  'experiment': 3.2968373663379125,
#  'due': 3.411247717515657,
#  'set': 4.8283137373023015,
#  'breadth': 6.907755278982137,
#  'anisotropi': 5.521460917862246,
#  'ambipolar': 6.907755278982137,
#  'impact': 6.907755278982137,
#  'hydromagnet': 4.8283137373023015,
#  'onward': 6.907755278982137,
#  'quinari': 6.907755278982137,
#  'kc': 5.809142990314028,
#  'clear': 6.907755278982137,
#  'leav': 6.907755278982137,
#  'pulsat': 6.214608098422191,
#  'account': 3.8632328412587142,
#  'chapman': 5.521460917862246,
#  'understand': 6.214608098422191,
#  'lati': 6.907755278982137,
#  'daytim': 5.115995809754082,
#  'depth': 6.214608098422191,
#  'stagger': 5.298317366548036,
#  'mask': 6.214608098422191,
#  'televis': 6.214608098422191,
#  'handl': 6.907755278982137,
#  'interior': 6.907755278982137,
#  'exercis': 6.907755278982137,
#  'magnon': 6.907755278982137,
#  'serv': 6.907755278982137,
#  'intersect': 6.907755278982137,
#  'enhanc': 5.298317366548036,
#  'isl': 6.907755278982137,
#  'hazard': 6.907755278982137,
#  'waltair': 5.298317366548036,
#  'solenoid': 6.907755278982137,
#  'manner': 5.809142990314028,
#  'ge': 5.521460917862246,
#  'comprehens': 5.521460917862246,
#  'aerodynam': 6.907755278982137,
#  'main': 4.3428059215206005,
#  'amplitud': 3.7722610630529876,
#  'cyclic': 6.214608098422191,
#  'subsequ': 6.907755278982137,
#  'symmetri': 6.214608098422191,
#  'nose': 5.809142990314028,
#  'forc': 4.422848629194137,
#  'connect': 4.509860006183766,
#  'open': 6.907755278982137,
#  'one': 3.324236340526027,
#  'nuvistor': 6.907755278982137,
#  'len': 5.809142990314028,
#  'quarter': 6.214608098422191,
#  'million': 6.214608098422191,
#  'increas': 3.036554268074246,
#  'helic': 6.907755278982137,
#  'rotat': 4.199705077879927,
#  'suf': 6.907755278982137,
#  'captur': 6.907755278982137,
#  'eleven': 6.907755278982137,
#  'histori': 6.907755278982137,
#  'found': 3.540459448995663,
#  'easili': 6.907755278982137,
#  'low': 3.0159349808715104,
#  'pressur': 4.422848629194137,
#  'bistat': 6.907755278982137,
#  'emerg': 6.907755278982137,
#  'hop': 6.907755278982137,
#  'aboard': 6.907755278982137,
#  'new': 3.540459448995663,
#  'function': 3.0159349808715104,
#  'appleton': 6.214608098422191,
#  'circumst': 6.907755278982137,
#  'submultipl': 6.907755278982137,
#  'matric': 6.214608098422191,
#  'ray': 3.506557897319982,
#  'emf': 6.907755278982137,
#  'adder': 6.907755278982137,
#  'astronom': 6.907755278982137,
#  'ez': 6.907755278982137,
#  'helium': 5.809142990314028,
#  'drop': 5.809142990314028,
#  'radiu': 6.214608098422191,
#  'christchurch': 6.214608098422191,
#  'raman': 6.907755278982137,
#  'locu': 6.907755278982137,
#  'suggest': 3.540459448995663,
#  'interact': 4.017383521085972,
#  'boron': 6.907755278982137,
#  'distortionless': 6.214608098422191,
#  'meteoroid': 6.907755278982137,
#  'theoret': 3.2441936328524905,
#  'anod': 5.809142990314028,
#  'height': 2.8473122684357177,
#  'stl': 6.907755278982137,
#  'shadow': 6.214608098422191,
#  'calculu': 6.214608098422191,
#  'pulkov': 6.214608098422191,
#  'rectif': 6.907755278982137,
#  'shift': 4.268697949366879,
#  'head': 5.521460917862246,
#  'increasingli': 6.907755278982137,
#  'collector': 5.521460917862246,
#  'order': 4.605170185988092,
#  'flip': 5.521460917862246,
#  'recommend': 6.907755278982137,
#  'maxwellian': 6.907755278982137,
#  'uhf': 6.214608098422191,
#  'orthonorm': 6.907755278982137,
#  'trend': 6.907755278982137,
#  'sq': 6.907755278982137,
#  'topsid': 6.907755278982137,
#  'hillhead': 6.907755278982137,
#  'overhead': 6.214608098422191,
#  'consist': 4.074541934925921,
#  'scalar': 6.214608098422191,
#  'east': 5.809142990314028,
#  'compat': 6.907755278982137,
#  'recent': 4.422848629194137,
#  'mode': 3.8632328412587142,
#  'photoion': 6.907755278982137,
#  'f': 2.8302178350764176,
#  'ramp': 6.907755278982137,
#  'latitudin': 6.214608098422191,
#  'satisfi': 6.214608098422191,
#  'orthogon': 6.907755278982137,
#  'flare': 4.074541934925921,
#  'lien': 6.907755278982137,
#  'illumin': 6.907755278982137,
#  'rarefi': 5.809142990314028,
#  'laplac': 6.907755278982137,
#  'memori': 4.710530701645918,
#  'van': 4.074541934925921,
#  'data': 3.0159349808715104,
#  'excess': 6.214608098422191,
#  'skylark': 6.907755278982137,
#  'frame': 6.907755278982137,
#  'baov': 6.907755278982137,
#  'mainli': 5.809142990314028,
#  'exospher': 4.710530701645918,
#  'dielectr': 4.509860006183766,
#  'hm': 6.907755278982137,
#  'nuclear': 4.710530701645918,
#  'uptap': 6.907755278982137,
#  'hypothes': 6.907755278982137,
#  'wafer': 6.214608098422191,
#  'invok': 6.214608098422191,
#  'lattic': 5.521460917862246,
#  'ba': 6.214608098422191,
#  'knowledg': 6.214608098422191,
#  'interv': 5.809142990314028,
#  'fast': 4.605170185988092,
#  'planar': 6.907755278982137,
#  'nocturn': 5.521460917862246,
#  'band': 3.1941832122778293,
#  'januari': 5.809142990314028,
#  'imped': 4.268697949366879,
#  'stuggart': 6.907755278982137,
#  'vane': 6.907755278982137,
#  'rarifi': 6.907755278982137,
#  'contactless': 6.907755278982137,
#  'extent': 6.214608098422191,
#  'powder': 6.907755278982137,
#  'oscillographi': 6.907755278982137,
#  'ith': 6.907755278982137,
#  'scheme': 6.907755278982137,
#  'correct': 5.115995809754082,
#  'diamet': 5.298317366548036,
#  'thermon': 6.907755278982137,
#  'tiro': 6.214608098422191,
#  'differenti': 4.422848629194137,
#  'lossless': 6.907755278982137,
#  'decreas': 3.7297014486341915,
#  'bodi': 4.8283137373023015,
#  'lead': 4.8283137373023015,
#  'german': 6.907755278982137,
#  'nyquist': 6.907755278982137,
#  'mm': 6.907755278982137,
#  'ferrit': 4.3428059215206005,
#  'scintil': 4.605170185988092,
#  'disintegr': 6.907755278982137,
#  'withstandard': 6.907755278982137,
#  'mani': 4.961845129926823,
#  'hyperfin': 6.214608098422191,
#  'steerabl': 6.907755278982137,
#  'ration': 6.907755278982137,
#  'intermediari': 6.907755278982137,
#  'season': 4.074541934925921,
#  'definit': 5.115995809754082,
#  'therefor': 6.907755278982137,
#  'invari': 6.214608098422191,
#  'elast': 6.907755278982137,
#  'cryosistor': 6.907755278982137,
#  'redfield': 6.907755278982137,
#  'topolog': 6.907755278982137,
#  'broadsid': 6.907755278982137,
#  'monthli': 5.298317366548036,
#  'terr': 6.907755278982137,
#  'compar': 3.3813947543659757,
#  'effect': 2.207274913189721,
#  'flayer': 6.907755278982137,
#  'el': 6.907755278982137,
#  'nonadiabat': 6.907755278982137,
#  'consid': 2.995732273553991,
#  'budden': 6.907755278982137,
#  'microcircuit': 6.907755278982137,
#  'post': 6.214608098422191,
#  'highest': 6.907755278982137,
#  'luminos': 6.907755278982137,
#  'media': 5.298317366548036,
#  'bit': 5.521460917862246,
#  'watson': 6.907755278982137,
#  'fabri': 6.907755278982137,
#  'twoer': 6.907755278982137,
#  'sky': 5.298317366548036,
#  'metr': 6.907755278982137,
#  'grade': 6.907755278982137,
#  'phonon': 5.809142990314028,
#  'analogu': 4.199705077879927,
#  'enabl': 5.521460917862246,
#  'five': 5.521460917862246,
#  'heavi': 5.521460917862246,
#  'favour': 5.521460917862246,
#  'layeri': 6.907755278982137,
#  'transvers': 4.710530701645918,
#  'neglig': 6.214608098422191,
#  'formula': 3.649658740960655,
#  'distort': 4.509860006183766,
#  'introduc': 5.809142990314028,
#  'centr': 4.422848629194137,
#  'overal': 5.809142990314028,
#  'equat': 3.2441936328524905,
#  'dynamo': 5.809142990314028,
#  'full': 5.298317366548036,
#  'novel': 6.214608098422191,
#  'almost': 5.521460917862246,
#  'precis': 5.115995809754082,
#  'distribut': 3.101092789211817,
#  'flexibl': 6.907755278982137,
#  'read': 5.298317366548036,
#  'perpendicularli': 6.907755278982137,
#  'express': 3.7297014486341915,
#  'caribbean': 6.907755278982137,
#  'stormi': 6.907755278982137,
#  'extragalact': 6.214608098422191,
#  'weather': 6.907755278982137,
#  'swing': 6.907755278982137,
#  'clock': 6.907755278982137,
#  'probabl': 4.509860006183766,
#  'unoccupi': 6.907755278982137,
#  'bidirect': 6.907755278982137,
#  'round': 6.907755278982137,
#  'coerciv': 6.907755278982137,
#  'explain': 4.135166556742356,
#  'shell': 6.214608098422191,
#  'arriv': 5.809142990314028,
#  'suppli': 4.422848629194137,
#  'procedur': 4.135166556742356,
#  'bifurc': 6.907755278982137,
#  'detect': 4.199705077879927,
#  'pen': 6.907755278982137,
#  'royal': 6.907755278982137,
#  'width': 5.115995809754082,
#  'sampl': 4.8283137373023015,
#  'arrang': 5.115995809754082,
#  'juli': 5.298317366548036,
#  'ranger': 6.907755278982137,
#  'min': 6.214608098422191,
#  'analys': 3.4420193761824107,
#  'demonstr': 4.961845129926823,
#  'half': 4.961845129926823,
#  'absolut': 6.907755278982137,
#  'parametr': 3.473768074496991,
#  'numer': 4.605170185988092,
#  'sept': 6.214608098422191,
#  'lump': 6.214608098422191,
#  'trace': 5.521460917862246,
#  'nice': 6.907755278982137,
#  'vavilov': 6.907755278982137,
#  'val': 6.907755278982137,
#  'stratif': 6.907755278982137,
#  'instal': 5.809142990314028,
#  'throughout': 5.809142990314028,
#  'neutral': 4.710530701645918,
#  'kato': 6.907755278982137,
#  'kind': 6.907755278982137,
#  'rol': 6.907755278982137,
#  'motor': 5.809142990314028,
#  'crane': 6.907755278982137,
#  'notat': 6.214608098422191,
#  'incoher': 6.214608098422191,
#  'deton': 6.907755278982137,
#  'telecommun': 6.907755278982137,
#  'specular': 6.907755278982137,
#  'alfven': 6.907755278982137,
#  'unwant': 6.214608098422191,
#  'partial': 5.298317366548036,
#  'tail': 6.907755278982137,
#  'harmon': 3.8632328412587142,
#  'perige': 6.907755278982137,
#  'emiss': -2.5624462272434183,
#  'briefli': 5.298317366548036,
#  'synthes': 5.298317366548036,
#  'transreson': 6.907755278982137,
#  'util': 5.809142990314028,
#  'faraday': 5.115995809754082,
#  'inject': 5.809142990314028,
#  'ring': 4.509860006183766,
#  'second': 4.3428059215206005,
#  'properti': 3.912023005428146,
#  'although': 5.298317366548036,
#  'pnpn': 6.214608098422191,
#  'intrins': 5.809142990314028,
#  'tidal': 6.907755278982137,
#  'couett': 6.907755278982137,
#  'incid': 4.135166556742356,
#  'meteorolog': 6.214608098422191,
#  'hree': 6.907755278982137,
#  'turn': 5.521460917862246,
#  'tunnel': 3.3813947543659757,
#  'well': 4.961845129926823,
#  'plot': 4.605170185988092,
#  'sputter': 6.907755278982137,
#  'banalor': 6.907755278982137,
#  'ottawa': 6.214608098422191,
#  'advanc': 6.214608098422191,
#  'novemb': 4.074541934925921,
#  'predetermin': 6.907755278982137,
#  'spheric': 4.710530701645918,
#  'highspe': 6.907755278982137,
#  'washington': 5.298317366548036,
#  'intens': 3.473768074496991,
#  'rico': 6.907755278982137,
#  'adopt': 6.214608098422191,
#  'intermodul': 6.907755278982137,
#  'oy': 6.907755278982137,
#  'airglow': 4.961845129926823,
#  'character': 6.907755278982137,
#  'orient': 5.298317366548036,
#  'fabric': 6.907755278982137,
#  'irrevers': 6.907755278982137,
#  'factor': 3.9633162998156966,
#  'quartz': 5.521460917862246,
#  'cauer': 6.214608098422191,
#  'cylind': 4.961845129926823,
#  'precess': 6.907755278982137,
#  'hundr': 6.214608098422191,
#  'imbed': 6.907755278982137,
#  'astrophys': 6.907755278982137,
#  'futur': 5.521460917862246,
#  'ionospher': 2.137070654516472,
#  'afbmd': 6.907755278982137,
#  'veroniqu': 6.907755278982137,
#  'want': 6.907755278982137,
#  'doubl': 4.8283137373023015,
#  'rod': 6.907755278982137,
#  'specif': 5.521460917862246,
#  'assess': 5.298317366548036,
#  'multicav': 6.907755278982137,
#  'releas': 6.907755278982137,
#  'transistor': 3.036554268074246,
#  'mobil': 6.907755278982137,
#  'take': 4.710530701645918,
#  'millston': 6.907755278982137,
#  'helix': 5.809142990314028,
#  'x': 4.710530701645918,
#  'spatial': 5.521460917862246,
#  'branch': 5.809142990314028,
#  'fictiti': 6.907755278982137,
#  'gradient': 4.8283137373023015,
#  'lie': 5.809142990314028,
#  'minut': 6.907755278982137,
#  'view': 6.214608098422191,
#  'filamentari': 6.907755278982137,
#  'stoke': 6.907755278982137,
#  'sm': 6.907755278982137,
#  'held': 6.214608098422191,
#  'refer': 4.422848629194137,
#  'caesium': 6.907755278982137,
#  'subcarri': 6.907755278982137,
#  'lightn': 6.214608098422191,
#  'sunspot': 4.509860006183766,
#  'disadvantag': 5.809142990314028,
#  'henc': 6.214608098422191,
#  'explos': 5.809142990314028,
#  'variabl': 3.506557897319982,
#  'electroacoust': 6.907755278982137,
#  'loss': 4.135166556742356,
#  'recurr': 5.809142990314028,
#  'interplanetari': 4.8283137373023015,
#  'test': 4.3428059215206005,
#  'difficulti': 5.115995809754082,
#  'suppress': 6.907755278982137,
#  'per': 5.115995809754082,
#  'usabl': 6.907755278982137,
#  'goldstein': 6.907755278982137,
#  'ahmedabad': 6.907755278982137,
#  'photo': 6.214608098422191,
#  'averag': 4.199705077879927,
#  'magic': 6.907755278982137,
#  'regularli': 6.214608098422191,
#  'circuit': 2.0099154790312257,
#  'turbul': 5.809142990314028,
#  'insuffici': 6.907755278982137,
#  'zero': 4.710530701645918,
#  'logarithm': 6.214608098422191,
#  'ral': 6.907755278982137,
#  'restrict': 5.809142990314028,
#  'defect': 6.214608098422191,
#  'thick': 4.710530701645918,
#  'ammonia': 6.907755278982137,
#  'light': 4.199705077879927,
#  'circular': 4.710530701645918,
#  'invers': 4.961845129926823,
#  'expon': 6.907755278982137,
#  'photoexcit': 6.907755278982137,
#  'rise': 5.809142990314028,
#  'holt': 6.907755278982137,
#  'florenc': 6.907755278982137,
#  'north': 5.298317366548036,
#  'es': 5.298317366548036,
#  'role': 5.521460917862246,
#  'impli': 5.809142990314028,
#  'photomultipli': 5.809142990314028,
#  'storag': 3.9633162998156966,
#  'feed': 6.214608098422191,
#  'occas': 5.809142990314028,
#  'polar': 3.9633162998156966,
#  'slight': 6.214608098422191,
#  'mixtur': 6.907755278982137,
#  'bloch': 6.907755278982137,
#  'especi': 6.907755278982137,
#  'univers': 5.521460917862246,
#  'rate': 3.649658740960655,
#  'sec': 4.961845129926823,
#  'rule': 5.809142990314028,
#  'interpret': 4.135166556742356,
#  'isobar': 6.907755278982137,
#  'qualit': 6.214608098422191,
#  'transform': 3.9633162998156966,
#  'calcul': 2.9565115604007097,
#  'index': 4.422848629194137,
#  'algebra': 5.809142990314028,
#  'schedul': 6.907755278982137,
#  'shape': 4.3428059215206005,
#  'extract': 6.214608098422191,
#  'k': 5.521460917862246,
#  'made': 2.900422093749666,
#  'discuss': -4.442151131448634,
#  'jacobi': 6.907755278982137,
#  'respons': 3.816712825623821,
#  'theorem': 5.809142990314028,
#  'time': 2.631089159966082,
#  'converg': 5.809142990314028,
#  'microwav': 3.4420193761824107,
#  'dust': 6.214608098422191,
#  'puk': 6.907755278982137,
#  'mill': 6.907755278982137,
#  'swept': 6.214608098422191,
#  'multivibr': 6.907755278982137,
#  'magnetomet': 5.809142990314028,
#  'root': 6.214608098422191,
#  'circul': 5.298317366548036,
#  'tabul': 6.214608098422191,
#  'symbol': 5.809142990314028,
#  'unequ': 5.809142990314028,
#  'leopoldvil': 6.907755278982137,
#  'angular': 4.710530701645918,
#  'kent': 6.907755278982137,
#  'l': 5.115995809754082,
#  'coaxial': 5.809142990314028,
#  'hf': 5.115995809754082,
#  'quick': 6.907755278982137,
#  'slough': 6.214608098422191,
#  'suitabl': 3.8632328412587142,
#  'circl': 6.907755278982137,
#  'penetr': 6.214608098422191,
#  'avoid': 5.809142990314028,
#  'durban': 6.907755278982137,
#  'coil': 4.8283137373023015,
#  'medium': 4.710530701645918,
#  'optron': 6.907755278982137,
#  'telegraph': 6.907755278982137,
#  'unilater': 6.214608098422191,
#  'balanc': 6.214608098422191,
#  'corbino': 6.907755278982137,
#  'vol': 6.214608098422191,
#  'outlin': 4.8283137373023015,
#  'proton': 4.199705077879927,
#  'gain': 3.611918412977808,
#  'constanc': 6.907755278982137,
#  'intend': 6.214608098422191,
#  'complex': 5.115995809754082,
#  'occur': 3.324236340526027,
#  'shoran': 6.907755278982137,
#  'milki': 6.907755278982137,
#  'conveni': 6.907755278982137,
#  'cross': 3.816712825623821,
#  'wideband': 6.907755278982137,
#  'identif': 6.214608098422191,
#  'vertex': 6.907755278982137,
#  'vicin': 6.214608098422191,
#  'diod': 2.659260036932778,
#  'galvanomagnet': 6.907755278982137,
#  'unreli': 6.214608098422191,
#  'passiv': 4.710530701645918,
#  'piezoelectr': 5.521460917862246,
#  'creation': 6.907755278982137,
#  'declin': 5.809142990314028,
#  'great': 5.809142990314028,
#  'output': 3.575550768806933,
#  'radii': 4.961845129926823,
#  'commenc': 5.521460917862246,
#  'microsecond': 6.214608098422191,
#  'repeat': 5.809142990314028,
#  'inner': 4.8283137373023015,
#  'nitrogen': 5.298317366548036,
#  'possess': 6.907755278982137,
#  'recognit': 6.907755278982137,
#  'bottleneck': 6.907755278982137,
#  'pattern': 4.710530701645918,
#  'interstellar': 6.907755278982137,
#  'bay': 5.809142990314028,
#  'sun': 4.268697949366879,
#  'titan': 6.907755278982137,
#  'seniti': 6.907755278982137,
#  'reappear': 6.907755278982137,
#  'profil': 4.3428059215206005,
#  'radiomet': 5.521460917862246,
#  'push': 5.521460917862246,
#  'meter': 6.907755278982137,
#  'emphasi': 6.214608098422191,
#  'evalu': 5.115995809754082,
#  'magnitud': 5.115995809754082,
#  'region': 2.864704011147587,
#  'neutron': 4.961845129926823,
#  'servo': 6.907755278982137,
#  'portabl': 6.907755278982137,
#  'fox': 6.907755278982137,
#  'narrow': 5.115995809754082,
#  'institut': 6.907755278982137,
#  'maxima': 6.214608098422191,
#  'self': 5.521460917862246,
#  'examin': 3.649658740960655,
#  'repres': 5.115995809754082,
#  'meteorit': 6.907755278982137,
#  'nearli': 6.214608098422191,
#  'ultraviolet': 6.907755278982137,
#  'octob': 5.521460917862246,
#  'constant': 3.8632328412587142,
#  'perhap': 6.907755278982137,
#  'write': 6.907755278982137,
#  'itali': 6.907755278982137,
#  'elong': 4.961845129926823,
#  'trajectori': 5.809142990314028,
#  'behaviour': 4.422848629194137,
#  'solut': 3.816712825623821,
#  'cosmic': 3.4420193761824107,
#  'ordinari': 5.521460917862246,
#  'necessit': 6.907755278982137,
#  'whether': 6.907755278982137,
#  'unsatisfactori': 6.907755278982137,
#  'site': 5.809142990314028,
#  'butterworth': 6.907755278982137,
#  'ai': 6.907755278982137,
#  'third': 5.521460917862246,
#  'observ': 1.9661128563728327,
#  'could': 4.422848629194137,
#  'detector': 5.115995809754082,
#  'summari': 6.214608098422191,
#  'loop': 4.8283137373023015,
#  'magnetograph': 6.907755278982137,
#  'still': 6.907755278982137,
#  'distinct': 6.907755278982137,
#  'eras': 6.907755278982137,
#  'adeli': 6.907755278982137,
#  'occult': 6.907755278982137,
#  'twenti': 5.809142990314028,
#  'beat': 6.907755278982137,
#  'sw': 6.907755278982137,
#  'scout': 6.214608098422191,
#  'achiev': 4.268697949366879,
#  'wedg': 6.214608098422191,
#  'masur': 6.907755278982137,
#  'whitfield': 6.907755278982137,
#  'varianc': 6.907755278982137,
#  'soviet': 6.214608098422191,
#  'summer': 5.809142990314028,
#  'cylindr': 4.961845129926823,
#  'sphere': 5.809142990314028,
#  'elementari': 5.809142990314028,
#  'within': 3.9633162998156966,
#  'radial': 5.298317366548036,
#  'kilocycl': 6.907755278982137,
#  'cheap': 6.907755278982137,
#  'dipol': 4.605170185988092,
#  'pioneer': 5.809142990314028,
#  'long': 4.074541934925921,
#  'ferroelectr': 6.214608098422191,
#  'uncompens': 6.907755278982137,
#  'april': 4.8283137373023015,
#  'abrupt': 6.907755278982137,
#  'six': 4.8283137373023015,
#  'scale': 4.135166556742356,
#  'research': 4.961845129926823,
#  'environ': 6.907755278982137,
#  'proport': 5.298317366548036,
#  'hold': 6.907755278982137,
#  'tropospher': 6.214608098422191,
#  'interferomet': 5.115995809754082,
#  'tabular': 6.907755278982137,
#  'translat': 6.907755278982137,
#  'either': 5.298317366548036,
#  'eject': 6.907755278982137,
#  'macquari': 5.521460917862246,
#  'particl': 3.270169119255751,
#  'israel': 6.907755278982137,
#  'constitut': 6.907755278982137,
#  'cool': 6.214608098422191,
#  'print': 6.907755278982137,
#  'local': 3.8632328412587142,
#  'taipet': 6.907755278982137,
#  'wherein': 6.907755278982137,
#  'far': 5.809142990314028,
#  'poona': 6.907755278982137,
#  'fourier': 4.8283137373023015,
#  'steadi': 4.3428059215206005,
#  'ta': 6.907755278982137,
#  'justifi': 6.907755278982137,
#  'cryotron': 5.809142990314028,
#  'descript': 3.7722610630529876,
#  'major': 4.710530701645918,
#  'departur': 5.521460917862246,
#  'criteria': 6.214608098422191,
#  'chang': 3.1941832122778293,
#  'flat': 5.521460917862246,
#  'slot': 5.809142990314028,
#  'sunris': 5.809142990314028,
#  'servomechan': 6.907755278982137,
#  'number': 4.017383521085972,
#  'charact': 5.521460917862246,
#  'super': 6.214608098422191,
#  'flash': 5.809142990314028,
#  'thunderstorm': 5.521460917862246,
#  'delta': 6.907755278982137,
#  'british': 6.214608098422191,
#  'superconduct': 5.809142990314028,
#  'fine': 6.907755278982137,
#  'duffin': 6.907755278982137,
#  'prototyp': 6.907755278982137,
#  'bohm': 6.907755278982137,
#  'waveform': 4.8283137373023015,
#  'geomagnet': 3.2188758248682006,
#  'triangl': 6.907755278982137,
#  'act': 5.115995809754082,
#  'would': 4.961845129926823,
#  'cite': 6.907755278982137,
#  'midnight': 5.809142990314028,
#  'cassiopeia': 6.907755278982137,
#  'transport': 5.809142990314028,
#  'lutting': 6.907755278982137,
#  'geograph': 6.214608098422191,
#  'return': 6.907755278982137,
#  'construct': 4.422848629194137,
#  'ascens': 6.907755278982137,
#  'acceler': 5.521460917862246,
#  'propag': 3.473768074496991,
#  'significantli': 6.907755278982137,
#  'nevada': 6.907755278982137,
#  'estim': -2.9952321485123092,
#  'jupit': 6.214608098422191,
#  'altern': 5.115995809754082,
#  'moon': 4.509860006183766,
#  'balloon': 5.298317366548036,
#  'convers': 4.710530701645918,
#  'monsoon': 6.907755278982137,
#  'usual': 4.710530701645918,
#  'block': 5.809142990314028,
#  'success': 5.115995809754082,
#  'opaqu': 6.907755278982137,
#  'particularli': 4.8283137373023015,
#  'section': 4.135166556742356,
#  'nicolet': 6.907755278982137,
#  'cherenkov': 4.710530701645918,
#  'punch': 6.214608098422191,
#  'liquid': 6.214608098422191,
#  'steep': 6.907755278982137,
#  'neon': 5.809142990314028,
#  'typic': 5.809142990314028,
#  'classifi': 6.907755278982137,
#  'bia': 5.298317366548036,
#  'arbitrarili': 6.907755278982137,
#  'environment': 6.907755278982137,
#  'antenna': 5.809142990314028,
#  'erser': 6.907755278982137,
#  'substitut': 6.214608098422191,
#  'hard': 5.809142990314028,
#  'volum': 6.214608098422191,
#  'confoc': 6.907755278982137,
#  'gyroscop': 6.907755278982137,
#  'middl': 6.214608098422191,
#  'hi': 6.907755278982137,
#  'choic': 6.907755278982137,
#  'load': 4.509860006183766,
#  'satur': 4.8283137373023015,
#  'live': 6.214608098422191,
#  'ambient': 6.214608098422191,
#  'signatur': 6.907755278982137,
#  'domain': 6.907755278982137,
#  'space': 3.506557897319982,
#  'note': 3.611918412977808,
#  'fragment': 6.907755278982137,
#  'pump': 4.8283137373023015,
#  'atom': 4.8283137373023015,
#  'hourli': 6.214608098422191,
#  'least': 4.961845129926823,
#  'multipli': 5.809142990314028,
#  'follow': 4.509860006183766,
#  'outsid': 4.8283137373023015,
#  'jacobian': 6.214608098422191,
#  'minimis': 6.907755278982137,
#  'accord': 6.907755278982137,
#  'locat': 5.115995809754082,
#  'tube': 4.509860006183766,
#  'terof': 6.907755278982137,
#  'stronger': 6.907755278982137,
#  'boulder': 6.907755278982137,
#  'depend': 3.6888794541139363,
#  'maser': 3.411247717515657,
#  'prepar': 6.214608098422191,
#  'u': 6.907755278982137,
#  'absorpt': 3.575550768806933,
#  'panoram': 6.907755278982137,
#  'nois': 2.7646205525906042,
#  'quadripol': 4.8283137373023015,
#  'nonlinear': 3.611918412977808,
#  'equival': 4.199705077879927,
#  'nonreciproc': 4.961845129926823,
#  'indic': 3.611918412977808,
#  'paper': 4.961845129926823,
#  'cap': 5.809142990314028,
#  'march': 4.710530701645918,
#  'splot': 6.907755278982137,
#  'kinet': 5.298317366548036,
#  'survey': 4.509860006183766,
#  'servic': 6.907755278982137,
#  'inferior': 6.907755278982137,
#  'differ': 3.411247717515657,
#  'card': 6.214608098422191,
#  'higher': 5.298317366548036,
#  'yield': 6.214608098422191,
#  'ce': 6.907755278982137,
#  'sector': 6.907755278982137,
#  'way': 6.214608098422191,
#  'wina': 6.907755278982137,
#  'fresh': 6.214608098422191,
#  'oscil': 3.036554268074246,
#  'interest': 6.214608098422191,
#  'solv': 4.605170185988092,
#  'gesellschaft': 6.907755278982137,
#  'bessel': 6.907755278982137,
#  'bombard': 6.214608098422191,
#  'mang': 6.907755278982137,
#  'author': 4.961845129926823,
#  'identifi': 5.809142990314028,
#  'import': 5.521460917862246,
#  'wi': 5.809142990314028,
#  'missil': 5.521460917862246,
#  'less': 4.422848629194137,
#  'emerald': 6.907755278982137,
#  'cut': 5.521460917862246,
#  'composit': 5.809142990314028,
#  'expect': 5.809142990314028,
#  'hine': 6.907755278982137,
#  'alloy': 6.907755278982137,
#  'sh': 6.907755278982137,
#  'magneto': 4.8283137373023015,
#  'shown': 4.3428059215206005,
#  'thu': 6.214608098422191,
#  'upon': 5.809142990314028,
#  'vectori': 6.907755278982137,
#  'emitt': 4.961845129926823,
#  'nearbi': 6.907755278982137,
#  'degre': 5.521460917862246,
#  'spectrum': 3.649658740960655,
#  'portion': 6.907755278982137,
#  'tht': 6.214608098422191,
#  'raptur': 6.907755278982137,
#  'shaper': 6.907755278982137,
#  'year': 4.422848629194137,
#  'spot': 6.214608098422191,
#  'earli': 6.907755278982137,
#  'instantan': 6.214608098422191,
#  'hanicap': 6.907755278982137,
#  'cover': 4.509860006183766,
#  'emit': 5.115995809754082,
#  'shunt': 6.214608098422191,
#  'surg': 6.907755278982137,
#  'spiral': 6.907755278982137,
#  'rc': 4.961845129926823,
#  'skin': 6.907755278982137,
#  'provision': 6.907755278982137,
#  'work': 4.422848629194137,
#  'check': 6.214608098422191,
#  'stray': 6.907755278982137,
#  'constitu': 6.214608098422191,
#  'helliwel': 6.907755278982137,
#  'paramet': 3.3813947543659757,
#  'format': 4.710530701645918,
#  'vortic': 6.907755278982137,
#  'gyro': 5.809142990314028,
#  'lifetim': 5.809142990314028,
#  'reactor': 5.298317366548036,
#  'apparatu': 6.214608098422191,
#  'microminiaturizatio': 6.214608098422191,
#  'boltzmann': 5.809142990314028,
#  'wear': 6.907755278982137,
#  'southern': 5.298317366548036,
#  'techniqu': 3.2968373663379125,
#  'tip': 6.907755278982137,
#  'wheatston': 6.214608098422191,
#  'recur': 6.907755278982137,
#  'store': 4.8283137373023015,
#  'monoton': 6.907755278982137,
#  'direct': 4.135166556742356,
#  'thousand': 6.907755278982137,
#  'discover': 5.809142990314028,
#  'tie': 6.907755278982137,
#  'video': 6.214608098422191,
#  'decad': 6.214608098422191,
#  'nighttim': 5.521460917862246,
#  'simpl': 4.268697949366879,
#  'transduct': 6.907755278982137,
#  'percentag': 6.214608098422191,
#  'quasi': 6.214608098422191,
#  'ballist': 6.907755278982137,
#  'lecher': 6.214608098422191,
#  'overrid': 6.907755278982137,
#  'agre': 5.115995809754082,
#  'mechan': -3.295336740962647,
#  'kw': 6.907755278982137,
#  'present': 3.816712825623821,
#  'si': 4.961845129926823,
#  'step': 5.521460917862246,
#  'coupl': 3.3813947543659757,
#  'mixer': 5.809142990314028,
#  'kokobunji': 6.907755278982137,
#  'rubi': 4.509860006183766,
#  'baguio': 6.907755278982137,
#  'appli': 3.2441936328524905,
#  'breakdown': 6.214608098422191,
#  'hx': 6.907755278982137,
#  'product': 4.3428059215206005,
#  'tent': 5.809142990314028,
#  'much': 5.298317366548036,
#  'failur': 6.214608098422191,
#  'total': 4.199705077879927,
#  'gaseou': 5.521460917862246,
#  'transfer': 4.199705077879927,
#  'true': 5.298317366548036,
#  'stream': 5.809142990314028,
#  'fade': 4.605170185988092,
#  'august': 5.115995809754082,
#  'deviat': 6.214608098422191,
#  'optimum': 4.710530701645918,
#  'date': 6.214608098422191,
#  'interpenetr': 6.907755278982137,
#  'valley': 6.907755278982137,
#  'nonhomogen': 6.907755278982137,
#  'allow': 4.961845129926823,
#  'uniform': 4.710530701645918,
#  'fribourg': 6.907755278982137,
#  'multipact': 6.907755278982137,
#  'northern': 5.521460917862246,
#  'recoveri': 5.809142990314028,
#  'dynam': 4.605170185988092,
#  'satellit': 2.4534079827286295,
#  'applic': 2.8302178350764176,
#  'packag': 6.907755278982137,
#  'selenium': 6.907755278982137,
#  'reproduc': 6.214608098422191,
#  'reveal': 5.521460917862246,
#  'speci': 5.809142990314028,
#  'repli': 5.298317366548036,
#  'filament': 6.907755278982137,
#  'naval': 6.907755278982137,
#  'wide': 3.8632328412587142,
#  'corpuscular': 5.521460917862246,
#  'ascrib': 5.298317366548036,
#  'topic': 6.907755278982137,
#  'permalloy': 6.907755278982137,
#  'superconductor': 6.214608098422191,
#  'ter': 6.907755278982137,
#  'sodium': 6.907755278982137,
#  'boresight': 6.907755278982137,
#  'virtual': 5.521460917862246,
#  'taper': 6.214608098422191,
#  'master': 6.907755278982137,
#  'induct': 4.605170185988092,
#  'beyond': 6.214608098422191,
#  'brown': 6.907755278982137,
#  'linear': 3.3524072174927233,
#  'electrostat': 4.605170185988092,
#  'reject': 6.214608098422191,
#  'infin': 6.907755278982137,
#  'obtain': 2.4534079827286295,
#  'steer': 6.214608098422191,
#  'temperatur': 3.506557897319982,
#  'capacit': 4.268697949366879,
#  'ocean': 6.907755278982137,
#  'case': 3.575550768806933,
#  'vector': 6.214608098422191,
#  'proceed': 6.907755278982137,
#  'synchron': 6.214608098422191,
#  'stop': 6.214608098422191,
#  'bank': 6.907755278982137,
#  'radic': 6.907755278982137,
#  'perman': 6.214608098422191,
#  'ude': 6.907755278982137,
#  'coverag': 6.214608098422191,
#  'cathod': -2.0789414166381537,
#  'later': 6.907755278982137,
#  'radio': 2.501036031717884,
#  'zenith': 6.214608098422191,
#  'sudden': 4.961845129926823,
#  'viscou': 6.907755278982137,
#  ...}

# %% [markdown]
# getting total doc rsv score

# %%
#calculates the rsv of a document based on the query provided
def generate_doc_rsv(file_name, query):
    result = 0
    doc_list = data[data["file_name"] == file_name]["text"]
    for doc in doc_list:
        for word in doc:
            if word in query:
                result += weights[word]
    return result

# %% [markdown]
# rank docs by query provided

# %%
#retreive all docs containing our word
#get the rsv score of the retrieved docs
def rank_docs(query):
    results = {
        'file_name': [],
        'score': []
    }
    docs = list()
    for word in query:
        docs = [*docs, *list(word_dict[word])]
    for file_name in docs:
        results['file_name'].append(file_name)
        results['score'].append(generate_doc_rsv(file_name, query))
    results = pd.DataFrame(results).sort_values('score', ascending=False)
    return results

# %% [markdown]
# # search results/ prediction

# %%
#preprocess the query first then rank
def search_query(search_query, retrieved_docs = 10):
    #tokenize query
    query = list(tokenize([search_query]))[0]
    #lower case
    query = [txt.lower() for txt in query]
    #stop words
    query = [txt for txt in query if not txt in stop_words]
    #stemming
    query = [porter_stemmer.stem(txt) for txt in query]
    return rank_docs(query).head(retrieved_docs)

# %% [markdown]
# get the query

# %% [markdown]
# get first top 10 results

# %%
result = search_query("calculator", 10)
result
# Out:
#      file_name     score
# 12  file_10053  8.869535
# 0   file_10077  2.956512
# 39  file_10008  2.956512
# 29  file_10135  2.956512
# 30  file_10032  2.956512
# 31  file_10588  2.956512
# 32  file_10054  2.956512
# 33  file_10087  2.956512
# 34  file_10827  2.956512
# 35  file_10853  2.956512
